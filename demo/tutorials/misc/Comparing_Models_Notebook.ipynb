# %% [markdown]
# ![logog](https://raw.githubusercontent.com/Pacific-AI-Corp/langtest/main/docs/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Pacific-AI-Corp/langtest/blob/main/demo/tutorials/misc/Comparing_Models_Notebook.ipynb)

# %% [markdown]
# **LangTest** is an open-source python library designed to help developers deliver safe and effective Natural Language Processing (NLP) models. Whether you are using **John Snow Labs, Hugging Face, Spacy** models or **OpenAI, Cohere, AI21, Hugging Face Inference API and Azure-OpenAI** based LLMs, it has got you covered. You can test any Named Entity Recognition (NER), Text Classification, fill-mask, Translation model using the library. We also support testing LLMS for Question-Answering, Summarization and text-generation tasks on benchmark datasets. The library supports 60+ out of the box tests. For a complete list of supported test categories, please refer to the [documentation](http://langtest.org/docs/pages/docs/test_categories).
#
# Metrics are calculated by comparing the model's extractions in the original list of sentences against the extractions carried out in the noisy list of sentences. The original annotated labels are not used at any point, we are simply comparing the model against itself in a 2 settings.

# %% [markdown]
# # Getting started with LangTest

# %%
# !pip install "langtest[johnsnowlabs,transformers,spacy]"

# %% [markdown]
# # Harness and Its Parameters
#
# The Harness class is a testing class for Natural Language Processing (NLP) models. It evaluates the performance of a NLP model on a given task using test data and generates a report with test results.Harness can be imported from the LangTest library in the following way.

# %%
#Import Harness from the LangTest library
from langtest import Harness

# %% [markdown]
# It imports the Harness class from within the module, that is designed to provide a blueprint or framework for conducting NLP testing, and that instances of the Harness class can be customized or configured for different testing scenarios or environments.
#
# Here is a list of the different parameters that can be passed to the Harness function:
#
# <br/>
#
#
# | Parameter     | Description |
# | - | - |
# | **task**      | Task for which the model is to be evaluated (text-classification or ner) |
# | **model**     | Specifies the model(s) to be evaluated. This parameter can be provided as either a dictionary or a list of dictionaries. Each dictionary should contain the following keys: <ul><li>model (mandatory): 	PipelineModel or path to a saved model or pretrained pipeline/model from hub.</li><li>hub (mandatory): Hub (library) to use in back-end for loading model from public models hub or from path</li></ul>|
# | **data**      | The data to be used for evaluation. A dictionary providing flexibility and options for data sources. It should include the following keys: <ul><li>data_source (mandatory): The source of the data.</li><li>subset (optional): The subset of the data.</li><li>feature_column (optional): The column containing the features.</li><li>target_column (optional): The column containing the target labels.</li><li>split (optional): The data split to be used.</li><li>source (optional): Set to 'huggingface' when loading Hugging Face dataset.</li></ul> |
# | **config**    | Configuration for the tests to be performed, specified in the form of a YAML file. |
#
# <br/>
# <br/>

# %% [markdown]
# # Comparing Models Using NLP Test
#
# With the LangTest library, testing multiple models and comparing them are now possible. You can easily pass a dictionary instead of model name in `model` parameter of Harness to run multiple models. Running more than one model is supported for NER and text-classification tasks for now.

# %% [markdown]
# ### New "model" Parameter
#
# Instead of giving a model name or instance in the parameter, now you can give list of dictionaries in the following format :
#
#
#
# ```python
#
# models = [{"model": "ner.dl" , "hub":"johnsnowlabs"} , {"model":"en_core_web_sm", "hub": "spacy"}]
#
# Harness(..., model=models, ...)
#
# ```

# %% [markdown]
# ## Comparing Text Classification Models

# %% [markdown]
# ### Setup and Configure Harness

# %% [markdown]
# We will compare `en.sentiment.imdb.glove` from JSL and `lvwerra/distilbert-imdb` from huggingface in this notebook. We will use imdb sentiments sample csv dataset. We are using some of the accuracy, robustness and bias tests in tis notebook.

# %%
# Load the sample.csv
# !wget https://raw.githubusercontent.com/JohnSnowLabs/langtest/main/langtest/data/imdb/sample.csv

# %%
models = [{"model": "en.sentiment.imdb.glove" , "hub":"johnsnowlabs"} , {"model":"lvwerra/distilbert-imdb", "hub": "huggingface"}]

harness = Harness(task="text-classification", model=models, data={"data_source":'sample.csv'})
# Out:
# Warning::Spark Session already created, some configs may not take.
# sentimentdl_glove_imdb download started this may take some time.
# Approximate size to download 8.7 MB
# [OK!]
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/735 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/333 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Test Configuration :
#  {
#  "tests": {
#   "defaults": {
#    "min_pass_rate": 1.0
#   },
#   "robustness": {
#    "add_typo": {
#     "min_pass_rate": 0.7
#    },
#    "american_to_british": {
#     "min_pass_rate": 0.7
#    }
#   },
#   "accuracy": {
#    "min_micro_f1_score": {
#     "min_score": 0.7
#    }
#   },
#   "bias": {
#    "replace_to_female_pronouns": {
#     "min_pass_rate": 0.7
#    },
#    "replace_to_low_income_country": {
#     "min_pass_rate": 0.7
#    }
#   },
#   "fairness": {
#    "min_gender_f1_score": {
#     "min_score": 0.6
#    }
#   },
#   "representation": {
#    "min_label_representation_count": {
#     "min_count": 50
#    }
#   }
#  }
# }

# %%
harness.configure({
    "tests":{
        "defaults":{"min_pass_rate":0.5},
        "accuracy":{
            "min_macro_f1_score":{"min_score":0.7},
        },
        "robustness":{
            "add_typo":{"min_pass_rate":0.7},
            "lowercase":{"min_pass_rate":0.7},
        },
        "bias":{
            "replace_to_female_pronouns":{"min_pass_rate":0.7},
        }
    }
})
# Out:
# {'tests': {'defaults': {'min_pass_rate': 0.5},
#   'accuracy': {'min_macro_f1_score': {'min_score': 0.7}},
#   'robustness': {'add_typo': {'min_pass_rate': 0.7},
#    'lowercase': {'min_pass_rate': 0.7}},
#   'bias': {'replace_to_female_pronouns': {'min_pass_rate': 0.7}}}}

# %% [markdown]
# ### Generate the testcases
# The result of the generate function now has an extra column called model_name which specifies which model is the testcase is for.

# %%
harness.generate()
# Out:
# Generating testcases...: 100%|██████████| 3/3 [00:00<00:00, 4780.74it/s]
# Generating testcases...: 100%|██████████| 3/3 [00:00<00:00, 2819.38it/s]

# %%
harness.testcases()
# Out:
#                    model_name    category                   test_type  \
# 0     en.sentiment.imdb.glove    accuracy          min_macro_f1_score
# 1     en.sentiment.imdb.glove  robustness                    add_typo
# 2     en.sentiment.imdb.glove  robustness                    add_typo
# 3     en.sentiment.imdb.glove  robustness                    add_typo
# 4     en.sentiment.imdb.glove  robustness                    add_typo
# ...                       ...         ...                         ...
# 1197  lvwerra/distilbert-imdb        bias  replace_to_female_pronouns
# 1198  lvwerra/distilbert-imdb        bias  replace_to_female_pronouns
# 1199  lvwerra/distilbert-imdb        bias  replace_to_female_pronouns
# 1200  lvwerra/distilbert-imdb        bias  replace_to_female_pronouns
# 1201  lvwerra/distilbert-imdb        bias  replace_to_female_pronouns
#
#                                                original  \
# 0                                                     -
# 1     Just as a reminder to anyone just now reading ...
# 2     Like CURSE OF THE KOMODO was for the creature ...
# 3     I think that the costumes were excellent, and ...
# 4     This is one of my most favorite movies of all ...
# ...                                                 ...
# 1197  The opening was a steal from "Eight-legged Fre...
# 1198  Now don't get me wrong, I love seeing half nak...
# 1199  Though I saw this movie dubbed in French, so I...
# 1200  This is one of the best presentations of the 6...
# 1201  I saw this movie previewed before something el...
#
#                                               test_case
# 0                                                 macro
# 1     Just as a reminder to anyone just now reading ...
# 2     Like CURSE OF THE KOMODO was for the creature ...
# 3     I think that the costumes were excellent, and ...
# 4     Thos is one of my most favorite movies of all ...
# ...                                                 ...
# 1197  The opening was a steal from "Eight-legged Fre...
# 1198  Now don't get me wrong, I love seeing half nak...
# 1199  Though I saw this movie dubbed in French, so I...
# 1200  This is one of the best presentations of the 6...
# 1201  I saw this movie previewed before something el...
#
# [1202 rows x 5 columns]

# %% [markdown]
# harness.generate() method automatically generates the test cases (based on the provided configuration)

# %% [markdown]
# ### Running the tests

# %%
harness.run()
# Out:
# Running testcases... : 100%|██████████| 601/601 [10:22<00:00,  1.04s/it]
# Running testcases... : 100%|██████████| 601/601 [09:02<00:00,  1.11it/s]

# %% [markdown]
# ### Generated Results

# %%
harness.generated_results()
# Out:
#                    model_name    category                   test_type  \
# 0     en.sentiment.imdb.glove    accuracy          min_macro_f1_score
# 1     en.sentiment.imdb.glove  robustness                    add_typo
# 2     en.sentiment.imdb.glove  robustness                    add_typo
# 3     en.sentiment.imdb.glove  robustness                    add_typo
# 4     en.sentiment.imdb.glove  robustness                    add_typo
# ...                       ...         ...                         ...
# 1197  lvwerra/distilbert-imdb        bias  replace_to_female_pronouns
# 1198  lvwerra/distilbert-imdb        bias  replace_to_female_pronouns
# 1199  lvwerra/distilbert-imdb        bias  replace_to_female_pronouns
# 1200  lvwerra/distilbert-imdb        bias  replace_to_female_pronouns
# 1201  lvwerra/distilbert-imdb        bias  replace_to_female_pronouns
#
#                                                original  \
# 0                                                     -
# 1     Just as a reminder to anyone just now reading ...
# 2     Like CURSE OF THE KOMODO was for the creature ...
# 3     I think that the costumes were excellent, and ...
# 4     This is one of my most favorite movies of all ...
# ...                                                 ...
# 1197  The opening was a steal from "Eight-legged Fre...
# 1198  Now don't get me wrong, I love seeing half nak...
# 1199  Though I saw this movie dubbed in French, so I...
# 1200  This is one of the best presentations of the 6...
# 1201  I saw this movie previewed before something el...
#
#                                               test_case expected_result  \
# 0                                                 macro             0.7
# 1     Just as a reminder to anyone just now reading ...             pos
# 2     Like CURSE OF THE KOMODO was for the creature ...             neg
# 3     I think that the costumes were excellent, and ...             pos
# 4     Thos is one of my most favorite movies of all ...             pos
# ...                                                 ...             ...
# 1197  The opening was a steal from "Eight-legged Fre...        NEGATIVE
# 1198  Now don't get me wrong, I love seeing half nak...        NEGATIVE
# 1199  Though I saw this movie dubbed in French, so I...        POSITIVE
# 1200  This is one of the best presentations of the 6...        POSITIVE
# 1201  I saw this movie previewed before something el...        NEGATIVE
#
#      actual_result   pass
# 0              0.0  False
# 1              pos   True
# 2              neg   True
# 3              pos   True
# 4              pos   True
# ...            ...    ...
# 1197      NEGATIVE   True
# 1198      NEGATIVE   True
# 1199      POSITIVE   True
# 1200      POSITIVE   True
# 1201      NEGATIVE   True
#
# [1202 rows x 8 columns]

# %% [markdown]
# ### Final Results
#
# We can call `.report()` which summarizes the results giving information about pass and fail counts and overall test pass/fail status of models and tests.

# %%
harness.report()

# %% [markdown]
# ## Comparing NER Models

# %% [markdown]
# ### Setup and Configure Harness

# %% [markdown]
# We will compare `ner.dl` from JSL and `en_core_web_sm` from spacy in this notebook. We will use CoNLL 2003 sample conll dataset. We are not providing a config so default config will be used.

# %%
# Load a sample.conll
# !wget https://raw.githubusercontent.com/JohnSnowLabs/langtest/main/langtest/data/conll/sample.conll
# Out:
# --2023-08-18 05:11:09--  https://raw.githubusercontent.com/JohnSnowLabs/langtest/main/langtest/data/conll/sample.conll
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50519 (49K) [text/plain]
# Saving to: ‘sample.conll’
#
# sample.conll        100%[===================>]  49.33K  --.-KB/s    in 0.001s
#
# 2023-08-18 05:11:10 (52.2 MB/s) - ‘sample.conll’ saved [50519/50519]

# %%
models = [{"model": "ner.dl" , "hub":"johnsnowlabs"} , {"model":"en_core_web_sm", "hub": "spacy"}]

harness = Harness(task="ner", model=models, data={"data_source":'sample.conll'})
# Out:
# Warning::Spark Session already created, some configs may not take.
# Warning::Spark Session already created, some configs may not take.
# recognize_entities_dl download started this may take some time.
# Approx size to download 160.1 MB
# [OK!]
# Test Configuration :
#  {
#  "tests": {
#   "defaults": {
#    "min_pass_rate": 1.0
#   },
#   "robustness": {
#    "add_typo": {
#     "min_pass_rate": 0.7
#    },
#    "american_to_british": {
#     "min_pass_rate": 0.7
#    }
#   },
#   "accuracy": {
#    "min_micro_f1_score": {
#     "min_score": 0.7
#    }
#   },
#   "bias": {
#    "replace_to_female_pronouns": {
#     "min_pass_rate": 0.7
#    },
#    "replace_to_low_income_country": {
#     "min_pass_rate": 0.7
#    }
#   },
#   "fairness": {
#    "min_gender_f1_score": {
#     "min_score": 0.6
#    }
#   },
#   "representation": {
#    "min_label_representation_count": {
#     "min_count": 50
#    }
#   }
#  }
# }

# %% [markdown]
# ### Generate the testcases
# The result of the generate function now has an extra column called model_name which specifies which model is the testcase is for.

# %%
harness.generate()
# Out:
# Generating testcases...: 100%|██████████| 5/5 [00:00<00:00, 6871.40it/s]
# Generating testcases...: 100%|██████████| 5/5 [00:00<00:00, 7101.77it/s]

# %%
harness.testcases()
# Out:
#           model_name        category                       test_type  \
# 0             ner.dl      robustness                        add_typo
# 1             ner.dl      robustness                        add_typo
# 2             ner.dl      robustness                        add_typo
# 3             ner.dl      robustness                        add_typo
# 4             ner.dl      robustness                        add_typo
# ...              ...             ...                             ...
# 1821  en_core_web_sm  representation  min_label_representation_count
# 1822  en_core_web_sm  representation  min_label_representation_count
# 1823  en_core_web_sm  representation  min_label_representation_count
# 1824  en_core_web_sm  representation  min_label_representation_count
# 1825  en_core_web_sm  representation  min_label_representation_count
#
#                                                original  \
# 0     SOCCER - JAPAN GET LUCKY WIN , CHINA IN SURPRI...
# 1                                           Nadim Ladki
# 2              AL-AIN , United Arab Emirates 1996-12-06
# 3     Japan began the defence of their Asian Cup tit...
# 4     But China saw their luck desert them in the se...
# ...                                                 ...
# 1821                                                  -
# 1822                                                  -
# 1823                                                  -
# 1824                                                  -
# 1825                                                  -
#
#                                               test_case
# 0     SOCCER - JAPAN GET LUCKY WIN , FHINA IN SURPRI...
# 1                                           Nadim Ladik
# 2              AL-AIB , United Arab Emirates 1996-12-06
# 3     Jaian began the defence of their Asian Cup tit...
# 4     But China saw their luck desert them in the se...
# ...                                                 ...
# 1821                                               MISC
# 1822                                                LOC
# 1823                                                  O
# 1824                                                PER
# 1825                                                ORG
#
# [1826 rows x 5 columns]

# %% [markdown]
# harness.generate() method automatically generates the test cases (based on the provided configuration)

# %% [markdown]
# ### Running the tests

# %%
harness.run()
# Out:
# Running testcases... :   0%|          | 0/913 [00:00<?, ?it/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/525 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/51.0M [00:00<?, ?B/s]
# Running testcases... : 100%|██████████| 913/913 [02:43<00:00,  5.58it/s]
# Running testcases... : 100%|██████████| 913/913 [00:21<00:00, 42.11it/s]

# %% [markdown]
# ### Generated Results

# %% [markdown]
# This method returns the generated results in the form of a pandas dataframe, which provides a convenient and easy-to-use format for working with the test results. You can use this method to quickly identify the test cases that failed and to determine where fixes are needed. This dataframe has an extra column called model_name when harness is used to compare different models.

# %%
harness.generated_results()
# Out:
#           model_name        category                       test_type  \
# 0             ner.dl      robustness                        add_typo
# 1             ner.dl      robustness                        add_typo
# 2             ner.dl      robustness                        add_typo
# 3             ner.dl      robustness                        add_typo
# 4             ner.dl      robustness                        add_typo
# ...              ...             ...                             ...
# 1821  en_core_web_sm  representation  min_label_representation_count
# 1822  en_core_web_sm  representation  min_label_representation_count
# 1823  en_core_web_sm  representation  min_label_representation_count
# 1824  en_core_web_sm  representation  min_label_representation_count
# 1825  en_core_web_sm  representation  min_label_representation_count
#
#                                                original  \
# 0     SOCCER - JAPAN GET LUCKY WIN , CHINA IN SURPRI...
# 1                                           Nadim Ladki
# 2              AL-AIN , United Arab Emirates 1996-12-06
# 3     Japan began the defence of their Asian Cup tit...
# 4     But China saw their luck desert them in the se...
# ...                                                 ...
# 1821                                                  -
# 1822                                                  -
# 1823                                                  -
# 1824                                                  -
# 1825                                                  -
#
#                                               test_case  \
# 0     SOCCER - JAPAN GET LUCKY WIN , FHINA IN SURPRI...
# 1                                           Nadim Ladik
# 2              AL-AIB , United Arab Emirates 1996-12-06
# 3     Jaian began the defence of their Asian Cup tit...
# 4     But China saw their luck desert them in the se...
# ...                                                 ...
# 1821                                               MISC
# 1822                                                LOC
# 1823                                                  O
# 1824                                                PER
# 1825                                                ORG
#
#                               expected_result  \
# 0                      JAPAN: LOC, CHINA: LOC
# 1                            Nadim Ladki: ORG
# 2      AL-AIN: LOC, United Arab Emirates: LOC
# 3     Japan: LOC, Asian Cup: MISC, Syria: LOC
# 4                 China: LOC, Uzbekistan: LOC
# ...                                       ...
# 1821                                     50.0
# 1822                                     50.0
# 1823                                     50.0
# 1824                                     50.0
# 1825                                     50.0
#
#                                 actual_result   pass
# 0                      JAPAN: LOC, FHINA: ORG  False
# 1                            Nadim Ladik: PER  False
# 2      AL-AIB: LOC, United Arab Emirates: LOC   True
# 3     Jaian: PER, Asian Cup: MISC, Syria: LOC  False
# 4                 China: LOC, Uzbekistan: LOC   True
# ...                                       ...    ...
# 1821                                     71.0   True
# 1822                                    183.0   True
# 1823                                   2291.0   True
# 1824                                    507.0   True
# 1825                                     88.0   True
#
# [1826 rows x 8 columns]

# %% [markdown]
# ### Final Results
#
# We can call `.report()` which summarizes the results giving information about pass and fail counts and overall test pass/fail status of models and tests.

# %%
harness.report()
# Out:
# <style type="text/css">
# #T_dd257_row0_col0, #T_dd257_row0_col1, #T_dd257_row0_col3, #T_dd257_row0_col5, #T_dd257_row0_col6, #T_dd257_row1_col0, #T_dd257_row1_col1, #T_dd257_row1_col2, #T_dd257_row1_col3, #T_dd257_row1_col4, #T_dd257_row1_col5, #T_dd257_row1_col6 {
#   background-color: green;
# }
# #T_dd257_row0_col2, #T_dd257_row0_col4 {
#   background-color: red;
# }
# </style>
# <table id="T_dd257" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >test_type</th>
#       <th id="T_dd257_level0_col0" class="col_heading level0 col0" >add_typo</th>
#       <th id="T_dd257_level0_col1" class="col_heading level0 col1" >american_to_british</th>
#       <th id="T_dd257_level0_col2" class="col_heading level0 col2" >min_gender_f1_score</th>
#       <th id="T_dd257_level0_col3" class="col_heading level0 col3" >min_label_representation_count</th>
#       <th id="T_dd257_level0_col4" class="col_heading level0 col4" >min_micro_f1_score</th>
#       <th id="T_dd257_level0_col5" class="col_heading level0 col5" >replace_to_female_pronouns</th>
#       <th id="T_dd257_level0_col6" class="col_heading level0 col6" >replace_to_low_income_country</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd257_level0_row0" class="row_heading level0 row0" >en_core_web_sm</th>
#       <td id="T_dd257_row0_col0" class="data row0 col0" >0.750000</td>
#       <td id="T_dd257_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_dd257_row0_col2" class="data row0 col2" >0.670000</td>
#       <td id="T_dd257_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_dd257_row0_col4" class="data row0 col4" >0.500000</td>
#       <td id="T_dd257_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_dd257_row0_col6" class="data row0 col6" >0.860000</td>
#     </tr>
#     <tr>
#       <th id="T_dd257_level0_row1" class="row_heading level0 row1" >ner.dl</th>
#       <td id="T_dd257_row1_col0" class="data row1 col0" >0.810000</td>
#       <td id="T_dd257_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_dd257_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_dd257_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_dd257_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_dd257_row1_col5" class="data row1 col5" >1.000000</td>
#       <td id="T_dd257_row1_col6" class="data row1 col6" >0.960000</td>
#     </tr>
#   </tbody>
# </table>
