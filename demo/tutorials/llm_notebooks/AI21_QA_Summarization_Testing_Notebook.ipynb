# %% [markdown]
# ![logog](https://raw.githubusercontent.com/Pacific-AI-Corp/langtest/main/docs/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Pacific-AI-Corp/langtest/blob/main/demo/tutorials/llm_notebooks/AI21_QA_Summarization_Testing_Notebook.ipynb)

# %% [markdown]
# **LangTest** is an open-source python library designed to help developers deliver safe and effective Natural Language Processing (NLP) models. Whether you are using **John Snow Labs, Hugging Face, Spacy** models or **OpenAI, Cohere, AI21, Hugging Face Inference API and Azure-OpenAI** based LLMs, it has got you covered. You can test any Named Entity Recognition (NER), Text Classification, fill-mask, Translation model using the library. We also support testing LLMS for Question-Answering, Summarization and text-generation tasks on benchmark datasets. The library supports 60+ out of the box tests. For a complete list of supported test categories, please refer to the [documentation](http://langtest.org/docs/pages/docs/test_categories).
#
# Metrics are calculated by comparing the model's extractions in the original list of sentences against the extractions carried out in the noisy list of sentences. The original annotated labels are not used at any point, we are simply comparing the model against itself in a 2 settings.

# %% [markdown]
# # Getting started with LangTest

# %%
# !pip install "langtest[evaluate,ai21,transformers]"

# %% [markdown]
# # Harness and Its Parameters
#
# The Harness class is a testing class for Natural Language Processing (NLP) models. It evaluates the performance of a NLP model on a given task using test data and generates a report with test results.Harness can be imported from the LangTest library in the following way.

# %%
#Import Harness from the LangTest library
from langtest import Harness

# %% [markdown]
# It imports the Harness class from within the module, that is designed to provide a blueprint or framework for conducting NLP testing, and that instances of the Harness class can be customized or configured for different testing scenarios or environments.
#
# Here is a list of the different parameters that can be passed to the Harness function:
#
# <br/>
#
#
# | Parameter  | Description |
# | - | - |
# |**task**     |Task for which the model is to be evaluated (question-answering or summarization)|
# | **model**     | Specifies the model(s) to be evaluated. This parameter can be provided as either a dictionary or a list of dictionaries. Each dictionary should contain the following keys: <ul><li>model (mandatory): 	PipelineModel or path to a saved model or pretrained pipeline/model from hub.</li><li>hub (mandatory): Hub (library) to use in back-end for loading model from public models hub or from path</li></ul>|
# | **data**      | The data to be used for evaluation. A dictionary providing flexibility and options for data sources. It should include the following keys: <ul><li>data_source (mandatory): The source of the data.</li><li>subset (optional): The subset of the data.</li><li>feature_column (optional): The column containing the features.</li><li>target_column (optional): The column containing the target labels.</li><li>split (optional): The data split to be used.</li><li>source (optional): Set to 'huggingface' when loading Hugging Face dataset.</li></ul> |
# | **config**    | Configuration for the tests to be performed, specified in the form of a YAML file. |
#
# <br/>
# <br/>

# %% [markdown]
# # AI21 Model Testing For Question Answering
#
# In this section, we dive into testing of AI21 models in Question Answering task.
#
# LangTest supports robustness tests for LLM testing for now.

# %% [markdown]
# ### Set environment for AI21

# %%
import os
os.environ["AI21_API_KEY"] = "<YOUR_API_KEY>"

# %% [markdown]
# ## BoolQ-test-tiny dataset testing

# %% [markdown]
# ### Setup and Configure Harness

# %%
harness = Harness(
                  task="question-answering", 
                  model={"model": "j2-jumbo-instruct", "hub":"ai21"}, 
                  data={"data_source" :"BoolQ",
                        "split":"test-tiny"}
                  )
# Out:
# Test Configuration :
#  {
#  "model_parameters": {
#   "max_tokens": 64
#  },
#  "tests": {
#   "defaults": {
#    "min_pass_rate": 1.0
#   },
#   "robustness": {
#    "add_typo": {
#     "min_pass_rate": 0.7
#    },
#    "lowercase": {
#     "min_pass_rate": 0.7
#    }
#   }
#  }
# }

# %% [markdown]
# We have specified task as QA, hub as AI21 and model as `j2-jumbo-instruct`.

# %% [markdown]
# For dataset we used `BoolQ` dataset and `test-tiny` split which includes 50 samples. Other available datasets are: [Benchmark Datasets](https://langtest.org/docs/pages/docs/data#question-answering)

# %% [markdown]
# For tests we used lowercase and uppercase. Other available robustness tests for QA task are:
# * `add_context`
# * `add_contraction`
# * `add_punctuation`
# * `add_typo`
# * `add_ocr_typo`
# * `american_to_british`
# * `british_to_american`
# * `lowercase`
# * `strip_punctuation`
# * `titlecase`
# * `uppercase`
# * `number_to_word`
# * `add_abbreviation`
# * `add_speech_to_text_typo`
# * `add_slangs`
# * `dyslexia_word_swap`
# * `multiple_perturbations`
# * `adjective_synonym_swap`
# * `adjective_antonym_swap`
# * `strip_all_punctuation`

# %% [markdown]
# Available Bias tests for QA task are:
#
# * `replace_to_male_pronouns`
# * `replace_to_female_pronouns`
# * `replace_to_neutral_pronouns`
# * `replace_to_high_income_country`
# * `replace_to_low_income_country`
# * `replace_to_upper_middle_income_country`
# * `replace_to_lower_middle_income_country`
# * `replace_to_white_firstnames`
# * `replace_to_black_firstnames`
# * `replace_to_hispanic_firstnames`
# * `replace_to_asian_firstnames`
# * `replace_to_white_lastnames`
# * `replace_to_sikh_names`
# * `replace_to_christian_names`
# * `replace_to_hindu_names`
# * `replace_to_muslim_names`
# * `replace_to_inter_racial_lastnames`
# * `replace_to_native_american_lastnames`
# * `replace_to_asian_lastnames`
# * `replace_to_hispanic_lastnames`
# * `replace_to_black_lastnames`
# * `replace_to_parsi_names`
# * `replace_to_jain_names`
# * `replace_to_buddhist_names`

# %% [markdown]
# Available Representation tests for QA task are:
#
# * `min_gender_representation_count`
# * `min_ethnicity_name_representation_count`
# * `min_religion_name_representation_count`
# * `min_country_economic_representation_count`
# * `min_gender_representation_proportion`
# * `min_ethnicity_name_representation_proportion`
# * `min_religion_name_representation_proportion`
# * `min_country_economic_representation_proportion`

# %% [markdown]
# Available Accuracy tests for QA task are:
#
# * `min_exact_match_score`
# * `min_bleu_score`
# * `min_rouge1_score`
# * `min_rouge2_score`
# * `min_rougeL_score`
# * `min_rougeLsum_score`

# %% [markdown]
# Available Fairness tests for QA task are:
#
# * `max_gender_rouge1_score`
# * `max_gender_rouge2_score`
# * `max_gender_rougeL_score`
# * `max_gender_rougeLsum_score`
# * `min_gender_rouge1_score`
# * `min_gender_rouge2_score`
# * `min_gender_rougeL_score`
# * `min_gender_rougeLsum_score`

# %% [markdown]
# You can also set prompts and other model parameters in config. Possible parameters are:
# * `user_promt:` Promt to be given to the model.
# * `temperature:` Temperature of the model.
# * `max_tokens:` Maximum number of output tokens allowed for model.

# %%
harness.configure({
    'model_parameters': {
      'max_tokens': 64
    },  
    'tests': {
      'defaults':{
        'min_pass_rate': 1.00
      },

      'robustness':{
        'lowercase': {'min_pass_rate': 0.70},
        'uppercase': {'min_pass_rate': 0.70}
      }
    }
})
# Out:
# {'model_parameters': {'max_tokens': 64},
#  'tests': {'defaults': {'min_pass_rate': 1.0},
#   'robustness': {'lowercase': {'min_pass_rate': 0.7},
#    'uppercase': {'min_pass_rate': 0.7}}}}

# %% [markdown]
# Here we have configured the harness to perform two robustness tests (uppercase and lowercase) and defined the minimum pass rate for each test.

# %% [markdown]
# ➤ You can adjust the level of transformation in the sentence by using the "`prob`" parameter, which controls the proportion of words to be changed during robustness tests.
#
# ➤ **NOTE** : "`prob`" defaults to 1.0, which means all words will be transformed.
# ```
# harness.configure(
# {
#  'tests': {
#     'defaults': {'min_pass_rate': 0.65},
#       'robustness': {
#         'lowercase': {'min_pass_rate': 0.66, 'prob': 0.50},
#         'uppercase':{'min_pass_rate': 0.60, 'prob': 0.70},
#       }
#   }
# })
#
# ```

# %% [markdown]
# ### Generating the test cases.

# %%
harness.generate()
# Out:
# Generating testcases...: 100%|██████████| 1/1 [00:00<?, ?it/s]

# %% [markdown]
# harness.generate() method automatically generates the test cases (based on the provided configuration)

# %%
harness.testcases()
# Out:
#       category  test_type                                   original_context  \
# 0   robustness  lowercase  20 euro note -- Until now there has been only ...
# 1   robustness  lowercase  2018–19 UEFA Champions League -- The final wil...
# 2   robustness  lowercase  Bullsnake -- Bullsnakes are very powerful cons...
# 3   robustness  lowercase  NBA playoffs -- All rounds are best-of-seven s...
# 4   robustness  lowercase  Manchester station group -- The Manchester sta...
# ..         ...        ...                                                ...
# 95  robustness  uppercase  Puerto Rico -- Puerto Rico (Spanish for ``Rich...
# 96  robustness  uppercase  West Memphis Three -- There have been a number...
# 97  robustness  uppercase  The Temptations -- As of 2017, the Temptations...
# 98  robustness  uppercase  Isle of Wight -- The Isle of Wight (/waɪt/; al...
# 99  robustness  uppercase  Tomb of the Unknown Soldier (Arlington) -- On ...
#
#                                     original_question  \
# 0   is the first series 20 euro note still legal t...
# 1   do the champions league winners get automatic ...
# 2                   can a bull snake kill a small dog
# 3                 are all nba playoff games best of 7
# 4   can i use my train ticket on the tram in manch...
# ..                                                ...
# 95              is puerto a part of the united states
# 96            is devil's knot based on west memphis 3
# 97  are any of the original temptations still in t...
# 98             is the isle of wight part of hampshire
# 99  is there a body in the tomb of the unknown sol...
#
#                                     perturbed_context  \
# 0   20 euro note -- until now there has been only ...
# 1   2018–19 uefa champions league -- the final wil...
# 2   bullsnake -- bullsnakes are very powerful cons...
# 3   nba playoffs -- all rounds are best-of-seven s...
# 4   manchester station group -- the manchester sta...
# ..                                                ...
# 95  PUERTO RICO -- PUERTO RICO (SPANISH FOR ``RICH...
# 96  WEST MEMPHIS THREE -- THERE HAVE BEEN A NUMBER...
# 97  THE TEMPTATIONS -- AS OF 2017, THE TEMPTATIONS...
# 98  ISLE OF WIGHT -- THE ISLE OF WIGHT (/WAꞮT/; AL...
# 99  TOMB OF THE UNKNOWN SOLDIER (ARLINGTON) -- ON ...
#
#                                    perturbed_question
# 0   is the first series 20 euro note still legal t...
# 1   do the champions league winners get automatic ...
# 2                   can a bull snake kill a small dog
# 3                 are all nba playoff games best of 7
# 4   can i use my train ticket on the tram in manch...
# ..                                                ...
# 95              IS PUERTO A PART OF THE UNITED STATES
# 96            IS DEVIL'S KNOT BASED ON WEST MEMPHIS 3
# 97  ARE ANY OF THE ORIGINAL TEMPTATIONS STILL IN T...
# 98             IS THE ISLE OF WIGHT PART OF HAMPSHIRE
# 99  IS THERE A BODY IN THE TOMB OF THE UNKNOWN SOL...
#
# [100 rows x 6 columns]

# %% [markdown]
# harness.testcases() method displays the produced test cases in form of a pandas data frame.

# %% [markdown]
# ### Running the tests

# %%
harness.run()
# Out:
# Running testcases... : 100%|██████████| 100/100 [01:39<00:00,  1.01it/s]

# %% [markdown]
# Called after harness.generate() and is to used to run all the tests.  Returns a pass/fail flag for each test.

# %%
harness.generated_results()
# Out:
#       category  test_type                                   original_context  \
# 0   robustness  lowercase  20 euro note -- Until now there has been only ...
# 1   robustness  lowercase  2018–19 UEFA Champions League -- The final wil...
# 2   robustness  lowercase  Bullsnake -- Bullsnakes are very powerful cons...
# 3   robustness  lowercase  NBA playoffs -- All rounds are best-of-seven s...
# 4   robustness  lowercase  Manchester station group -- The Manchester sta...
# ..         ...        ...                                                ...
# 95  robustness  uppercase  Puerto Rico -- Puerto Rico (Spanish for ``Rich...
# 96  robustness  uppercase  West Memphis Three -- There have been a number...
# 97  robustness  uppercase  The Temptations -- As of 2017, the Temptations...
# 98  robustness  uppercase  Isle of Wight -- The Isle of Wight (/waɪt/; al...
# 99  robustness  uppercase  Tomb of the Unknown Soldier (Arlington) -- On ...
#
#                                     original_question  \
# 0   is the first series 20 euro note still legal t...
# 1   do the champions league winners get automatic ...
# 2                   can a bull snake kill a small dog
# 3                 are all nba playoff games best of 7
# 4   can i use my train ticket on the tram in manch...
# ..                                                ...
# 95              is puerto a part of the united states
# 96            is devil's knot based on west memphis 3
# 97  are any of the original temptations still in t...
# 98             is the isle of wight part of hampshire
# 99  is there a body in the tomb of the unknown sol...
#
#                                     perturbed_context  \
# 0   20 euro note -- until now there has been only ...
# 1   2018–19 uefa champions league -- the final wil...
# 2   bullsnake -- bullsnakes are very powerful cons...
# 3   nba playoffs -- all rounds are best-of-seven s...
# 4   manchester station group -- the manchester sta...
# ..                                                ...
# 95  PUERTO RICO -- PUERTO RICO (SPANISH FOR ``RICH...
# 96  WEST MEMPHIS THREE -- THERE HAVE BEEN A NUMBER...
# 97  THE TEMPTATIONS -- AS OF 2017, THE TEMPTATIONS...
# 98  ISLE OF WIGHT -- THE ISLE OF WIGHT (/WAꞮT/; AL...
# 99  TOMB OF THE UNKNOWN SOLDIER (ARLINGTON) -- ON ...
#
#                                    perturbed_question expected_result  \
# 0   is the first series 20 euro note still legal t...          \nTrue
# 1   do the champions league winners get automatic ...          \nTrue
# 2                   can a bull snake kill a small dog         \nFalse
# 3                 are all nba playoff games best of 7          \nTrue
# 4   can i use my train ticket on the tram in manch...         \nFalse
# ..                                                ...             ...
# 95              IS PUERTO A PART OF THE UNITED STATES          \nTrue
# 96            IS DEVIL'S KNOT BASED ON WEST MEMPHIS 3          \nTrue
# 97  ARE ANY OF THE ORIGINAL TEMPTATIONS STILL IN T...          \nTrue
# 98             IS THE ISLE OF WIGHT PART OF HAMPSHIRE          \nTrue
# 99  IS THERE A BODY IN THE TOMB OF THE UNKNOWN SOL...          \nTrue
#
#    actual_result  pass
# 0         \nTrue  True
# 1         \nTrue  True
# 2        \nFalse  True
# 3         \nTrue  True
# 4        \nFalse  True
# ..           ...   ...
# 95        \nTrue  True
# 96        \nTrue  True
# 97        \nTrue  True
# 98       \nTrue.  True
# 99        \nTrue  True
#
# [100 rows x 9 columns]

# %% [markdown]
# This method returns the generated results in the form of a pandas dataframe, which provides a convenient and easy-to-use format for working with the test results. You can use this method to quickly identify the test cases that failed and to determine where fixes are needed.

# %% [markdown]
# ### Final Results

# %% [markdown]
# We can call `.report()` which summarizes the results giving information about pass and fail counts and overall test pass/fail flag.

# %%
harness.report()
# Out:
#      category  test_type  fail_count  pass_count pass_rate minimum_pass_rate  \
# 0  robustness  lowercase           4          46       92%               70%
# 1  robustness  uppercase           8          42       84%               70%
#
#    pass
# 0  True
# 1  True

# %% [markdown]
# #### NQ-open-test dataset testing

# %% [markdown]
# We can also use another dataset, NQ-open for testing the model.

# %%
harness = Harness(
                  task="question-answering", 
                  model={"model": "j2-jumbo-instruct", "hub": "ai21"}, 
                  data={"data_source" :"NQ-open",
                        "split":"test-tiny"}
                  )
# Out:
# Test Configuration :
#  {
#  "model_parameters": {
#   "max_tokens": 64
#  },
#  "tests": {
#   "defaults": {
#    "min_pass_rate": 1.0
#   },
#   "robustness": {
#    "add_typo": {
#     "min_pass_rate": 0.7
#    },
#    "lowercase": {
#     "min_pass_rate": 0.7
#    }
#   }
#  }
# }

# %%
harness.configure({
    'model_parameters': {
      'max_tokens': 64
    },
    'tests': {
      'defaults':{
        'min_pass_rate': 1.00
      },

      'robustness':{
        'add_abbreviation':{'min_pass_rate': 0.70},
        'uppercase': {'min_pass_rate': 0.70}
      }
    }
})
# Out:
# {'model_parameters': {'max_tokens': 64},
#  'tests': {'defaults': {'min_pass_rate': 1.0},
#   'robustness': {'add_abbreviation': {'min_pass_rate': 0.7},
#    'uppercase': {'min_pass_rate': 0.7}}}}

# %%
harness.data =harness.data[:20]

# %%
harness.generate()
# Out:
# Generating testcases...: 100%|██████████| 1/1 [00:00<?, ?it/s]
# WARNING:root:[W009] Removing samples where no transformation has been applied:
# [W010] - Test 'add_abbreviation': 4 samples removed out of 20

# %%
harness.testcases()
# Out:
#       category         test_type  \
# 0   robustness  add_abbreviation
# 1   robustness  add_abbreviation
# 2   robustness  add_abbreviation
# 3   robustness  add_abbreviation
# 4   robustness  add_abbreviation
# 5   robustness  add_abbreviation
# 6   robustness  add_abbreviation
# 7   robustness  add_abbreviation
# 8   robustness  add_abbreviation
# 9   robustness  add_abbreviation
# 10  robustness  add_abbreviation
# 11  robustness  add_abbreviation
# 12  robustness  add_abbreviation
# 13  robustness  add_abbreviation
# 14  robustness  add_abbreviation
# 15  robustness  add_abbreviation
# 16  robustness         uppercase
# 17  robustness         uppercase
# 18  robustness         uppercase
# 19  robustness         uppercase
# 20  robustness         uppercase
# 21  robustness         uppercase
# 22  robustness         uppercase
# 23  robustness         uppercase
# 24  robustness         uppercase
# 25  robustness         uppercase
# 26  robustness         uppercase
# 27  robustness         uppercase
# 28  robustness         uppercase
# 29  robustness         uppercase
# 30  robustness         uppercase
# 31  robustness         uppercase
# 32  robustness         uppercase
# 33  robustness         uppercase
# 34  robustness         uppercase
# 35  robustness         uppercase
#
#                                     original_question  \
# 0   on the 6th day of christmas my true love sent ...
# 1        how many 5 star generals are there in the us
# 2       how many costco locations are there in the us
# 3           who played grand moff tarkin in rogue one
# 4   youngest current member of the house of repres...
# 5   who wrote the miraculous journey of edward tulane
# 6   when did the night mare before christmas come out
# 7       when does the green book come out in theaters
# 8    who signed the sugauli treaty on behalf of nepal
# 9   what is the name of the hat you wear at gradua...
# 10             who is the guy with arrows in avengers
# 11                 when did the first 3ds xl come out
# 12              how many players can an nfl team have
# 13              what are the rights of a u.s. citizen
# 14  the american psychologist noted as the founder...
# 15    who is the protagonist in she stoops to conquer
# 16  on the 6th day of christmas my true love sent ...
# 17       how many 5 star generals are there in the us
# 18        who killed natalie and ann in sharp objects
# 19      how many costco locations are there in the us
# 20          who played grand moff tarkin in rogue one
# 21  youngest current member of the house of repres...
# 22  who wrote the miraculous journey of edward tulane
# 23  when did the night mare before christmas come out
# 24      when does the green book come out in theaters
# 25   who signed the sugauli treaty on behalf of nepal
# 26           how many players on an nfl active roster
# 27  what is the name of the hat you wear at gradua...
# 28         when did part 2 making a murderer come out
# 29             who is the guy with arrows in avengers
# 30                 when did the first 3ds xl come out
# 31              how many players can an nfl team have
# 32              what are the rights of a u.s. citizen
# 33  the american psychologist noted as the founder...
# 34    who is the protagonist in she stoops to conquer
# 35              a fatty acid that has one double bond
#
#                                    perturbed_question
# 0   on da 6th day of christmas my true <3333 sent ...
# 1           how many 5 star generals r there in da us
# 2          how many costco locations r there in da us
# 3              who pld grand moff tarkin in rogue one
# 4   youngest current member of da house of represe...
# 5    who wrote da miraculous journey of edward tulane
# 6        when did da night mare b4 christmas come out
# 7        when does da green book come out in theaters
# 8       who signed da sugauli treaty on behalf of NPL
# 9       wat is da name of tdahat u wear at graduation
# 10              who is da guy with arrows in avengers
# 11                    when did da 1st 3ds xl come out
# 12                how many players can an nfl team hv
# 13                  wat r da rights of a u.s. citizen
# 14  da american psychologist noted as tdafounder o...
# 15      who is da protagonist in she stoops 2 conquer
# 16  ON THE 6TH DAY OF CHRISTMAS MY TRUE LOVE SENT ...
# 17       HOW MANY 5 STAR GENERALS ARE THERE IN THE US
# 18        WHO KILLED NATALIE AND ANN IN SHARP OBJECTS
# 19      HOW MANY COSTCO LOCATIONS ARE THERE IN THE US
# 20          WHO PLAYED GRAND MOFF TARKIN IN ROGUE ONE
# 21  YOUNGEST CURRENT MEMBER OF THE HOUSE OF REPRES...
# 22  WHO WROTE THE MIRACULOUS JOURNEY OF EDWARD TULANE
# 23  WHEN DID THE NIGHT MARE BEFORE CHRISTMAS COME OUT
# 24      WHEN DOES THE GREEN BOOK COME OUT IN THEATERS
# 25   WHO SIGNED THE SUGAULI TREATY ON BEHALF OF NEPAL
# 26           HOW MANY PLAYERS ON AN NFL ACTIVE ROSTER
# 27  WHAT IS THE NAME OF THE HAT YOU WEAR AT GRADUA...
# 28         WHEN DID PART 2 MAKING A MURDERER COME OUT
# 29             WHO IS THE GUY WITH ARROWS IN AVENGERS
# 30                 WHEN DID THE FIRST 3DS XL COME OUT
# 31              HOW MANY PLAYERS CAN AN NFL TEAM HAVE
# 32              WHAT ARE THE RIGHTS OF A U.S. CITIZEN
# 33  THE AMERICAN PSYCHOLOGIST NOTED AS THE FOUNDER...
# 34    WHO IS THE PROTAGONIST IN SHE STOOPS TO CONQUER
# 35              A FATTY ACID THAT HAS ONE DOUBLE BOND

# %%
harness.run()
# Out:
# Running testcases... : 100%|██████████| 36/36 [01:52<00:00,  3.13s/it]

# %%
harness.generated_results()

# %%
harness.report()

# %% [markdown]
# # Ai21 Model Testing For Summarization
#
# In this section, we dive into testing of Ai21 models in Summarization task.
#
# LangTest supports robustness tests for LLM testing for now.

# %% [markdown]
# ## XSum-test-tiny dataset testing

# %% [markdown]
# ### Setup and configure harness

# %%
harness = Harness(
                  task="summarization", 
                  model={"model": "j2-jumbo-instruct", "hub": "ai21"},
                  data={"data_source" :"XSum",
                        "split":"test-tiny"}
                  )

# %% [markdown]
# We have specified task as summarization, hub as AI21 and model as `j2-jumbo-instruct`.
#
#
# For dataset we used `XSum` dataset and `test-tiny` split which includes 50 samples. Other available datasets are: [Benchmark Datasets](https://langtest.org/docs/pages/docs/data#summarization)

# %% [markdown]
# For tests we used lowercase and uppercase. Other available robustness tests for summarization task are:
#
# * `add_context`
# * `add_contraction`
# * `add_punctuation`
# * `add_typo`
# * `add_ocr_typo`
# * `american_to_british`
# * `british_to_american`
# * `lowercase`
# * `strip_punctuation`
# * `titlecase`
# * `uppercase`
# * `number_to_word`
# * `add_abbreviation`
# * `add_speech_to_text_typo`
# * `add_slangs`
# * `dyslexia_word_swap`
# * `multiple_perturbations`
# * `adjective_synonym_swap`
# * `adjective_antonym_swap`
# * `strip_all_punctuation`
#
# Available Bias tests for summarization task are:
#
# * `replace_to_male_pronouns`
# * `replace_to_female_pronouns`
# * `replace_to_neutral_pronouns`
# * `replace_to_high_income_country`
# * `replace_to_low_income_country`
# * `replace_to_upper_middle_income_country`
# * `replace_to_lower_middle_income_country`
# * `replace_to_white_firstnames`
# * `replace_to_black_firstnames`
# * `replace_to_hispanic_firstnames`
# * `replace_to_asian_firstnames`
# * `replace_to_white_lastnames`
# * `replace_to_sikh_names`
# * `replace_to_christian_names`
# * `replace_to_hindu_names`
# * `replace_to_muslim_names`
# * `replace_to_inter_racial_lastnames`
# * `replace_to_native_american_lastnames`
# * `replace_to_asian_lastnames`
# * `replace_to_hispanic_lastnames`
# * `replace_to_black_lastnames`
# * `replace_to_parsi_names`
# * `replace_to_jain_names`
# * `replace_to_buddhist_names`
#
# Available Representation tests for summarization task are:
#
# * `min_gender_representation_count`
# * `min_ethnicity_name_representation_count`
# * `min_religion_name_representation_count`
# * `min_country_economic_representation_count`
# * `min_gender_representation_proportion`
# * `min_ethnicity_name_representation_proportion`
# * `min_religion_name_representation_proportion`
# * `min_country_economic_representation_proportion`
#
#
# Available Accuracy tests for summarization task are:
#
# * `min_exact_match_score`
# * `min_bleu_score`
# * `min_rouge1_score`
# * `min_rouge2_score`
# * `min_rougeL_score`
# * `min_rougeLsum_score`
#
#
# Available Fairness tests for summarization task are:
#
# * `max_gender_rouge1_score`
# * `max_gender_rouge2_score`
# * `max_gender_rougeL_score`
# * `max_gender_rougeLsum_score`
# * `min_gender_rouge1_score`
# * `min_gender_rouge2_score`
# * `min_gender_rougeL_score`
# * `min_gender_rougeLsum_score`

# %%
harness.configure(
{
 'tests': {'defaults': {'min_pass_rate': 0.65},
           'robustness': {'uppercase': {'min_pass_rate': 0.66}, 
                          'lowercase':{'min_pass_rate': 0.60},
                        }
          }
 }
 )
# Out:
# {'tests': {'defaults': {'min_pass_rate': 0.65},
#   'robustness': {'uppercase': {'min_pass_rate': 0.66},
#    'lowercase': {'min_pass_rate': 0.6}}}}

# %% [markdown]
# `Here we have configured the harness to perform two robustness tests (uppercase and lowercase) and defined the minimum pass rate for each test.`

# %% [markdown]
# ### Generating the Test Cases

# %%
harness.data = harness.data[:20]

# %%
harness.generate()
# Out:
# Generating testcases...: 100%|██████████| 1/1 [00:00<?, ?it/s]

# %%
harness.testcases()
# Out:
#       category  test_type                                           original
# 0   robustness  uppercase  The ex-Reading defender denied fraudulent trad...  \
# 1   robustness  uppercase  Voges was forced to retire hurt on 86 after su...
# 2   robustness  uppercase  Seven photographs taken in the Norfolk country...
# 3   robustness  uppercase  Chris Poole - known as "moot" online - created...
# 4   robustness  uppercase  Four police officers were injured in the incid...
# 5   robustness  uppercase  The injured pedestrian - a young man - is thou...
# 6   robustness  uppercase  Barca will be investigated for alleged misappr...
# 7   robustness  uppercase  The think tank said the city's 1,536 schools n...
# 8   robustness  uppercase  His 110 means he has scored 323 runs in a week...
# 9   robustness  uppercase  Ms Kendall told the BBC Labour risked sending ...
# 10  robustness  uppercase  The Association of School and College Leaders ...
# 11  robustness  uppercase  Media playback is unsupported on your device\n...
# 12  robustness  uppercase  Ann Barnes dealt with an "ill-advised" TV docu...
# 13  robustness  uppercase  The man grabbed hold of a child's bag outside ...
# 14  robustness  uppercase  Taylor, 25, joined County in May from Macclesf...
# 15  robustness  uppercase  The Derbyshire club, who play in the eighth-ti...
# 16  robustness  uppercase  The referendum will take place on 10 March, bu...
# 17  robustness  uppercase  More than a dozen men stormed into the Kiwi ca...
# 18  robustness  uppercase  The New Zealander made only one unenforced swi...
# 19  robustness  uppercase  Then playing for Walsall, the 24-year-old won ...
# 20  robustness  lowercase  The ex-Reading defender denied fraudulent trad...
# 21  robustness  lowercase  Voges was forced to retire hurt on 86 after su...
# 22  robustness  lowercase  Seven photographs taken in the Norfolk country...
# 23  robustness  lowercase  Chris Poole - known as "moot" online - created...
# 24  robustness  lowercase  Four police officers were injured in the incid...
# 25  robustness  lowercase  The injured pedestrian - a young man - is thou...
# 26  robustness  lowercase  Barca will be investigated for alleged misappr...
# 27  robustness  lowercase  The think tank said the city's 1,536 schools n...
# 28  robustness  lowercase  His 110 means he has scored 323 runs in a week...
# 29  robustness  lowercase  Ms Kendall told the BBC Labour risked sending ...
# 30  robustness  lowercase  The Association of School and College Leaders ...
# 31  robustness  lowercase  Media playback is unsupported on your device\n...
# 32  robustness  lowercase  Ann Barnes dealt with an "ill-advised" TV docu...
# 33  robustness  lowercase  The man grabbed hold of a child's bag outside ...
# 34  robustness  lowercase  Taylor, 25, joined County in May from Macclesf...
# 35  robustness  lowercase  The Derbyshire club, who play in the eighth-ti...
# 36  robustness  lowercase  The referendum will take place on 10 March, bu...
# 37  robustness  lowercase  More than a dozen men stormed into the Kiwi ca...
# 38  robustness  lowercase  The New Zealander made only one unenforced swi...
# 39  robustness  lowercase  Then playing for Walsall, the 24-year-old won ...
#
#                                             test_case
# 0   THE EX-READING DEFENDER DENIED FRAUDULENT TRAD...
# 1   VOGES WAS FORCED TO RETIRE HURT ON 86 AFTER SU...
# 2   SEVEN PHOTOGRAPHS TAKEN IN THE NORFOLK COUNTRY...
# 3   CHRIS POOLE - KNOWN AS "MOOT" ONLINE - CREATED...
# 4   FOUR POLICE OFFICERS WERE INJURED IN THE INCID...
# 5   THE INJURED PEDESTRIAN - A YOUNG MAN - IS THOU...
# 6   BARCA WILL BE INVESTIGATED FOR ALLEGED MISAPPR...
# 7   THE THINK TANK SAID THE CITY'S 1,536 SCHOOLS N...
# 8   HIS 110 MEANS HE HAS SCORED 323 RUNS IN A WEEK...
# 9   MS KENDALL TOLD THE BBC LABOUR RISKED SENDING ...
# 10  THE ASSOCIATION OF SCHOOL AND COLLEGE LEADERS ...
# 11  MEDIA PLAYBACK IS UNSUPPORTED ON YOUR DEVICE\n...
# 12  ANN BARNES DEALT WITH AN "ILL-ADVISED" TV DOCU...
# 13  THE MAN GRABBED HOLD OF A CHILD'S BAG OUTSIDE ...
# 14  TAYLOR, 25, JOINED COUNTY IN MAY FROM MACCLESF...
# 15  THE DERBYSHIRE CLUB, WHO PLAY IN THE EIGHTH-TI...
# 16  THE REFERENDUM WILL TAKE PLACE ON 10 MARCH, BU...
# 17  MORE THAN A DOZEN MEN STORMED INTO THE KIWI CA...
# 18  THE NEW ZEALANDER MADE ONLY ONE UNENFORCED SWI...
# 19  THEN PLAYING FOR WALSALL, THE 24-YEAR-OLD WON ...
# 20  the ex-reading defender denied fraudulent trad...
# 21  voges was forced to retire hurt on 86 after su...
# 22  seven photographs taken in the norfolk country...
# 23  chris poole - known as "moot" online - created...
# 24  four police officers were injured in the incid...
# 25  the injured pedestrian - a young man - is thou...
# 26  barca will be investigated for alleged misappr...
# 27  the think tank said the city's 1,536 schools n...
# 28  his 110 means he has scored 323 runs in a week...
# 29  ms kendall told the bbc labour risked sending ...
# 30  the association of school and college leaders ...
# 31  media playback is unsupported on your device\n...
# 32  ann barnes dealt with an "ill-advised" tv docu...
# 33  the man grabbed hold of a child's bag outside ...
# 34  taylor, 25, joined county in may from macclesf...
# 35  the derbyshire club, who play in the eighth-ti...
# 36  the referendum will take place on 10 march, bu...
# 37  more than a dozen men stormed into the kiwi ca...
# 38  the new zealander made only one unenforced swi...
# 39  then playing for walsall, the 24-year-old won ...

# %% [markdown]
# ### Running the tests

# %%
harness.run()
# Out:
# Running testcases... : 100%|██████████| 40/40 [02:23<00:00,  3.59s/it]

# %% [markdown]
# ### Generated Results

# %%
harness.generated_results()
# Out:
#       category  test_type                                           original
# 0   robustness  uppercase  The ex-Reading defender denied fraudulent trad...  \
# 1   robustness  uppercase  Voges was forced to retire hurt on 86 after su...
# 2   robustness  uppercase  Seven photographs taken in the Norfolk country...
# 3   robustness  uppercase  Chris Poole - known as "moot" online - created...
# 4   robustness  uppercase  Four police officers were injured in the incid...
# 5   robustness  uppercase  The injured pedestrian - a young man - is thou...
# 6   robustness  uppercase  Barca will be investigated for alleged misappr...
# 7   robustness  uppercase  The think tank said the city's 1,536 schools n...
# 8   robustness  uppercase  His 110 means he has scored 323 runs in a week...
# 9   robustness  uppercase  Ms Kendall told the BBC Labour risked sending ...
# 10  robustness  uppercase  The Association of School and College Leaders ...
# 11  robustness  uppercase  Media playback is unsupported on your device\n...
# 12  robustness  uppercase  Ann Barnes dealt with an "ill-advised" TV docu...
# 13  robustness  uppercase  The man grabbed hold of a child's bag outside ...
# 14  robustness  uppercase  Taylor, 25, joined County in May from Macclesf...
# 15  robustness  uppercase  The Derbyshire club, who play in the eighth-ti...
# 16  robustness  uppercase  The referendum will take place on 10 March, bu...
# 17  robustness  uppercase  More than a dozen men stormed into the Kiwi ca...
# 18  robustness  uppercase  The New Zealander made only one unenforced swi...
# 19  robustness  uppercase  Then playing for Walsall, the 24-year-old won ...
# 20  robustness  lowercase  The ex-Reading defender denied fraudulent trad...
# 21  robustness  lowercase  Voges was forced to retire hurt on 86 after su...
# 22  robustness  lowercase  Seven photographs taken in the Norfolk country...
# 23  robustness  lowercase  Chris Poole - known as "moot" online - created...
# 24  robustness  lowercase  Four police officers were injured in the incid...
# 25  robustness  lowercase  The injured pedestrian - a young man - is thou...
# 26  robustness  lowercase  Barca will be investigated for alleged misappr...
# 27  robustness  lowercase  The think tank said the city's 1,536 schools n...
# 28  robustness  lowercase  His 110 means he has scored 323 runs in a week...
# 29  robustness  lowercase  Ms Kendall told the BBC Labour risked sending ...
# 30  robustness  lowercase  The Association of School and College Leaders ...
# 31  robustness  lowercase  Media playback is unsupported on your device\n...
# 32  robustness  lowercase  Ann Barnes dealt with an "ill-advised" TV docu...
# 33  robustness  lowercase  The man grabbed hold of a child's bag outside ...
# 34  robustness  lowercase  Taylor, 25, joined County in May from Macclesf...
# 35  robustness  lowercase  The Derbyshire club, who play in the eighth-ti...
# 36  robustness  lowercase  The referendum will take place on 10 March, bu...
# 37  robustness  lowercase  More than a dozen men stormed into the Kiwi ca...
# 38  robustness  lowercase  The New Zealander made only one unenforced swi...
# 39  robustness  lowercase  Then playing for Walsall, the 24-year-old won ...
#
#                                             test_case
# 0   THE EX-READING DEFENDER DENIED FRAUDULENT TRAD...  \
# 1   VOGES WAS FORCED TO RETIRE HURT ON 86 AFTER SU...
# 2   SEVEN PHOTOGRAPHS TAKEN IN THE NORFOLK COUNTRY...
# 3   CHRIS POOLE - KNOWN AS "MOOT" ONLINE - CREATED...
# 4   FOUR POLICE OFFICERS WERE INJURED IN THE INCID...
# 5   THE INJURED PEDESTRIAN - A YOUNG MAN - IS THOU...
# 6   BARCA WILL BE INVESTIGATED FOR ALLEGED MISAPPR...
# 7   THE THINK TANK SAID THE CITY'S 1,536 SCHOOLS N...
# 8   HIS 110 MEANS HE HAS SCORED 323 RUNS IN A WEEK...
# 9   MS KENDALL TOLD THE BBC LABOUR RISKED SENDING ...
# 10  THE ASSOCIATION OF SCHOOL AND COLLEGE LEADERS ...
# 11  MEDIA PLAYBACK IS UNSUPPORTED ON YOUR DEVICE\n...
# 12  ANN BARNES DEALT WITH AN "ILL-ADVISED" TV DOCU...
# 13  THE MAN GRABBED HOLD OF A CHILD'S BAG OUTSIDE ...
# 14  TAYLOR, 25, JOINED COUNTY IN MAY FROM MACCLESF...
# 15  THE DERBYSHIRE CLUB, WHO PLAY IN THE EIGHTH-TI...
# 16  THE REFERENDUM WILL TAKE PLACE ON 10 MARCH, BU...
# 17  MORE THAN A DOZEN MEN STORMED INTO THE KIWI CA...
# 18  THE NEW ZEALANDER MADE ONLY ONE UNENFORCED SWI...
# 19  THEN PLAYING FOR WALSALL, THE 24-YEAR-OLD WON ...
# 20  the ex-reading defender denied fraudulent trad...
# 21  voges was forced to retire hurt on 86 after su...
# 22  seven photographs taken in the norfolk country...
# 23  chris poole - known as "moot" online - created...
# 24  four police officers were injured in the incid...
# 25  the injured pedestrian - a young man - is thou...
# 26  barca will be investigated for alleged misappr...
# 27  the think tank said the city's 1,536 schools n...
# 28  his 110 means he has scored 323 runs in a week...
# 29  ms kendall told the bbc labour risked sending ...
# 30  the association of school and college leaders ...
# 31  media playback is unsupported on your device\n...
# 32  ann barnes dealt with an "ill-advised" tv docu...
# 33  the man grabbed hold of a child's bag outside ...
# 34  taylor, 25, joined county in may from macclesf...
# 35  the derbyshire club, who play in the eighth-ti...
# 36  the referendum will take place on 10 march, bu...
# 37  more than a dozen men stormed into the kiwi ca...
# 38  the new zealander made only one unenforced swi...
# 39  then playing for walsall, the 24-year-old won ...
#
#                                       expected_result
# 0   \nThe ex-Reading defender Sam Sodje has denied...  \
# 1   \nAdam Voges, the Australian batsman, has been...
# 2   \nThe Duchess of Cambridge has collaborated wi...
# 3   \nChris Poole, known as "moot" online, created...
# 4   \nA man and a boy have been charged with six c...
# 5   \nA young man was injured in a collision with ...
# 6   \nRosell has resigned as Barca president after...
# 7   \nThe government's National Funding Formula pl...
# 8   \nTim Murtagh reduced Surrey to 23-2 inside th...
# 9   \nThe Labour party risks sending a "resignatio...
# 10  \nThe Association of School and College Leader...
# 11  \nThe BBC's Ireland correspondent, Chris Buckl...
# 12  \nAnn Barnes dealt with an "ill-advised" TV do...
# 13  \nA man grabbed hold of a pupil's bag outside ...
# 14  \nNewport manager John Sheridan is confident t...
# 15  \nNew Mills have lost all 19 league and cup ga...
# 16  \nBath Conservative MP Ben Howlett said he was...
# 17  \nA brawl erupted between attackers and patron...
# 18  \nWales have made three changes for their Six ...
# 19  \nBradshaw says he was "gutted" to miss out on...
# 20  \nThe Sodje brothers have denied fraudulent tr...
# 21  \nMiddlesex hope to have the Australian batsma...
# 22  \nThe Duchess of Cambridge is to feature in Br...
# 23  \nChris Poole, known as "moot" online, created...
# 24  \nA man and a boy have been charged with six c...
# 25  \nThe injured pedestrian is thought to have be...
# 26  \nRosell has resigned as Barca president after...
# 27  \nThe government's National Funding Formula pl...
# 28  \nTim Murtagh reduced Surrey to 23-2 inside th...
# 29  \nThe Labour leadership contest is heating up,...
# 30  \nThe Association of School and College Leader...
# 31  \nThe BBC's Ireland correspondent, Chris Buckl...
# 32  \nAnn Barnes dealt with an "ill-advised" TV do...
# 33  \nA man grabbed hold of a child's bag outside ...
# 34  \nNewport manager John Sheridan is confident h...
# 35  \nNew Mills have lost all 19 league and cup ga...
# 36  \nBath Conservative MP Ben Howlett said he was...
# 37  \nA brawl erupted in a cafe in Tbilisi, Georgi...
# 38  \nWales coach Warren Gatland has made only one...
# 39  \nBradshaw says he was "gutted" to miss out on...
#
#                                         actual_result  eval_score   pass
# 0   \nSam Sodje, Efe, Bright and Stephen Sodje hav...    0.333333  False
# 1   \nMiddlesex hope to have the Australian back f...    0.309524  False
# 2   \nThe Duchess of Cambridge has collaborated wi...    0.406250  False
# 3   \nChris Poole - known as "moot" online - creat...    0.875912   True
# 4   \nA man and a boy have been charged with six c...    0.875000   True
# 5   \nThe injured pedestrian is thought to have be...    0.375000  False
# 6   \nRosell has resigned as Barca president after...    1.000000   True
# 7   \nThe government's National Funding Formula pl...    0.597015   True
# 8   \nTim Murtagh reduced Surrey to 23-2 inside th...    0.705882   True
# 9   \nThe Labour leadership contest has begun, wit...    0.395604  False
# 10  \nThe Association of School and College Leader...    1.000000   True
# 11  \nThe BBC's Ireland correspondent, Chris Buckl...    1.000000   True
# 12  \nAnn Barnes dealt with an "ill-advised" TV do...    1.000000   True
# 13  \nA man grabbed hold of a pupil's bag outside ...    1.000000   True
# 14  \nNewport manager John Sheridan is confident h...    0.926829   True
# 15  \nNew Mills have lost all 19 league and cup ga...    0.800000   True
# 16  \nBath and North East Somerset Council said th...    0.190476  False
# 17  \nA brawl erupted between a group of neo-Nazis...    0.358974  False
# 18  \nWales have made three changes to the team to...    0.628571   True
# 19  \nBradshaw says he was "gutted" to miss out on...    1.000000   True
# 20  \nSam Sodje, Efe, Bright and Stephen Sodje are...    0.387097  False
# 21  \nMiddlesex hope to have the Australian batsma...    1.000000   True
# 22  \nThe Duchess of Cambridge has collaborated wi...    0.157895  False
# 23  \nChris Poole, known as "moot" online, created...    1.000000   True
# 24  \nA man and a boy have been charged with six c...    1.000000   True
# 25  \nA young man is believed to have sustained in...    0.040000  False
# 26  \nRosell is resigning as Barca president after...    0.622222   True
# 27  \nThe government's National Funding Formula pl...    0.597015   True
# 28  \nTim Murtagh reduced Surrey to 23-2 inside th...    0.517241   True
# 29  \nThe Labour leadership contest has kicked off...    0.456140  False
# 30  \nThe Association of School and College Leader...    1.000000   True
# 31  \nThe BBC's Ireland correspondent, Chris Buckl...    1.000000   True
# 32  \nAnn Barnes dealt with an "ill-advised" TV do...    1.000000   True
# 33  \nA man grabbed hold of a pupil's bag outside ...    0.891892   True
# 34  \nNewport manager John Sheridan is confident h...    1.000000   True
# 35  \nNew Mills have lost all 19 league and cup ga...    0.680851   True
# 36  \nBath and North East Somerset Council said th...    0.677966   True
# 37  \nA brawl erupted in the Kiwi cafe in the Geor...    0.666667   True
# 38  \nWales have made three changes to the team to...    0.372093  False
# 39  \nBradshaw says he was "gutted" to miss out on...    0.733333   True

# %% [markdown]
# ### Generate Report

# %% [markdown]
# We can call `.report()` which summarizes the results giving information about pass and fail counts and overall test pass/fail flag.

# %%
harness.report()
# Out:
#      category  test_type  fail_count  pass_count pass_rate minimum_pass_rate
# 0  robustness  uppercase           7          13       65%               66%  \
# 1  robustness  lowercase           5          15       75%               60%
#
#     pass
# 0  False
# 1   True
