# %% [markdown]
# ![logog](https://raw.githubusercontent.com/Pacific-AI-Corp/langtest/main/docs/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Pacific-AI-Corp/langtest/blob/main/demo/tutorials/llm_notebooks/Swapping_Drug_Names_Test.ipynb)

# %% [markdown]
# **LangTest** is an open-source python library designed to help developers deliver safe and effective Natural Language Processing (NLP) models. Whether you are using **John Snow Labs, Hugging Face, Spacy** models or **OpenAI, Cohere, AI21, Hugging Face Inference API and Azure-OpenAI** based LLMs, it has got you covered. You can test any Named Entity Recognition (NER), Text Classification, fill-mask, Translation model using the library. We also support testing LLMS for Question-Answering, Summarization and text-generation tasks on benchmark datasets. The library supports 60+ out of the box tests. For a complete list of supported test categories, please refer to the [documentation](http://langtest.org/docs/pages/docs/test_categories).
#
# Metrics are calculated by comparing the model's extractions in the original list of sentences against the extractions carried out in the noisy list of sentences. The original annotated labels are not used at any point, we are simply comparing the model against itself in a 2 settings.

# %% [markdown]
# # Getting started with LangTest

# %%
# !pip install "langtest[openai,transformers]==2.3.0"

# %%
import os

os.environ["OPENAI_API_KEY"] = "<YOUR_API_KEY>"

# %% [markdown]
# # Harness and Its Parameters
#
# The Harness class is a testing class for Natural Language Processing (NLP) models. It evaluates the performance of a NLP model on a given task using test data and generates a report with test results.Harness can be imported from the LangTest library in the following way.

# %%
from langtest import Harness

# %% [markdown]
# It imports the Harness class from within the module, that is designed to provide a blueprint or framework for conducting NLP testing, and that instances of the Harness class can be customized or configured for different testing scenarios or environments.
#
# Here is a list of the different parameters that can be passed to the Harness function:
#
# <br/>
#
#
# | Parameter  | Description |
# | - | - |
# |**task**     |Task for which the model is to be evaluated (question-answering, summarization)|
# | **model**     | Specifies the model(s) to be evaluated. This parameter can be provided as either a dictionary or a list of dictionaries. Each dictionary should contain the following keys: <ul><li>model (mandatory): 	PipelineModel or path to a saved model or pretrained pipeline/model from hub.</li><li>hub (mandatory): Hub (library) to use in back-end for loading model from public models hub or from path</li></ul>|
# | **data**      | The data to be used for evaluation. A dictionary providing flexibility and options for data sources. It should include the following keys: <ul><li>data_source (mandatory): The source of the data.</li><li>subset (optional): The subset of the data.</li><li>feature_column (optional): The column containing the features.</li><li>target_column (optional): The column containing the target labels.</li><li>split (optional): The data split to be used.</li><li>source (optional): Set to 'huggingface' when loading Hugging Face dataset.</li></ul> |
# | **config**    | Configuration for the tests to be performed, specified in the form of a YAML file. |
#
# <br/>
# <br/>

# %% [markdown]
# # 👩‍⚕️🩺💉Assess any models for potential consistency issues when converting generic drug names to brand names. 🩹🩸💊

# %% [markdown]
# Assessing models for potential consistency issues when converting generic drug names to brand names involves evaluating the model's ability to accurately and reliably translate generic pharmaceutical terms into their corresponding branded counterparts. This process ensures that the model maintains the integrity of the information and prevents errors that could lead to misunderstandings or misinformation. Consistency checks are crucial in medical contexts where accurate drug identification can significantly impact patient safety and treatment efficacy. By systematically testing and refining the model, developers can ensure that it performs well across various scenarios, thus providing a reliable tool for healthcare applications.
#
# The test `drug_generic_to_brand` focuses on converting generic drug names to their corresponding brand names, ensuring that the model accurately and consistently performs this conversion. This test is critical in medical and pharmaceutical applications where precise drug identification is essential.
#
# For example, consider the generic drug name "ibuprofen." When applying the `drug_generic_to_brand` test, the model should accurately finds "ibuprofen" to its well-known brand name, "Advil." Similarly, "acetaminophen" should be converted to "Tylenol." These conversions help ensure that the model correctly handles drug names, which is vital for tasks such as prescription processing, patient education, and pharmaceutical research. By conducting this test, developers can identify and address any inconsistencies or errors, ultimately enhancing the model's reliability and accuracy in real-world applications.
#
# <b>Original Text:</b> "The patient was given 1 unit of `metformin` daily."</br>
# <b>Pertubated Text:</b> "The patient was given 1 unit of `glucophage` daily."
#
# To generating test cases in langtest like above example, we using `ner_posology` model from JohnsnowLabs to detect the drug entity and replace it with its brand name if entity belongs to generic name of the drug.

# %% [markdown]
# ## Running drug_generic_to_brand test on Curated Dataset

# %%
harness = Harness(
    task="question-answering",
    model={
        "model": "gpt-3.5-turbo",
        "hub": "openai"
    },
    data=[],  # No data needed for this drug_generic_to_brand test
)
# Out:
# Test Configuration :
#  {
#  "model_parameters": {
#   "max_tokens": 64
#  },
#  "tests": {
#   "defaults": {
#    "min_pass_rate": 1.0
#   },
#   "robustness": {
#    "add_typo": {
#     "min_pass_rate": 0.7
#    },
#    "lowercase": {
#     "min_pass_rate": 0.7
#    }
#   }
#  }
# }

# %%
harness.configure(
    {
        "evaluation": {
            "metric": "llm_eval",  # Recommended metric for evaluating language models
            "model": "gpt-4o",
            "hub": "openai"
        },
        "model_parameters": {
            "max_tokens": 50,
        },
        "tests": {
            "defaults": {
                "min_pass_rate": 0.8,
            },
            "clinical": {
                "drug_generic_to_brand": {
                    "min_pass_rate": 0.8,
                    "count": 50,  # Number of questions to ask
                    "curated_dataset": True,  # Use a curated dataset from the langtest library
                }
            }
        }
    }
)
# Out:
# {'evaluation': {'metric': 'llm_eval', 'model': 'gpt-4o', 'hub': 'openai'},
#  'model_parameters': {'max_tokens': 50},
#  'tests': {'defaults': {'min_pass_rate': 0.8},
#   'clinical': {'drug_generic_to_brand': {'min_pass_rate': 0.8,
#     'count': 50,
#     'curated_dataset': True}}}}

# %%
harness.generate()
# Out:
# Generating testcases...: 100%|██████████| 1/1 [00:00<00:00, 975.42it/s]

# %%
harness.testcases()
# Out:
#     category              test_type  \
# 0   clinical  drug_generic_to_brand
# 1   clinical  drug_generic_to_brand
# 2   clinical  drug_generic_to_brand
# 3   clinical  drug_generic_to_brand
# 4   clinical  drug_generic_to_brand
# 5   clinical  drug_generic_to_brand
# 6   clinical  drug_generic_to_brand
# 7   clinical  drug_generic_to_brand
# 8   clinical  drug_generic_to_brand
# 9   clinical  drug_generic_to_brand
# 10  clinical  drug_generic_to_brand
# 11  clinical  drug_generic_to_brand
# 12  clinical  drug_generic_to_brand
# 13  clinical  drug_generic_to_brand
# 14  clinical  drug_generic_to_brand
# 15  clinical  drug_generic_to_brand
# 16  clinical  drug_generic_to_brand
# 17  clinical  drug_generic_to_brand
# 18  clinical  drug_generic_to_brand
# 19  clinical  drug_generic_to_brand
# 20  clinical  drug_generic_to_brand
# 21  clinical  drug_generic_to_brand
# 22  clinical  drug_generic_to_brand
# 23  clinical  drug_generic_to_brand
# 24  clinical  drug_generic_to_brand
# 25  clinical  drug_generic_to_brand
# 26  clinical  drug_generic_to_brand
# 27  clinical  drug_generic_to_brand
# 28  clinical  drug_generic_to_brand
# 29  clinical  drug_generic_to_brand
# 30  clinical  drug_generic_to_brand
# 31  clinical  drug_generic_to_brand
# 32  clinical  drug_generic_to_brand
# 33  clinical  drug_generic_to_brand
# 34  clinical  drug_generic_to_brand
# 35  clinical  drug_generic_to_brand
# 36  clinical  drug_generic_to_brand
# 37  clinical  drug_generic_to_brand
# 38  clinical  drug_generic_to_brand
# 39  clinical  drug_generic_to_brand
# 40  clinical  drug_generic_to_brand
# 41  clinical  drug_generic_to_brand
# 42  clinical  drug_generic_to_brand
# 43  clinical  drug_generic_to_brand
# 44  clinical  drug_generic_to_brand
# 45  clinical  drug_generic_to_brand
# 46  clinical  drug_generic_to_brand
# 47  clinical  drug_generic_to_brand
# 48  clinical  drug_generic_to_brand
# 49  clinical  drug_generic_to_brand
#
#                                     original_question  \
# 0   Question:\nA 31-year-old woman comes to the ph...
# 1   Question:\nAn 18-year-old high school student ...
# 2   Question:\nA typically healthy 27-year-old wom...
# 3   Question:\nA 58-year-old man presents for a fo...
# 4   Question:\nA 24-year-old woman presents to the...
# 5   Question:\nA 56-year-old man comes to the phys...
# 6   Question:\nTwo 19-year-old men are referred by...
# 7   Question:\nA 7-year-old girl presents with a l...
# 8   Question:\nA 26-year-old woman presents to her...
# 9   Question:\nA 35-year-old man presents to his p...
# 10  Question:\nA 77-year-old man presents to the e...
# 11  Question:\nA 56-year-old woman presents with f...
# 12  Question:\nA 29-year-old man comes to the phys...
# 13  Question:\nA 55-year-old man comes to the phys...
# 14  Question:\nA 22-year-old female presents to an...
# 15  Question:\nA 23-year-old Caucasian male presen...
# 16  Question:\nA 35-year-old woman presents to her...
# 17  Question:\nA 19-year-old woman presents to the...
# 18  Question:\nA 65-year-old man presents with hyp...
# 19  Question:\nA 61-year-old woman comes to the ph...
# 20  Question:\nA 31-year-old woman is brought to t...
# 21  Question:\nA 49-year-old man being treated for...
# 22  Question:\nA 44-year-old woman presents with p...
# 23  Question:\nA 62-year-old man presents with epi...
# 24  Question:\nA 5-year-old girl is brought to the...
# 25  Question:\nA 5-month-old boy is brought to the...
# 26  Question:\nA 45-year-old-man presents to the p...
# 27  Question:\nA 72-year-old man comes to the emer...
# 28  Question:\nA 25-year-old man is admitted to th...
# 29  Question:\nA 61-year-old obese man with recent...
# 30  Question:\nA 25-year-old woman presents to the...
# 31  Question:\nA 61-year-old woman comes to the ph...
# 32  Question:\nA scientist is trying to design a d...
# 33  Question:\nA 67-year-old man comes to the phys...
# 34  Question:\nA 25-year-old man is admitted to th...
# 35  Question:\nA 69-year-old woman comes to the em...
# 36  Question:\nA 71-year-old man develops worsenin...
# 37  Question:\nA 28-year-old man presents with fev...
# 38  Question:\nA 7-year-old boy is brought to the ...
# 39  Question:\nA 75-year-old woman is being treate...
# 40  Question:\nA 59-year-old man comes to the phys...
# 41  Question:\nA 56-year-old man presents to his g...
# 42  Question:\nA 56-year-old woman with rheumatoid...
# 43  Question:\nA 26-year-old immigrant from Mexico...
# 44  Question:\nA 62-year-old man comes to the phys...
# 45  Question:\nA 2-year-old boy is brought to the ...
# 46  Question:\nA 60-year-old woman comes to the ph...
# 47  Question:\nA 26-year-old man undergoing surgic...
# 48  Question:\nA 25-year-old man presents to his p...
# 49  Question:\nA 78-year-old Caucasian male actor ...
#
#                                    perturbed_question
# 0   Question:\nA 31-year-old woman comes to the ph...
# 1   Question:\nAn 18-year-old high school student ...
# 2   Question:\nA typically healthy 27-year-old wom...
# 3   Question:\nA 58-year-old man presents for a fo...
# 4   Question:\nA 24-year-old woman presents to the...
# 5   Question:\nA 56-year-old man comes to the phys...
# 6   Question:\nTwo 19-year-old men are referred by...
# 7   Question:\nA 7-year-old girl presents with a l...
# 8   Question:\nA 26-year-old woman presents to her...
# 9   Question:\nA 35-year-old man presents to his p...
# 10  Question:\nA 77-year-old man presents to the e...
# 11  Question:\nA 56-year-old woman presents with f...
# 12  Question:\nA 29-year-old man comes to the phys...
# 13  Question:\nA 55-year-old man comes to the phys...
# 14  Question:\nA 22-year-old female presents to an...
# 15  Question:\nA 23-year-old Caucasian male presen...
# 16  Question:\nA 35-year-old woman presents to her...
# 17  Question:\nA 19-year-old woman presents to the...
# 18  Question:\nA 65-year-old man presents with hyp...
# 19  Question:\nA 61-year-old woman comes to the ph...
# 20  Question:\nA 31-year-old woman is brought to t...
# 21  Question:\nA 49-year-old man being treated for...
# 22  Question:\nA 44-year-old woman presents with p...
# 23  Question:\nA 62-year-old man presents with epi...
# 24  Question:\nA 5-year-old girl is brought to the...
# 25  Question:\nA 5-month-old boy is brought to the...
# 26  Question:\nA 45-year-old-man presents to the p...
# 27  Question:\nA 72-year-old man comes to the emer...
# 28  Question:\nA 25-year-old man is admitted to th...
# 29  Question:\nA 61-year-old obese man with recent...
# 30  Question:\nA 25-year-old woman presents to the...
# 31  Question:\nA 61-year-old woman comes to the ph...
# 32  Question:\nA scientist is trying to design a d...
# 33  Question:\nA 67-year-old man comes to the phys...
# 34  Question:\nA 25-year-old man is admitted to th...
# 35  Question:\nA 69-year-old woman comes to the em...
# 36  Question:\nA 71-year-old man develops worsenin...
# 37  Question:\nA 28-year-old man presents with fev...
# 38  Question:\nA 7-year-old boy is brought to the ...
# 39  Question:\nA 75-year-old woman is being treate...
# 40  Question:\nA 59-year-old man comes to the phys...
# 41  Question:\nA 56-year-old man presents to his g...
# 42  Question:\nA 56-year-old woman with rheumatoid...
# 43  Question:\nA 26-year-old immigrant from Mexico...
# 44  Question:\nA 62-year-old man comes to the phys...
# 45  Question:\nA 2-year-old boy is brought to the ...
# 46  Question:\nA 60-year-old woman comes to the ph...
# 47  Question:\nA 26-year-old man undergoing surgic...
# 48  Question:\nA 25-year-old man presents to his p...
# 49  Question:\nA 78-year-old Caucasian male actor ...

# %%
harness.run()
# Out:
# Running testcases... : 100%|██████████| 50/50 [00:28<00:00,  1.73it/s]

# %%
df = harness.generated_results()
df
# Out:
#     category              test_type  \
# 0   clinical  drug_generic_to_brand
# 1   clinical  drug_generic_to_brand
# 2   clinical  drug_generic_to_brand
# 3   clinical  drug_generic_to_brand
# 4   clinical  drug_generic_to_brand
# 5   clinical  drug_generic_to_brand
# 6   clinical  drug_generic_to_brand
# 7   clinical  drug_generic_to_brand
# 8   clinical  drug_generic_to_brand
# 9   clinical  drug_generic_to_brand
# 10  clinical  drug_generic_to_brand
# 11  clinical  drug_generic_to_brand
# 12  clinical  drug_generic_to_brand
# 13  clinical  drug_generic_to_brand
# 14  clinical  drug_generic_to_brand
# 15  clinical  drug_generic_to_brand
# 16  clinical  drug_generic_to_brand
# 17  clinical  drug_generic_to_brand
# 18  clinical  drug_generic_to_brand
# 19  clinical  drug_generic_to_brand
# 20  clinical  drug_generic_to_brand
# 21  clinical  drug_generic_to_brand
# 22  clinical  drug_generic_to_brand
# 23  clinical  drug_generic_to_brand
# 24  clinical  drug_generic_to_brand
# 25  clinical  drug_generic_to_brand
# 26  clinical  drug_generic_to_brand
# 27  clinical  drug_generic_to_brand
# 28  clinical  drug_generic_to_brand
# 29  clinical  drug_generic_to_brand
# 30  clinical  drug_generic_to_brand
# 31  clinical  drug_generic_to_brand
# 32  clinical  drug_generic_to_brand
# 33  clinical  drug_generic_to_brand
# 34  clinical  drug_generic_to_brand
# 35  clinical  drug_generic_to_brand
# 36  clinical  drug_generic_to_brand
# 37  clinical  drug_generic_to_brand
# 38  clinical  drug_generic_to_brand
# 39  clinical  drug_generic_to_brand
# 40  clinical  drug_generic_to_brand
# 41  clinical  drug_generic_to_brand
# 42  clinical  drug_generic_to_brand
# 43  clinical  drug_generic_to_brand
# 44  clinical  drug_generic_to_brand
# 45  clinical  drug_generic_to_brand
# 46  clinical  drug_generic_to_brand
# 47  clinical  drug_generic_to_brand
# 48  clinical  drug_generic_to_brand
# 49  clinical  drug_generic_to_brand
#
#                                     original_question  \
# 0   Question:\nA 31-year-old woman comes to the ph...
# 1   Question:\nAn 18-year-old high school student ...
# 2   Question:\nA typically healthy 27-year-old wom...
# 3   Question:\nA 58-year-old man presents for a fo...
# 4   Question:\nA 24-year-old woman presents to the...
# 5   Question:\nA 56-year-old man comes to the phys...
# 6   Question:\nTwo 19-year-old men are referred by...
# 7   Question:\nA 7-year-old girl presents with a l...
# 8   Question:\nA 26-year-old woman presents to her...
# 9   Question:\nA 35-year-old man presents to his p...
# 10  Question:\nA 77-year-old man presents to the e...
# 11  Question:\nA 56-year-old woman presents with f...
# 12  Question:\nA 29-year-old man comes to the phys...
# 13  Question:\nA 55-year-old man comes to the phys...
# 14  Question:\nA 22-year-old female presents to an...
# 15  Question:\nA 23-year-old Caucasian male presen...
# 16  Question:\nA 35-year-old woman presents to her...
# 17  Question:\nA 19-year-old woman presents to the...
# 18  Question:\nA 65-year-old man presents with hyp...
# 19  Question:\nA 61-year-old woman comes to the ph...
# 20  Question:\nA 31-year-old woman is brought to t...
# 21  Question:\nA 49-year-old man being treated for...
# 22  Question:\nA 44-year-old woman presents with p...
# 23  Question:\nA 62-year-old man presents with epi...
# 24  Question:\nA 5-year-old girl is brought to the...
# 25  Question:\nA 5-month-old boy is brought to the...
# 26  Question:\nA 45-year-old-man presents to the p...
# 27  Question:\nA 72-year-old man comes to the emer...
# 28  Question:\nA 25-year-old man is admitted to th...
# 29  Question:\nA 61-year-old obese man with recent...
# 30  Question:\nA 25-year-old woman presents to the...
# 31  Question:\nA 61-year-old woman comes to the ph...
# 32  Question:\nA scientist is trying to design a d...
# 33  Question:\nA 67-year-old man comes to the phys...
# 34  Question:\nA 25-year-old man is admitted to th...
# 35  Question:\nA 69-year-old woman comes to the em...
# 36  Question:\nA 71-year-old man develops worsenin...
# 37  Question:\nA 28-year-old man presents with fev...
# 38  Question:\nA 7-year-old boy is brought to the ...
# 39  Question:\nA 75-year-old woman is being treate...
# 40  Question:\nA 59-year-old man comes to the phys...
# 41  Question:\nA 56-year-old man presents to his g...
# 42  Question:\nA 56-year-old woman with rheumatoid...
# 43  Question:\nA 26-year-old immigrant from Mexico...
# 44  Question:\nA 62-year-old man comes to the phys...
# 45  Question:\nA 2-year-old boy is brought to the ...
# 46  Question:\nA 60-year-old woman comes to the ph...
# 47  Question:\nA 26-year-old man undergoing surgic...
# 48  Question:\nA 25-year-old man presents to his p...
# 49  Question:\nA 78-year-old Caucasian male actor ...
#
#                                    perturbed_question expected_result  \
# 0   Question:\nA 31-year-old woman comes to the ph...               B
# 1   Question:\nAn 18-year-old high school student ...               C
# 2   Question:\nA typically healthy 27-year-old wom...               D
# 3   Question:\nA 58-year-old man presents for a fo...               B
# 4   Question:\nA 24-year-old woman presents to the...               D
# 5   Question:\nA 56-year-old man comes to the phys...               D
# 6   Question:\nTwo 19-year-old men are referred by...               B
# 7   Question:\nA 7-year-old girl presents with a l...               D
# 8   Question:\nA 26-year-old woman presents to her...               A
# 9   Question:\nA 35-year-old man presents to his p...               B
# 10  Question:\nA 77-year-old man presents to the e...               B
# 11  Question:\nA 56-year-old woman presents with f...               B
# 12  Question:\nA 29-year-old man comes to the phys...               A
# 13  Question:\nA 55-year-old man comes to the phys...               D
# 14  Question:\nA 22-year-old female presents to an...               A
# 15  Question:\nA 23-year-old Caucasian male presen...               B
# 16  Question:\nA 35-year-old woman presents to her...               A
# 17  Question:\nA 19-year-old woman presents to the...               B
# 18  Question:\nA 65-year-old man presents with hyp...               D
# 19  Question:\nA 61-year-old woman comes to the ph...               C
# 20  Question:\nA 31-year-old woman is brought to t...               A
# 21  Question:\nA 49-year-old man being treated for...               D
# 22  Question:\nA 44-year-old woman presents with p...               A
# 23  Question:\nA 62-year-old man presents with epi...               C
# 24  Question:\nA 5-year-old girl is brought to the...               B
# 25  Question:\nA 5-month-old boy is brought to the...               C
# 26  Question:\nA 45-year-old-man presents to the p...               A
# 27  Question:\nA 72-year-old man comes to the emer...               A
# 28  Question:\nA 25-year-old man is admitted to th...               C
# 29  Question:\nA 61-year-old obese man with recent...               C
# 30  Question:\nA 25-year-old woman presents to the...               B
# 31  Question:\nA 61-year-old woman comes to the ph...               C
# 32  Question:\nA scientist is trying to design a d...               C
# 33  Question:\nA 67-year-old man comes to the phys...               D
# 34  Question:\nA 25-year-old man is admitted to th...               C
# 35  Question:\nA 69-year-old woman comes to the em...               B
# 36  Question:\nA 71-year-old man develops worsenin...               B
# 37  Question:\nA 28-year-old man presents with fev...               B
# 38  Question:\nA 7-year-old boy is brought to the ...               D
# 39  Question:\nA 75-year-old woman is being treate...               A
# 40  Question:\nA 59-year-old man comes to the phys...               C
# 41  Question:\nA 56-year-old man presents to his g...               D
# 42  Question:\nA 56-year-old woman with rheumatoid...               C
# 43  Question:\nA 26-year-old immigrant from Mexico...               D
# 44  Question:\nA 62-year-old man comes to the phys...               B
# 45  Question:\nA 2-year-old boy is brought to the ...               A
# 46  Question:\nA 60-year-old woman comes to the ph...               B
# 47  Question:\nA 26-year-old man undergoing surgic...               A
# 48  Question:\nA 25-year-old man presents to his p...               C
# 49  Question:\nA 78-year-old Caucasian male actor ...               B
#
#    actual_result   pass
# 0              C  False
# 1              C   True
# 2              B  False
# 3              D  False
# 4              A  False
# 5              A  False
# 6              C  False
# 7              C  False
# 8              B  False
# 9              B   True
# 10             B   True
# 11             B   True
# 12             D  False
# 13             D   True
# 14             A   True
# 15             A  False
# 16             A   True
# 17             A  False
# 18             D   True
# 19             A  False
# 20             C  False
# 21             D   True
# 22             A   True
# 23             C   True
# 24             B   True
# 25             A  False
# 26             D  False
# 27             D  False
# 28             D  False
# 29             A  False
# 30             C  False
# 31             A  False
# 32             D  False
# 33             D   True
# 34             D  False
# 35             B   True
# 36             B   True
# 37             B   True
# 38             D   True
# 39             B  False
# 40             D  False
# 41             C  False
# 42             A  False
# 43             C  False
# 44             A  False
# 45             D  False
# 46             C  False
# 47             B  False
# 48             A  False
# 49             B   True

# %%
harness.report()
# Out:
#    category              test_type  fail_count  pass_count pass_rate  \
# 0  clinical  drug_generic_to_brand          32          18       36%
#
#   minimum_pass_rate   pass
# 0               80%  False

# %%
# check the first failing row
row1 = df[df['pass'] == False].iloc[0]

# text wrap 
import textwrap

for col, each in row1.items():
    if col in ['pass', 'category', 'test_type']:
        continue
    print(f"{col.title()}:\n{textwrap.fill(each, width=100)}\n")
# Out:
# Original_Question:
# Question: A 31-year-old woman comes to the physician because of intermittent episodes of stabbing
# right lower jaw pain for 6 weeks. The pain is severe, sharp, and lasts for a few seconds. These
# episodes commonly occur when she washes her face, brushes her teeth, or eats a meal. She does not
# have visual disturbances, weakness of her facial muscles, or hearing loss. Five weeks ago, she had
# an episode of acute bacterial sinusitis, which was treated with antibiotics. Which of the following
# is the most appropriate initial treatment for this patient's condition? Options: A: Amoxicillin B:
# Carbamazepine C: Valacyclovir D: Doxepin
#
# Perturbed_Question:
# Question: A 31-year-old woman comes to the physician because of intermittent episodes of stabbing
# right lower jaw pain for 6 weeks. The pain is severe, sharp, and lasts for a few seconds. These
# episodes commonly occur when she washes her face, brushes her teeth, or eats a meal. She does not
# have visual disturbances, weakness of her facial muscles, or hearing loss. Five weeks ago, she had
# an episode of acute bacterial sinusitis, which was treated with antibiotics. Which of the following
# is the most appropriate initial treatment for this patient's condition? Options: A: Amoxicillin B:
# epimaz C: Valacyclovir D: zonalon
#
# Expected_Result:
# B
#
# Actual_Result:
# C
