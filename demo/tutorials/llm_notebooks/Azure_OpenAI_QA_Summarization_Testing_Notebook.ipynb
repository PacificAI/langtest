# %% [markdown]
# ![logog](https://raw.githubusercontent.com/Pacific-AI-Corp/langtest/main/docs/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Pacific-AI-Corp/langtest/blob/main/demo/tutorials/llm_notebooks/Azure_OpenAI_QA_Summarization_Testing_Notebook.ipynb)

# %% [markdown]
# **LangTest** is an open-source python library designed to help developers deliver safe and effective Natural Language Processing (NLP) models. Whether you are using **John Snow Labs, Hugging Face, Spacy** models or **OpenAI, Cohere, AI21, Hugging Face Inference API and Azure-OpenAI** based LLMs, it has got you covered. You can test any Named Entity Recognition (NER), Text Classification, fill-mask, Translation model using the library. We also support testing LLMS for Question-Answering, Summarization and text-generation tasks on benchmark datasets. The library supports 60+ out of the box tests. For a complete list of supported test categories, please refer to the [documentation](http://langtest.org/docs/pages/docs/test_categories).
#
# Metrics are calculated by comparing the model's extractions in the original list of sentences against the extractions carried out in the noisy list of sentences. The original annotated labels are not used at any point, we are simply comparing the model against itself in a 2 settings.

# %% [markdown]
# # Getting started with LangTest

# %%
# !pip install "langtest[evaluate,openai,transformers]"

# %% [markdown]
# # Harness and Its Parameters
#
# The Harness class is a testing class for Natural Language Processing (NLP) models. It evaluates the performance of a NLP model on a given task using test data and generates a report with test results.Harness can be imported from the LangTest library in the following way.

# %%
#Import Harness from the LangTest library
from langtest import Harness

# %% [markdown]
# It imports the Harness class from within the module, that is designed to provide a blueprint or framework for conducting NLP testing, and that instances of the Harness class can be customized or configured for different testing scenarios or environments.
#
# Here is a list of the different parameters that can be passed to the Harness function:
#
# <br/>
#
#
# | Parameter  | Description |
# | - | - |
# |**task**     |Task for which the model is to be evaluated (question-answering or summarization)|
# | **model**     | Specifies the model(s) to be evaluated. This parameter can be provided as either a dictionary or a list of dictionaries. Each dictionary should contain the following keys: <ul><li>model (mandatory): 	PipelineModel or path to a saved model or pretrained pipeline/model from hub.</li><li>hub (mandatory): Hub (library) to use in back-end for loading model from public models hub or from path</li></ul>|
# | **data**      | The data to be used for evaluation. A dictionary providing flexibility and options for data sources. It should include the following keys: <ul><li>data_source (mandatory): The source of the data.</li><li>subset (optional): The subset of the data.</li><li>feature_column (optional): The column containing the features.</li><li>target_column (optional): The column containing the target labels.</li><li>split (optional): The data split to be used.</li><li>source (optional): Set to 'huggingface' when loading Hugging Face dataset.</li></ul> |
# | **config**    | Configuration for the tests to be performed, specified in the form of a YAML file. |
#
# <br/>
# <br/>

# %% [markdown]
# # Azure OpenAI Model Testing For Question Answering
#
# In this section, we dive into testing of Azure OpenAI models in Question Answering task.
#
# LangTest supports robustness tests for LLM testing for now.

# %% [markdown]
# ### Set environment for Azure OpenAI

# %%
import os
import openai

os.environ["OPENAI_API_KEY"] = "<API_KEY>"
openai.api_type = "azure"
openai.api_base = "<ENDPOINT>"
openai.api_version = "2022-12-01"
openai.api_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## BoolQ-test-tiny dataset testing

# %% [markdown]
# ### Setup and Configure Harness

# %%
harness = Harness(
                  task="question-answering", 
                  model={"model": "gpt-3.5-turbo-instruct","hub":"azure-openai"}, 
                  data={"data_source" :"BoolQ",
                        "split":"test-tiny"}
                  )

# %% [markdown]
# We have specified task as QA, hub as OpenAI and model as gpt-3.5-turbo-instruct, text-davinci-002 whatever model available from azure openai services.
#
# For dataset we used `BoolQ` dataset and `test-tiny` split which includes 50 samples. Other available datasets are: [Benchmark Datasets](https://langtest.org/docs/pages/docs/data#question-answering)

# %% [markdown]
# For tests we used lowercase and uppercase. Other available robustness tests for QA task are:
# * `add_context`
# * `add_contraction`
# * `add_punctuation`
# * `add_typo`
# * `add_ocr_typo`
# * `american_to_british`
# * `british_to_american`
# * `lowercase`
# * `strip_punctuation`
# * `titlecase`
# * `uppercase`
# * `number_to_word`
# * `add_abbreviation`
# * `add_speech_to_text_typo`
# * `add_slangs`
# * `dyslexia_word_swap`
# * `multiple_perturbations`
# * `adjective_synonym_swap`
# * `adjective_antonym_swap`
# * `strip_all_punctuation`

# %% [markdown]
# Available Bias tests for QA task are:
#
# * `replace_to_male_pronouns`
# * `replace_to_female_pronouns`
# * `replace_to_neutral_pronouns`
# * `replace_to_high_income_country`
# * `replace_to_low_income_country`
# * `replace_to_upper_middle_income_country`
# * `replace_to_lower_middle_income_country`
# * `replace_to_white_firstnames`
# * `replace_to_black_firstnames`
# * `replace_to_hispanic_firstnames`
# * `replace_to_asian_firstnames`
# * `replace_to_white_lastnames`
# * `replace_to_sikh_names`
# * `replace_to_christian_names`
# * `replace_to_hindu_names`
# * `replace_to_muslim_names`
# * `replace_to_inter_racial_lastnames`
# * `replace_to_native_american_lastnames`
# * `replace_to_asian_lastnames`
# * `replace_to_hispanic_lastnames`
# * `replace_to_black_lastnames`
# * `replace_to_parsi_names`
# * `replace_to_jain_names`
# * `replace_to_buddhist_names`
#
# Available Representation tests for QA task are:
#
# * `min_gender_representation_count`
# * `min_ethnicity_name_representation_count`
# * `min_religion_name_representation_count`
# * `min_country_economic_representation_count`
# * `min_gender_representation_proportion`
# * `min_ethnicity_name_representation_proportion`
# * `min_religion_name_representation_proportion`
# * `min_country_economic_representation_proportion`
#
#
# Available Accuracy tests for QA task are:
#
# * `min_exact_match_score`
# * `min_bleu_score`
# * `min_rouge1_score`
# * `min_rouge2_score`
# * `min_rougeL_score`
# * `min_rougeLsum_score`
#
#
# Available Fairness tests for QA task are:
#
# * `max_gender_rouge1_score`
# * `max_gender_rouge2_score`
# * `max_gender_rougeL_score`
# * `max_gender_rougeLsum_score`
# * `min_gender_rouge1_score`
# * `min_gender_rouge2_score`
# * `min_gender_rougeL_score`
# * `min_gender_rougeLsum_score`

# %% [markdown]
# You can also set prompts and other model parameters in config. Possible parameters are:
# * `user_promt:` Promt to be given to the model.
# * `temperature:` Temperature of the model.
# * `max_tokens:` Maximum number of output tokens allowed for model.

# %%
harness.configure({
    'model_parameters': {
        'deployment_name': '<DEPLOYMENT_NAME>',
        'max_tokens': 512
    },
    
    'tests': {
      'defaults':{
        'min_pass_rate': 1.00
      },

      'robustness':{
        'lowercase': {'min_pass_rate': 0.70},
        'uppercase': {'min_pass_rate': 0.70}
      }
    }
})
# Out:
# {'model_parameters': {'deployment_name': '<DEPLOYMENT_NAME>',
#   'max_tokens': 512},
#  'tests': {'defaults': {'min_pass_rate': 1.0},
#   'robustness': {'lowercase': {'min_pass_rate': 0.7},
#    'uppercase': {'min_pass_rate': 0.7}}}}

# %% [markdown]
# Here we have configured the harness to perform two robustness tests (uppercase and lowercase) and defined the minimum pass rate for each test.

# %% [markdown]
# ➤ You can adjust the level of transformation in the sentence by using the "`prob`" parameter, which controls the proportion of words to be changed during robustness tests.
#
# ➤ **NOTE** : "`prob`" defaults to 1.0, which means all words will be transformed.
# ```
# harness.configure(
# {
#  'tests': {
#     'defaults': {'min_pass_rate': 0.65},
#       'robustness': {
#         'lowercase': {'min_pass_rate': 0.66, 'prob': 0.50},
#         'uppercase':{'min_pass_rate': 0.60, 'prob': 0.70},
#       }
#   }
# })
#
# ```

# %% [markdown]
# ### Generating the test cases.

# %%
harness.generate()
# Out:
# Generating testcases...: 100%|██████████| 2/2 [00:00<?, ?it/s]

# %% [markdown]
# harness.generate() method automatically generates the test cases (based on the provided configuration)

# %%
harness.testcases()
# Out:
#       category  test_type                                  original_question  \
# 0   robustness  lowercase  is the first series 20 euro note still legal t...
# 1   robustness  lowercase  do the champions league winners get automatic ...
# 2   robustness  lowercase                  can a bull snake kill a small dog
# 3   robustness  lowercase                are all nba playoff games best of 7
# 4   robustness  lowercase  can i use my train ticket on the tram in manch...
# ..         ...        ...                                                ...
# 95  robustness  uppercase              is puerto a part of the united states
# 96  robustness  uppercase            is devil's knot based on west memphis 3
# 97  robustness  uppercase  are any of the original temptations still in t...
# 98  robustness  uppercase             is the isle of wight part of hampshire
# 99  robustness  uppercase  is there a body in the tomb of the unknown sol...
#
#                                      original_context  \
# 0   20 euro note -- Until now there has been only ...
# 1   2018–19 UEFA Champions League -- The final wil...
# 2   Bullsnake -- Bullsnakes are very powerful cons...
# 3   NBA playoffs -- All rounds are best-of-seven s...
# 4   Manchester station group -- The Manchester sta...
# ..                                                ...
# 95  Puerto Rico -- Puerto Rico (Spanish for ``Rich...
# 96  West Memphis Three -- There have been a number...
# 97  The Temptations -- As of 2017, the Temptations...
# 98  Isle of Wight -- The Isle of Wight (/waɪt/; al...
# 99  Tomb of the Unknown Soldier (Arlington) -- On ...
#
#                                    perturbed_question  \
# 0   is the first series 20 euro note still legal t...
# 1   do the champions league winners get automatic ...
# 2                   can a bull snake kill a small dog
# 3                 are all nba playoff games best of 7
# 4   can i use my train ticket on the tram in manch...
# ..                                                ...
# 95              IS PUERTO A PART OF THE UNITED STATES
# 96            IS DEVIL'S KNOT BASED ON WEST MEMPHIS 3
# 97  ARE ANY OF THE ORIGINAL TEMPTATIONS STILL IN T...
# 98             IS THE ISLE OF WIGHT PART OF HAMPSHIRE
# 99  IS THERE A BODY IN THE TOMB OF THE UNKNOWN SOL...
#
#                                     perturbed_context
# 0   20 euro note -- until now there has been only ...
# 1   2018–19 uefa champions league -- the final wil...
# 2   bullsnake -- bullsnakes are very powerful cons...
# 3   nba playoffs -- all rounds are best-of-seven s...
# 4   manchester station group -- the manchester sta...
# ..                                                ...
# 95  PUERTO RICO -- PUERTO RICO (SPANISH FOR ``RICH...
# 96  WEST MEMPHIS THREE -- THERE HAVE BEEN A NUMBER...
# 97  THE TEMPTATIONS -- AS OF 2017, THE TEMPTATIONS...
# 98  ISLE OF WIGHT -- THE ISLE OF WIGHT (/WAꞮT/; AL...
# 99  TOMB OF THE UNKNOWN SOLDIER (ARLINGTON) -- ON ...
#
# [100 rows x 6 columns]

# %% [markdown]
# harness.testcases() method displays the produced test cases in form of a pandas data frame.

# %% [markdown]
# ### Running the tests

# %%
harness.run()
# Out:
# Running testcases... : 100%|██████████| 100/100 [02:19<00:00,  1.39s/it]

# %% [markdown]
# Called after harness.generate() and is to used to run all the tests.  Returns a pass/fail flag for each test.

# %%
harness.generated_results()
# Out:
#       category  test_type                                  original_question  \
# 0   robustness  lowercase  is the first series 20 euro note still legal t...
# 1   robustness  lowercase  do the champions league winners get automatic ...
# 2   robustness  lowercase                  can a bull snake kill a small dog
# 3   robustness  lowercase                are all nba playoff games best of 7
# 4   robustness  lowercase  can i use my train ticket on the tram in manch...
# ..         ...        ...                                                ...
# 95  robustness  uppercase              is puerto a part of the united states
# 96  robustness  uppercase            is devil's knot based on west memphis 3
# 97  robustness  uppercase  are any of the original temptations still in t...
# 98  robustness  uppercase             is the isle of wight part of hampshire
# 99  robustness  uppercase  is there a body in the tomb of the unknown sol...
#
#                                      original_context  \
# 0   20 euro note -- Until now there has been only ...
# 1   2018–19 UEFA Champions League -- The final wil...
# 2   Bullsnake -- Bullsnakes are very powerful cons...
# 3   NBA playoffs -- All rounds are best-of-seven s...
# 4   Manchester station group -- The Manchester sta...
# ..                                                ...
# 95  Puerto Rico -- Puerto Rico (Spanish for ``Rich...
# 96  West Memphis Three -- There have been a number...
# 97  The Temptations -- As of 2017, the Temptations...
# 98  Isle of Wight -- The Isle of Wight (/waɪt/; al...
# 99  Tomb of the Unknown Soldier (Arlington) -- On ...
#
#                                    perturbed_question  \
# 0   is the first series 20 euro note still legal t...
# 1   do the champions league winners get automatic ...
# 2                   can a bull snake kill a small dog
# 3                 are all nba playoff games best of 7
# 4   can i use my train ticket on the tram in manch...
# ..                                                ...
# 95              IS PUERTO A PART OF THE UNITED STATES
# 96            IS DEVIL'S KNOT BASED ON WEST MEMPHIS 3
# 97  ARE ANY OF THE ORIGINAL TEMPTATIONS STILL IN T...
# 98             IS THE ISLE OF WIGHT PART OF HAMPSHIRE
# 99  IS THERE A BODY IN THE TOMB OF THE UNKNOWN SOL...
#
#                                     perturbed_context   expected_result  \
# 0   20 euro note -- until now there has been only ...         \n\nFalse
# 1   2018–19 uefa champions league -- the final wil...  \n\nAnswer: True
# 2   bullsnake -- bullsnakes are very powerful cons...         \n\nFalse
# 3   nba playoffs -- all rounds are best-of-seven s...         \n\nFalse
# 4   manchester station group -- the manchester sta...         \n\nFalse
# ..                                                ...               ...
# 95  PUERTO RICO -- PUERTO RICO (SPANISH FOR ``RICH...         \n\nFalse
# 96  WEST MEMPHIS THREE -- THERE HAVE BEEN A NUMBER...         \n\nFalse
# 97  THE TEMPTATIONS -- AS OF 2017, THE TEMPTATIONS...         \n\nFalse
# 98  ISLE OF WIGHT -- THE ISLE OF WIGHT (/WAꞮT/; AL...         \n\nFalse
# 99  TOMB OF THE UNKNOWN SOLDIER (ARLINGTON) -- ON ...         \n\nFalse
#
#        actual_result   pass
# 0          \n\nFalse   True
# 1   \n\nAnswer: True   True
# 2          \n\nFalse   True
# 3          \n\nFalse   True
# 4          \n\nFalse   True
# ..               ...    ...
# 95  \n\nAnswer: True  False
# 96         \n\nFalse   True
# 97         \n\nFalse   True
# 98         \n\nFalse   True
# 99         \n\nFalse   True
#
# [100 rows x 9 columns]

# %% [markdown]
# This method returns the generated results in the form of a pandas dataframe, which provides a convenient and easy-to-use format for working with the test results. You can use this method to quickly identify the test cases that failed and to determine where fixes are needed.

# %% [markdown]
# ### Final Results

# %% [markdown]
# We can call `.report()` which summarizes the results giving information about pass and fail counts and overall test pass/fail flag.

# %%
harness.report()
# Out:
#      category  test_type  fail_count  pass_count pass_rate minimum_pass_rate  \
# 0  robustness  lowercase           5          45       90%               70%
# 1  robustness  uppercase           6          44       88%               70%
#
#    pass
# 0  True
# 1  True

# %% [markdown]
# ## NQ-open-test dataset testing

# %% [markdown]
# We can also use another dataset, NQ-open for testing the model.

# %%
harness = Harness(
                  task="question-answering", 
                  model={"model": "gpt-3.5-turbo-instruct","hub":"azure-openai"}, 
                  data={"data_source" :"NQ-open",
                        "split":"test-tiny"}
                  )

# %%
harness.configure({
    'model_parameters': {
        'deployment_name': '<YOUR_DEPLOYMENT_NAME>',
        'max_tokens': 512
    },
    'tests': {
      'defaults':{
        'min_pass_rate': 1.00
      },

      'robustness':{
        'lowercase': {'min_pass_rate': 0.70},
        'uppercase': {'min_pass_rate': 0.70}
      }
    }
})
# Out:
# {'model_parameters': {'deployment_name': '<YOUR_DEPLOYMENT_NAME>',
#   'max_tokens': 512},
#  'tests': {'defaults': {'min_pass_rate': 1.0},
#   'robustness': {'lowercase': {'min_pass_rate': 0.7},
#    'uppercase': {'min_pass_rate': 0.7}}}}

# %%
harness.generate()
# Out:
# Generating testcases...: 100%|██████████| 2/2 [00:00<?, ?it/s]

# %%
harness.testcases()
# Out:
#       category  test_type                                  original_question  \
# 0   robustness  lowercase  on the 6th day of christmas my true love sent ...
# 1   robustness  lowercase       how many 5 star generals are there in the us
# 2   robustness  lowercase        who killed natalie and ann in sharp objects
# 3   robustness  lowercase      how many costco locations are there in the us
# 4   robustness  lowercase          who played grand moff tarkin in rogue one
# ..         ...        ...                                                ...
# 95  robustness  uppercase          who has the most followers on the twitter
# 96  robustness  uppercase  who said it's not what your country can do for...
# 97  robustness  uppercase            when does lil wayne new album drop 2018
# 98  robustness  uppercase  the khajuraho temples are especially well know...
# 99  robustness  uppercase  when does the regular nba basketball season start
#
#    original_context                                 perturbed_question  \
# 0                 -  on the 6th day of christmas my true love sent ...
# 1                 -       how many 5 star generals are there in the us
# 2                 -        who killed natalie and ann in sharp objects
# 3                 -      how many costco locations are there in the us
# 4                 -          who played grand moff tarkin in rogue one
# ..              ...                                                ...
# 95                -          WHO HAS THE MOST FOLLOWERS ON THE TWITTER
# 96                -  WHO SAID IT'S NOT WHAT YOUR COUNTRY CAN DO FOR...
# 97                -            WHEN DOES LIL WAYNE NEW ALBUM DROP 2018
# 98                -  THE KHAJURAHO TEMPLES ARE ESPECIALLY WELL KNOW...
# 99                -  WHEN DOES THE REGULAR NBA BASKETBALL SEASON START
#
#    perturbed_context
# 0                  -
# 1                  -
# 2                  -
# 3                  -
# 4                  -
# ..               ...
# 95                 -
# 96                 -
# 97                 -
# 98                 -
# 99                 -
#
# [100 rows x 6 columns]

# %%
harness.run()
# Out:
# Running testcases... : 100%|██████████| 100/100 [04:33<00:00,  2.73s/it]

# %%
harness.generated_results()
# Out:
#       category  test_type                                  original_question  \
# 0   robustness  lowercase  on the 6th day of christmas my true love sent ...
# 1   robustness  lowercase       how many 5 star generals are there in the us
# 2   robustness  lowercase        who killed natalie and ann in sharp objects
# 3   robustness  lowercase      how many costco locations are there in the us
# 4   robustness  lowercase          who played grand moff tarkin in rogue one
# ..         ...        ...                                                ...
# 95  robustness  uppercase          who has the most followers on the twitter
# 96  robustness  uppercase  who said it's not what your country can do for...
# 97  robustness  uppercase            when does lil wayne new album drop 2018
# 98  robustness  uppercase  the khajuraho temples are especially well know...
# 99  robustness  uppercase  when does the regular nba basketball season start
#
#    original_context                                 perturbed_question  \
# 0                 -  on the 6th day of christmas my true love sent ...
# 1                 -       how many 5 star generals are there in the us
# 2                 -        who killed natalie and ann in sharp objects
# 3                 -      how many costco locations are there in the us
# 4                 -          who played grand moff tarkin in rogue one
# ..              ...                                                ...
# 95                -          WHO HAS THE MOST FOLLOWERS ON THE TWITTER
# 96                -  WHO SAID IT'S NOT WHAT YOUR COUNTRY CAN DO FOR...
# 97                -            WHEN DOES LIL WAYNE NEW ALBUM DROP 2018
# 98                -  THE KHAJURAHO TEMPLES ARE ESPECIALLY WELL KNOW...
# 99                -  WHEN DOES THE REGULAR NBA BASKETBALL SEASON START
#
#    perturbed_context                                    expected_result  \
# 0                  -                              \nSix geese a-laying.
# 1                  -  \n\nThere are currently nine 5-star generals i...
# 2                  -  \n\nAdora Crellin killed Natalie and Ann in Sh...
# 3                  -  \n\nThere are currently 785 Costco locations i...
# 4                  -  \n\nPeter Cushing played Grand Moff Tarkin in ...
# ..               ...                                                ...
# 95                 -  \n\nThe most followed person on Twitter is sin...
# 96                 -  \n\nJohn F. Kennedy said, "Ask not what your c...
# 97                 -  \n\nLil Wayne's new album, "Tha Carter V," is ...
# 98                 -  \n\nThe Khajuraho Temples are especially well ...
# 99                 -  \n\nThe regular NBA basketball season typicall...
#
#                                         actual_result  pass
# 0                               \nSix geese a-laying.  True
# 1   \n\nThere are currently nine 5-star generals i...  True
# 2   \n\nAdora Crellin killed Natalie and Ann in Sh...  True
# 3   \n\nThere are currently 785 Costco locations i...  True
# 4   \n\nPeter Cushing played Grand Moff Tarkin in ...  True
# ..                                                ...   ...
# 95  \n\nThe most followed person on Twitter is cur...  True
# 96                                \n\nJohn F. Kennedy  True
# 97  \n\nLil Wayne's new album, "Tha Carter V," is ...  True
# 98  \n\nThe Khajuraho Temples are especially well ...  True
# 99  \n\nThe regular NBA basketball season typicall...  True
#
# [100 rows x 9 columns]

# %%
harness.report()
# Out:
#      category  test_type  fail_count  pass_count pass_rate minimum_pass_rate  \
# 0  robustness  lowercase           1          49       98%               70%
# 1  robustness  uppercase           3          47       94%               70%
#
#    pass
# 0  True
# 1  True

# %% [markdown]
# # Azure OpenAI Model Testing For Summarization
#
# In this section, we dive into testing of Azure OpenAI models in Summarization task.
#
# LangTest supports robustness tests for LLM testing for now.

# %% [markdown]
# ## XSum-test-tiny dataset testing

# %% [markdown]
# ### Setup and configure harness

# %%
harness = Harness(
                  task="summarization", 
                  model={"model": "gpt-3.5-turbo-instruct","hub":"azure-openai"}, 
                  data={"data_source" :"XSum",
                        "split":"test-tiny"}
                  )

# %% [markdown]
# We have specified task as Summarization, hub as Azure-OpenAI and model as gpt-3.5-turbo-instruct, text-davinci-002 whatever model available from azure openai services.
#
#
# For dataset we used `XSum` dataset and `test-tiny` split which includes 50 samples. Other available datasets are: [Benchmark Datasets](https://langtest.org/docs/pages/docs/data#summarization)

# %% [markdown]
# For tests we used lowercase and uppercase. Other available robustness tests for summarization task are:
#
# * `add_context`
# * `add_contraction`
# * `add_punctuation`
# * `add_typo`
# * `add_ocr_typo`
# * `american_to_british`
# * `british_to_american`
# * `lowercase`
# * `strip_punctuation`
# * `titlecase`
# * `uppercase`
# * `number_to_word`
# * `add_abbreviation`
# * `add_speech_to_text_typo`
# * `add_slang_typo`
# * `dyslexia_word_swap`
# * `multiple_perturbations`
# * `adjective_synonym_swap`
# * `adjective_antonym_swap`
# * `strip_all_punctuation`
#
# Available Bias tests for summarization task are:
#
# * `replace_to_male_pronouns`
# * `replace_to_female_pronouns`
# * `replace_to_neutral_pronouns`
# * `replace_to_high_income_country`
# * `replace_to_low_income_country`
# * `replace_to_upper_middle_income_country`
# * `replace_to_lower_middle_income_country`
# * `replace_to_white_firstnames`
# * `replace_to_black_firstnames`
# * `replace_to_hispanic_firstnames`
# * `replace_to_asian_firstnames`
# * `replace_to_white_lastnames`
# * `replace_to_sikh_names`
# * `replace_to_christian_names`
# * `replace_to_hindu_names`
# * `replace_to_muslim_names`
# * `replace_to_inter_racial_lastnames`
# * `replace_to_native_american_lastnames`
# * `replace_to_asian_lastnames`
# * `replace_to_hispanic_lastnames`
# * `replace_to_black_lastnames`
# * `replace_to_parsi_names`
# * `replace_to_jain_names`
# * `replace_to_buddhist_names`
#
# Available Representation tests for summarization task are:
#
# * `min_gender_representation_count`
# * `min_ethnicity_name_representation_count`
# * `min_religion_name_representation_count`
# * `min_country_economic_representation_count`
# * `min_gender_representation_proportion`
# * `min_ethnicity_name_representation_proportion`
# * `min_religion_name_representation_proportion`
# * `min_country_economic_representation_proportion`
#
#
# Available Accuracy tests for summarization task are:
#
# * `min_exact_match_score`
# * `min_bleu_score`
# * `min_rouge1_score`
# * `min_rouge2_score`
# * `min_rougeL_score`
# * `min_rougeLsum_score`
#
#
# Available Fairness tests for summarization task are:
#
# * `max_gender_rouge1_score`
# * `max_gender_rouge2_score`
# * `max_gender_rougeL_score`
# * `max_gender_rougeLsum_score`
# * `min_gender_rouge1_score`
# * `min_gender_rouge2_score`
# * `min_gender_rougeL_score`
# * `min_gender_rougeLsum_score`

# %%
harness.configure(
{
 'tests': {'defaults': {'min_pass_rate': 0.65},
           'robustness': {'uppercase': {'min_pass_rate': 0.66}, 
                          'lowercase':{'min_pass_rate': 0.60},
                        }
          }
 }
 )
# Out:
# {'tests': {'defaults': {'min_pass_rate': 0.65},
#   'robustness': {'uppercase': {'min_pass_rate': 0.66},
#    'lowercase': {'min_pass_rate': 0.6}}}}

# %% [markdown]
# `Here we have configured the harness to perform two robustness tests (uppercase and lowercase) and defined the minimum pass rate for each test.`

# %% [markdown]
# ### Generating the Test Cases

# %%
harness.generate()
# Out:
# Generating testcases...: 100%|██████████| 1/1 [00:00<?, ?it/s]

# %%
harness.testcases()
# Out:
#       category  test_type                                           original
# 0   robustness  uppercase  The ex-Reading defender denied fraudulent trad...  \
# 1   robustness  uppercase  Voges was forced to retire hurt on 86 after su...
# 2   robustness  uppercase  Seven photographs taken in the Norfolk country...
# 3   robustness  uppercase  Chris Poole - known as "moot" online - created...
# 4   robustness  uppercase  Four police officers were injured in the incid...
# 5   robustness  uppercase  The injured pedestrian - a young man - is thou...
# 6   robustness  uppercase  Barca will be investigated for alleged misappr...
# 7   robustness  uppercase  The think tank said the city's 1,536 schools n...
# 8   robustness  uppercase  His 110 means he has scored 323 runs in a week...
# 9   robustness  uppercase  Ms Kendall told the BBC Labour risked sending ...
# 10  robustness  uppercase  The Association of School and College Leaders ...
# 11  robustness  uppercase  Media playback is unsupported on your device\n...
# 12  robustness  uppercase  Ann Barnes dealt with an "ill-advised" TV docu...
# 13  robustness  uppercase  The man grabbed hold of a child's bag outside ...
# 14  robustness  uppercase  Taylor, 25, joined County in May from Macclesf...
# 15  robustness  lowercase  The ex-Reading defender denied fraudulent trad...
# 16  robustness  lowercase  Voges was forced to retire hurt on 86 after su...
# 17  robustness  lowercase  Seven photographs taken in the Norfolk country...
# 18  robustness  lowercase  Chris Poole - known as "moot" online - created...
# 19  robustness  lowercase  Four police officers were injured in the incid...
# 20  robustness  lowercase  The injured pedestrian - a young man - is thou...
# 21  robustness  lowercase  Barca will be investigated for alleged misappr...
# 22  robustness  lowercase  The think tank said the city's 1,536 schools n...
# 23  robustness  lowercase  His 110 means he has scored 323 runs in a week...
# 24  robustness  lowercase  Ms Kendall told the BBC Labour risked sending ...
# 25  robustness  lowercase  The Association of School and College Leaders ...
# 26  robustness  lowercase  Media playback is unsupported on your device\n...
# 27  robustness  lowercase  Ann Barnes dealt with an "ill-advised" TV docu...
# 28  robustness  lowercase  The man grabbed hold of a child's bag outside ...
# 29  robustness  lowercase  Taylor, 25, joined County in May from Macclesf...
#
#                                             test_case
# 0   THE EX-READING DEFENDER DENIED FRAUDULENT TRAD...
# 1   VOGES WAS FORCED TO RETIRE HURT ON 86 AFTER SU...
# 2   SEVEN PHOTOGRAPHS TAKEN IN THE NORFOLK COUNTRY...
# 3   CHRIS POOLE - KNOWN AS "MOOT" ONLINE - CREATED...
# 4   FOUR POLICE OFFICERS WERE INJURED IN THE INCID...
# 5   THE INJURED PEDESTRIAN - A YOUNG MAN - IS THOU...
# 6   BARCA WILL BE INVESTIGATED FOR ALLEGED MISAPPR...
# 7   THE THINK TANK SAID THE CITY'S 1,536 SCHOOLS N...
# 8   HIS 110 MEANS HE HAS SCORED 323 RUNS IN A WEEK...
# 9   MS KENDALL TOLD THE BBC LABOUR RISKED SENDING ...
# 10  THE ASSOCIATION OF SCHOOL AND COLLEGE LEADERS ...
# 11  MEDIA PLAYBACK IS UNSUPPORTED ON YOUR DEVICE\n...
# 12  ANN BARNES DEALT WITH AN "ILL-ADVISED" TV DOCU...
# 13  THE MAN GRABBED HOLD OF A CHILD'S BAG OUTSIDE ...
# 14  TAYLOR, 25, JOINED COUNTY IN MAY FROM MACCLESF...
# 15  the ex-reading defender denied fraudulent trad...
# 16  voges was forced to retire hurt on 86 after su...
# 17  seven photographs taken in the norfolk country...
# 18  chris poole - known as "moot" online - created...
# 19  four police officers were injured in the incid...
# 20  the injured pedestrian - a young man - is thou...
# 21  barca will be investigated for alleged misappr...
# 22  the think tank said the city's 1,536 schools n...
# 23  his 110 means he has scored 323 runs in a week...
# 24  ms kendall told the bbc labour risked sending ...
# 25  the association of school and college leaders ...
# 26  media playback is unsupported on your device\n...
# 27  ann barnes dealt with an "ill-advised" tv docu...
# 28  the man grabbed hold of a child's bag outside ...
# 29  taylor, 25, joined county in may from macclesf...

# %% [markdown]
# ### Running the tests

# %%
harness.run()
# Out:
# Running testcases... : 100%|██████████| 30/30 [01:52<00:00,  3.76s/it]

# %% [markdown]
# ### Generated Results

# %%
harness.generated_results()
# Out:
# Downloading builder script: 100%|██████████| 6.27k/6.27k [00:00<00:00, 3.14MB/s]
#       category  test_type                                           original
# 0   robustness  uppercase  The ex-Reading defender denied fraudulent trad...  \
# 1   robustness  uppercase  Voges was forced to retire hurt on 86 after su...
# 2   robustness  uppercase  Seven photographs taken in the Norfolk country...
# 3   robustness  uppercase  Chris Poole - known as "moot" online - created...
# 4   robustness  uppercase  Four police officers were injured in the incid...
# 5   robustness  uppercase  The injured pedestrian - a young man - is thou...
# 6   robustness  uppercase  Barca will be investigated for alleged misappr...
# 7   robustness  uppercase  The think tank said the city's 1,536 schools n...
# 8   robustness  uppercase  His 110 means he has scored 323 runs in a week...
# 9   robustness  uppercase  Ms Kendall told the BBC Labour risked sending ...
# 10  robustness  uppercase  The Association of School and College Leaders ...
# 11  robustness  uppercase  Media playback is unsupported on your device\n...
# 12  robustness  uppercase  Ann Barnes dealt with an "ill-advised" TV docu...
# 13  robustness  uppercase  The man grabbed hold of a child's bag outside ...
# 14  robustness  uppercase  Taylor, 25, joined County in May from Macclesf...
# 15  robustness  lowercase  The ex-Reading defender denied fraudulent trad...
# 16  robustness  lowercase  Voges was forced to retire hurt on 86 after su...
# 17  robustness  lowercase  Seven photographs taken in the Norfolk country...
# 18  robustness  lowercase  Chris Poole - known as "moot" online - created...
# 19  robustness  lowercase  Four police officers were injured in the incid...
# 20  robustness  lowercase  The injured pedestrian - a young man - is thou...
# 21  robustness  lowercase  Barca will be investigated for alleged misappr...
# 22  robustness  lowercase  The think tank said the city's 1,536 schools n...
# 23  robustness  lowercase  His 110 means he has scored 323 runs in a week...
# 24  robustness  lowercase  Ms Kendall told the BBC Labour risked sending ...
# 25  robustness  lowercase  The Association of School and College Leaders ...
# 26  robustness  lowercase  Media playback is unsupported on your device\n...
# 27  robustness  lowercase  Ann Barnes dealt with an "ill-advised" TV docu...
# 28  robustness  lowercase  The man grabbed hold of a child's bag outside ...
# 29  robustness  lowercase  Taylor, 25, joined County in May from Macclesf...
#
#                                             test_case
# 0   THE EX-READING DEFENDER DENIED FRAUDULENT TRAD...  \
# 1   VOGES WAS FORCED TO RETIRE HURT ON 86 AFTER SU...
# 2   SEVEN PHOTOGRAPHS TAKEN IN THE NORFOLK COUNTRY...
# 3   CHRIS POOLE - KNOWN AS "MOOT" ONLINE - CREATED...
# 4   FOUR POLICE OFFICERS WERE INJURED IN THE INCID...
# 5   THE INJURED PEDESTRIAN - A YOUNG MAN - IS THOU...
# 6   BARCA WILL BE INVESTIGATED FOR ALLEGED MISAPPR...
# 7   THE THINK TANK SAID THE CITY'S 1,536 SCHOOLS N...
# 8   HIS 110 MEANS HE HAS SCORED 323 RUNS IN A WEEK...
# 9   MS KENDALL TOLD THE BBC LABOUR RISKED SENDING ...
# 10  THE ASSOCIATION OF SCHOOL AND COLLEGE LEADERS ...
# 11  MEDIA PLAYBACK IS UNSUPPORTED ON YOUR DEVICE\n...
# 12  ANN BARNES DEALT WITH AN "ILL-ADVISED" TV DOCU...
# 13  THE MAN GRABBED HOLD OF A CHILD'S BAG OUTSIDE ...
# 14  TAYLOR, 25, JOINED COUNTY IN MAY FROM MACCLESF...
# 15  the ex-reading defender denied fraudulent trad...
# 16  voges was forced to retire hurt on 86 after su...
# 17  seven photographs taken in the norfolk country...
# 18  chris poole - known as "moot" online - created...
# 19  four police officers were injured in the incid...
# 20  the injured pedestrian - a young man - is thou...
# 21  barca will be investigated for alleged misappr...
# 22  the think tank said the city's 1,536 schools n...
# 23  his 110 means he has scored 323 runs in a week...
# 24  ms kendall told the bbc labour risked sending ...
# 25  the association of school and college leaders ...
# 26  media playback is unsupported on your device\n...
# 27  ann barnes dealt with an "ill-advised" tv docu...
# 28  the man grabbed hold of a child's bag outside ...
# 29  taylor, 25, joined county in may from macclesf...
#
#                                       expected_result
# 0    Sam Sodje, 37, and his brothers Efe, 44, Brig...  \
# 1    Adam Voges, a 37-year-old Australian crickete...
# 2    The June edition of British Vogue will featur...
# 3
# 4    Four police officers were injured in an incid...
# 5    A young man was walking with a group of peopl...
# 6   \nSandro Rosell resigned as president of FC Ba...
# 7    London Councils has warned that 1,536 schools...
# 8    Jason Roy scored 110 runs in a week, includin...
# 9    The Labour Party is in the midst of a leaders...
# 10   The Association of School and College Leaders...
# 11  \nChris Buckler, the BBC's Ireland corresponde...
# 12   Ann Barnes, the outgoing Police and Crime Com...
# 13   A man in his 30s with blonde hair and a scrat...
# 14   Taylor's move to Wrexham has left Newport Cou...
# 15   Four brothers, Sam, Efe, Bright and Stephen S...
# 16   Adam Voges, a 37-year-old Australian crickete...
# 17   Seven photographs of the Duchess of Cambridge...
# 18
# 19   Four police officers were injured in an incid...
# 20   A young man was walking with a group of peopl...
# 21  \nSandro Rosell resigned as president of Barce...
# 22   London Councils has warned that 1,536 schools...
# 23   Roy scored a century in response to his first...
# 24   The Labour Party is in the midst of a leaders...
# 25   The Association of School and College Leaders...
# 26  \nChris Buckler, the BBC's Ireland corresponde...
# 27   Ann Barnes, Kent's Police and Crime Commissio...
# 28   A man in his 30s, with blonde hair and a scra...
# 29   Taylor's move to Wrexham has left Newport Cou...
#
#                                         actual_result  eval_score   pass
# 0    Sam Sodje, 37, and his brothers Efe, 44, Brig...    0.920000   True
# 1    Adam Voges, a 37-year-old Australian crickete...    0.776699   True
# 2    Seven photographs taken by photographer Josh ...    0.616822   True
# 3    Chris Poole, known as "moot" online, created ...    0.000000  False
# 4    Four police officers were injured in an incid...    0.962963   True
# 5    A young man was injured while walking with a ...    0.705882   True
# 6   \nSandro Rosell resigned as president of Barce...    0.571429   True
# 7    London Councils, representing the city's 32 b...    0.383838  False
# 8    Tim Murtagh reduced Surrey to 23-2 in the fir...    0.474227  False
# 9    The Labour Party is in the midst of a leaders...    0.730769   True
# 10   The Association of School and College Leaders...    0.613861   True
# 11  \nChris Buckler, the BBC's Ireland corresponde...    0.270270  False
# 12   Ann Barnes, the outgoing Police and Crime Com...    0.392523  False
# 13   A man in his 30s, with blonde hair and a scra...    0.680000   True
# 14   Taylor's move to Wrexham has left Newport Cou...    0.807339   True
# 15   Sam Sodje, 37, and his brothers Efe, 44, Brig...    0.666667   True
# 16   Adam Voges, a 37-year-old Australian crickete...    0.725490   True
# 17   Josh Olins' seven photographs of the Duchess ...    0.627451   True
# 18                                                       0.000000  False
# 19   Four police officers were injured in an incid...    0.962963   True
# 20   A young man was walking with a group of peopl...    0.941176   True
# 21  \nSandro Rosell resigned as president of FC Ba...    0.725275   True
# 22   London Councils have warned that the governme...    0.297030  False
# 23   Tim Murtagh reduced Surrey to 23-2 in the fir...    0.303030  False
# 24   The Labour Party is in the midst of a leaders...    0.380952  False
# 25   The Association of School and College Leaders...    0.816327   True
# 26  \nChris Buckler, the BBC's Ireland corresponde...    1.000000   True
# 27   Ann Barnes, the outgoing Police and Crime Com...    0.345455  False
# 28   A man in his 30s, with blonde hair and a scra...    0.989474   True
# 29   Taylor's move to Wrexham has left Newport Cou...    0.836364   True

# %% [markdown]
# ### Generate Report

# %% [markdown]
# We can call `.report()` which summarizes the results giving information about pass and fail counts and overall test pass/fail flag.

# %%
harness.report()
# Out:
#      category  test_type  fail_count  pass_count pass_rate minimum_pass_rate
# 0  robustness  uppercase           5          10       67%               66%  \
# 1  robustness  lowercase           5          10       67%               60%
#
#    pass
# 0  True
# 1  True
