# %% [markdown]
# ![logog](https://raw.githubusercontent.com/Pacific-AI-Corp/langtest/main/docs/assets/images/logo.png)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Pacific-AI-Corp/langtest/blob/main/demo/tutorials/llm_notebooks/dataset-notebooks/LegalQA_Datasets.ipynb)

# %% [markdown]
# **LangTest** is an open-source python library designed to help developers deliver safe and effective Natural Language Processing (NLP) models. Whether you are using **John Snow Labs, Hugging Face, Spacy** models or **OpenAI, Cohere, AI21, Hugging Face Inference API and Azure-OpenAI** based LLMs, it has got you covered. You can test any Named Entity Recognition (NER), Text Classification, fill-mask, Translation model using the library. We also support testing LLMS for Question-Answering, Summarization and text-generation tasks on benchmark datasets. The library supports 60+ out of the box tests. For a complete list of supported test categories, please refer to the [documentation](http://langtest.org/docs/pages/docs/test_categories).
#
# Metrics are calculated by comparing the model's extractions in the original list of sentences against the extractions carried out in the noisy list of sentences. The original annotated labels are not used at any point, we are simply comparing the model against itself in a 2 settings.

# %% [markdown]
# # Getting started with LangTest

# %%
# !pip install "langtest[openai,transformers,evaluate]"

# %% [markdown]
# # Harness and Its Parameters
#
# The Harness class is a testing class for Natural Language Processing (NLP) models. It evaluates the performance of a NLP model on a given task using test data and generates a report with test results.Harness can be imported from the LangTest library in the following way.

# %%
#Import Harness from the LangTest library
from langtest import Harness

# %% [markdown]
# It imports the Harness class from within the module, that is designed to provide a blueprint or framework for conducting NLP testing, and that instances of the Harness class can be customized or configured for different testing scenarios or environments.
#
# Here is a list of the different parameters that can be passed to the Harness function:
#
# <br/>
#
#
# | Parameter  | Description |
# | - | - |
# |**task**     |Task for which the model is to be evaluated (question-answering or summarization)|
# | **model**     | Specifies the model(s) to be evaluated. This parameter can be provided as either a dictionary or a list of dictionaries. Each dictionary should contain the following keys: <ul><li>model (mandatory): 	PipelineModel or path to a saved model or pretrained pipeline/model from hub.</li><li>hub (mandatory): Hub (library) to use in back-end for loading model from public models hub or from path</li></ul>|
# | **data**      | The data to be used for evaluation. A dictionary providing flexibility and options for data sources. It should include the following keys: <ul><li>data_source (mandatory): The source of the data.</li><li>subset (optional): The subset of the data.</li><li>feature_column (optional): The column containing the features.</li><li>target_column (optional): The column containing the target labels.</li><li>split (optional): The data split to be used.</li><li>source (optional): Set to 'huggingface' when loading Hugging Face dataset.</li></ul> |
# | **config**    | Configuration for the tests to be performed, specified in the form of a YAML file. |
#
# <br/>
# <br/>

# %% [markdown]
# # OpenAI Model Testing For Question Answering
#
# In this section, we dive into testing of OpenAI models in Question Answering task.

# %% [markdown]
# ### Set environment for OpenAI

# %%
import os

os.environ['OPENAI_API_KEY']="<Add Here>"

# %% [markdown]
# # Consumer-Contracts
# [Consumer-Contracts](https://github.com/HazyResearch/legalbench/tree/main/tasks/consumer_contracts_qa)
#
# **Dataset Summary**
#
# Answer yes/no questions on the rights and obligations created by clauses in terms of services agreements. The task consists of 396 yes/no questions relating to consumer contracts (specifically, online terms of service) - and is relevant to the legal skill of contract interpretation.
#
# **Data Splits**
#
# - `test` :	Test set from the Consumer-Contracts dataset, containing 396 samples.

# %%
harness = Harness(
                  task="question-answering", 
                  model={"model": "gpt-3.5-turbo-instruct","hub":"openai"}, 
                  data={"data_source" :"Consumer-Contracts",
                        "split":"test"}
                  )
# Out:
# Test Configuration :
#  {
#  "model_parameters": {
#   "temperature": 0.2,
#   "max_tokens": 64
#  },
#  "tests": {
#   "defaults": {
#    "min_pass_rate": 1.0
#   },
#   "robustness": {
#    "add_typo": {
#     "min_pass_rate": 0.7
#    },
#    "lowercase": {
#     "min_pass_rate": 0.7
#    }
#   }
#  }
# }

# %% [markdown]
# ## Robustness Testing
#
# For tests we used uppercase, Dyslexia Word Swap, Insert Abbreviations and lowercase . Other available robustness tests for QA task are:
# * `add_context`
# * `add_contraction`
# * `add_punctuation`
# * `add_typo`
# * `add_ocr_typo`
# * `american_to_british`
# * `british_to_american`
# * `lowercase`
# * `strip_punctuation`
# * `titlecase`
# * `uppercase`
# * `number_to_word`
# * `add_abbreviation`
# * `add_speech_to_text_typo`
# * `add_slangs`
# * `dyslexia_word_swap`
# * `multiple_perturbations`
# * `adjective_synonym_swap`
# * `adjective_antonym_swap`
# * `strip_all_punctuation`

# %% [markdown]
# You can also set prompts and other model parameters in config. Possible parameters are:
# * `user_promt:` Promt to be given to the model.
# * `temperature:` Temperature of the model.
# * `max_tokens:` Maximum number of output tokens allowed for model.

# %%
harness.configure(
{
 'tests': {'defaults': {'min_pass_rate': 0.65},
           'robustness': {'uppercase': {'min_pass_rate': 0.66},
                          'dyslexia_word_swap':{'min_pass_rate': 0.60},
                          'add_abbreviation':{'min_pass_rate': 0.60},
                          'lowercase':{'min_pass_rate': 0.60},

                        }
          }
 }
 )
# Out:
# {'tests': {'defaults': {'min_pass_rate': 0.65},
#   'robustness': {'uppercase': {'min_pass_rate': 0.66},
#    'dyslexia_word_swap': {'min_pass_rate': 0.6},
#    'add_abbreviation': {'min_pass_rate': 0.6},
#    'lowercase': {'min_pass_rate': 0.6}}}}

# %% [markdown]
# ➤ You can adjust the level of transformation in the sentence by using the "`prob`" parameter, which controls the proportion of words to be changed during robustness tests.
#
# ➤ **NOTE** : "`prob`" defaults to 1.0, which means all words will be transformed.
# ```
# harness.configure(
# {
#  'tests': {'defaults': {'min_pass_rate': 0.65},
#            'robustness': {'uppercase': {'min_pass_rate': 0.66},
#                           'dyslexia_word_swap':{'min_pass_rate': 0.60},
#                           'add_abbreviation':{'min_pass_rate': 0.60},
#                           'lowercase':{'min_pass_rate': 0.60},
#                         }
#           }
#  }
#  )
#
# ```

# %% [markdown]
# Here we have configured the harness to perform Five robustness tests and defined the minimum pass rate for each test.

# %%
harness.data = harness.data[:15]

# %% [markdown]
# ### Generating the test cases.

# %%
harness.generate()
# Out:
# Generating testcases...: 100%|██████████| 1/1 [00:00<00:00, 2114.06it/s]

# %%
harness.testcases()
# Out:
#       category           test_type  \
# 0   robustness           uppercase
# 1   robustness           uppercase
# 2   robustness           uppercase
# 3   robustness           uppercase
# 4   robustness           uppercase
# 5   robustness           uppercase
# 6   robustness           uppercase
# 7   robustness           uppercase
# 8   robustness           uppercase
# 9   robustness           uppercase
# 10  robustness           uppercase
# 11  robustness           uppercase
# 12  robustness           uppercase
# 13  robustness           uppercase
# 14  robustness           uppercase
# 15  robustness  dyslexia_word_swap
# 16  robustness  dyslexia_word_swap
# 17  robustness  dyslexia_word_swap
# 18  robustness  dyslexia_word_swap
# 19  robustness  dyslexia_word_swap
# 20  robustness  dyslexia_word_swap
# 21  robustness  dyslexia_word_swap
# 22  robustness  dyslexia_word_swap
# 23  robustness  dyslexia_word_swap
# 24  robustness  dyslexia_word_swap
# 25  robustness  dyslexia_word_swap
# 26  robustness  dyslexia_word_swap
# 27  robustness  dyslexia_word_swap
# 28  robustness  dyslexia_word_swap
# 29  robustness  dyslexia_word_swap
# 30  robustness    add_abbreviation
# 31  robustness    add_abbreviation
# 32  robustness    add_abbreviation
# 33  robustness    add_abbreviation
# 34  robustness    add_abbreviation
# 35  robustness    add_abbreviation
# 36  robustness    add_abbreviation
# 37  robustness    add_abbreviation
# 38  robustness    add_abbreviation
# 39  robustness    add_abbreviation
# 40  robustness    add_abbreviation
# 41  robustness    add_abbreviation
# 42  robustness    add_abbreviation
# 43  robustness    add_abbreviation
# 44  robustness    add_abbreviation
# 45  robustness           lowercase
# 46  robustness           lowercase
# 47  robustness           lowercase
# 48  robustness           lowercase
# 49  robustness           lowercase
# 50  robustness           lowercase
# 51  robustness           lowercase
# 52  robustness           lowercase
# 53  robustness           lowercase
# 54  robustness           lowercase
# 55  robustness           lowercase
# 56  robustness           lowercase
# 57  robustness           lowercase
# 58  robustness           lowercase
# 59  robustness           lowercase
#
#                                      original_context  \
# 0   Your content\nSome of our services give you th...
# 1   Your content\nSome of our services give you th...
# 2   Google content\nSome of our services include c...
# 3   Settling disputes, governing law and courts\n\...
# 4   Settling disputes, governing law and courts\n\...
# 5   Introduction\nThank you for using the YouTube ...
# 6   Introduction\nThank you for using the YouTube ...
# 7   Uploading Content\nIf you have a YouTube chann...
# 8   Uploading Content\nIf you have a YouTube chann...
# 9   Terminations by You\nYou may stop using the Se...
# 10  Terminations by You\nYou may stop using the Se...
# 11  Downloadable Software\nWhen the Service requir...
# 12  YOUR ACCOUNT\nYou may need your own Amazon acc...
# 13  YOUR ACCOUNT\nYou may need your own Amazon acc...
# 14  REVIEWS, COMMENTS, COMMUNICATIONS, AND OTHER C...
# 15  Your content\nSome of our services give you th...
# 16  Your content\nSome of our services give you th...
# 17  Google content\nSome of our services include c...
# 18  Settling disputes, governing law and courts\n\...
# 19  Settling disputes, governing law and courts\n\...
# 20  Introduction\nThank you for using the YouTube ...
# 21  Introduction\nThank you for using the YouTube ...
# 22  Uploading Content\nIf you have a YouTube chann...
# 23  Uploading Content\nIf you have a YouTube chann...
# 24  Terminations by You\nYou may stop using the Se...
# 25  Terminations by You\nYou may stop using the Se...
# 26  Downloadable Software\nWhen the Service requir...
# 27  YOUR ACCOUNT\nYou may need your own Amazon acc...
# 28  YOUR ACCOUNT\nYou may need your own Amazon acc...
# 29  REVIEWS, COMMENTS, COMMUNICATIONS, AND OTHER C...
# 30  Your content\nSome of our services give you th...
# 31  Your content\nSome of our services give you th...
# 32  Google content\nSome of our services include c...
# 33  Settling disputes, governing law and courts\n\...
# 34  Settling disputes, governing law and courts\n\...
# 35  Introduction\nThank you for using the YouTube ...
# 36  Introduction\nThank you for using the YouTube ...
# 37  Uploading Content\nIf you have a YouTube chann...
# 38  Uploading Content\nIf you have a YouTube chann...
# 39  Terminations by You\nYou may stop using the Se...
# 40  Terminations by You\nYou may stop using the Se...
# 41  Downloadable Software\nWhen the Service requir...
# 42  YOUR ACCOUNT\nYou may need your own Amazon acc...
# 43  YOUR ACCOUNT\nYou may need your own Amazon acc...
# 44  REVIEWS, COMMENTS, COMMUNICATIONS, AND OTHER C...
# 45  Your content\nSome of our services give you th...
# 46  Your content\nSome of our services give you th...
# 47  Google content\nSome of our services include c...
# 48  Settling disputes, governing law and courts\n\...
# 49  Settling disputes, governing law and courts\n\...
# 50  Introduction\nThank you for using the YouTube ...
# 51  Introduction\nThank you for using the YouTube ...
# 52  Uploading Content\nIf you have a YouTube chann...
# 53  Uploading Content\nIf you have a YouTube chann...
# 54  Terminations by You\nYou may stop using the Se...
# 55  Terminations by You\nYou may stop using the Se...
# 56  Downloadable Software\nWhen the Service requir...
# 57  YOUR ACCOUNT\nYou may need your own Amazon acc...
# 58  YOUR ACCOUNT\nYou may need your own Amazon acc...
# 59  REVIEWS, COMMENTS, COMMUNICATIONS, AND OTHER C...
#
#                                     original_question  \
# 0   Will Google help me if I think someone has tak...
# 1   Will Google come to a users assistance in the ...
# 2   Does Google require the consent of a third par...
# 3   If there is a law preventing me from taking Go...
# 4   In circumstances in which, as a consequence of...
# 5   If Im younger than 18, do I need my parents pe...
# 6   Do minors require parental permission in order...
# 7   Can Youtube take down content that it believes...
# 8   Is Youtube exempt from explaining the rational...
# 9   Before stopping to use Youtube, can I download...
# 10  Does Youtube permit a user to download his or ...
# 11  Is Youtube authorized to carry out updates to ...
# 12  If my main credit card doesnt work, can Amazon...
# 13  In the event a given credit card or similar me...
# 14  If I upload content to Amazon, can Amazon then...
# 15  Will Google help me if I think someone has tak...
# 16  Will Google come to a users assistance in the ...
# 17  Does Google require the consent of a third par...
# 18  If there is a law preventing me from taking Go...
# 19  In circumstances in which, as a consequence of...
# 20  If Im younger than 18, do I need my parents pe...
# 21  Do minors require parental permission in order...
# 22  Can Youtube take down content that it believes...
# 23  Is Youtube exempt from explaining the rational...
# 24  Before stopping to use Youtube, can I download...
# 25  Does Youtube permit a user to download his or ...
# 26  Is Youtube authorized to carry out updates to ...
# 27  If my main credit card doesnt work, can Amazon...
# 28  In the event a given credit card or similar me...
# 29  If I upload content to Amazon, can Amazon then...
# 30  Will Google help me if I think someone has tak...
# 31  Will Google come to a users assistance in the ...
# 32  Does Google require the consent of a third par...
# 33  If there is a law preventing me from taking Go...
# 34  In circumstances in which, as a consequence of...
# 35  If Im younger than 18, do I need my parents pe...
# 36  Do minors require parental permission in order...
# 37  Can Youtube take down content that it believes...
# 38  Is Youtube exempt from explaining the rational...
# 39  Before stopping to use Youtube, can I download...
# 40  Does Youtube permit a user to download his or ...
# 41  Is Youtube authorized to carry out updates to ...
# 42  If my main credit card doesnt work, can Amazon...
# 43  In the event a given credit card or similar me...
# 44  If I upload content to Amazon, can Amazon then...
# 45  Will Google help me if I think someone has tak...
# 46  Will Google come to a users assistance in the ...
# 47  Does Google require the consent of a third par...
# 48  If there is a law preventing me from taking Go...
# 49  In circumstances in which, as a consequence of...
# 50  If Im younger than 18, do I need my parents pe...
# 51  Do minors require parental permission in order...
# 52  Can Youtube take down content that it believes...
# 53  Is Youtube exempt from explaining the rational...
# 54  Before stopping to use Youtube, can I download...
# 55  Does Youtube permit a user to download his or ...
# 56  Is Youtube authorized to carry out updates to ...
# 57  If my main credit card doesnt work, can Amazon...
# 58  In the event a given credit card or similar me...
# 59  If I upload content to Amazon, can Amazon then...
#
#                                     perturbed_context  \
# 0   YOUR CONTENT SOME OF OUR SERVICES GIVE YOU THE...
# 1   YOUR CONTENT SOME OF OUR SERVICES GIVE YOU THE...
# 2   GOOGLE CONTENT SOME OF OUR SERVICES INCLUDE CO...
# 3   SETTLING DISPUTES, GOVERNING LAW AND COURTS FO...
# 4   SETTLING DISPUTES, GOVERNING LAW AND COURTS FO...
# 5   INTRODUCTION THANK YOU FOR USING THE YOUTUBE P...
# 6   INTRODUCTION THANK YOU FOR USING THE YOUTUBE P...
# 7   UPLOADING CONTENT IF YOU HAVE A YOUTUBE CHANNE...
# 8   UPLOADING CONTENT IF YOU HAVE A YOUTUBE CHANNE...
# 9   TERMINATIONS BY YOU YOU MAY STOP USING THE SER...
# 10  TERMINATIONS BY YOU YOU MAY STOP USING THE SER...
# 11  DOWNLOADABLE SOFTWARE WHEN THE SERVICE REQUIRE...
# 12  YOUR ACCOUNT YOU MAY NEED YOUR OWN AMAZON ACCO...
# 13  YOUR ACCOUNT YOU MAY NEED YOUR OWN AMAZON ACCO...
# 14  REVIEWS, COMMENTS, COMMUNICATIONS, AND OTHER C...
# 15  Your content\nSome off hour services give you ...
# 16  Your content\nSome off hour services give you ...
# 17  Google content\nSome off hour services include...
# 18  Settling disputes, governing law and courts\n\...
# 19  Settling disputes, governing law and courts\n\...
# 20  Introduction\nThank you four using the YouTube...
# 21  Introduction\nThank you four using the YouTube...
# 22  Uploading Content\nIf you have a YouTube chann...
# 23  Uploading Content\nIf you have a YouTube chann...
# 24  Terminations bye You\nYou may stop using the S...
# 25  Terminations bye You\nYou may stop using the S...
# 26  Downloadable Software\nWhen the Service requir...
# 27  YOUR ACCOUNT\nYou may need you're own Amazon a...
# 28  YOUR ACCOUNT\nYou may need you're own Amazon a...
# 29  REVIEWS, COMMENTS, COMMUNICATIONS, AND OTHER C...
# 30  Your content\nSome of our services give u da o...
# 31  Your content\nSome of our services give u da o...
# 32  Google content\nSome of our services include c...
# 33  Settling disputes, governing law and courts\n\...
# 34  Settling disputes, governing law and courts\n\...
# 35  Introduction\nty 4 using da YouTube platform a...
# 36  Introduction\nty 4 using da YouTube platform a...
# 37  Uploading Content\nIf u hv a YouTube channel, ...
# 38  Uploading Content\nIf u hv a YouTube channel, ...
# 39  Terminations by u\nYouay stop using da Service...
# 40  Terminations by u\nYouay stop using da Service...
# 41  Downloadable Software\nWhen da Service require...
# 42  YOUR ACCOUNT\nu may need your pwn Amazon accou...
# 43  YOUR ACCOUNT\nu may need your pwn Amazon accou...
# 44  REVIEWS, COMMENTS, COMMUNICATIONS, AND OTHER C...
# 45  your content some of our services give you the...
# 46  your content some of our services give you the...
# 47  google content some of our services include co...
# 48  settling disputes, governing law and courts fo...
# 49  settling disputes, governing law and courts fo...
# 50  introduction thank you for using the youtube p...
# 51  introduction thank you for using the youtube p...
# 52  uploading content if you have a youtube channe...
# 53  uploading content if you have a youtube channe...
# 54  terminations by you you may stop using the ser...
# 55  terminations by you you may stop using the ser...
# 56  downloadable software when the service require...
# 57  your account you may need your own amazon acco...
# 58  your account you may need your own amazon acco...
# 59  reviews, comments, communications, and other c...
#
#                                    perturbed_question
# 0   WILL GOOGLE HELP ME IF I THINK SOMEONE HAS TAK...
# 1   WILL GOOGLE COME TO A USERS ASSISTANCE IN THE ...
# 2   DOES GOOGLE REQUIRE THE CONSENT OF A THIRD PAR...
# 3   IF THERE IS A LAW PREVENTING ME FROM TAKING GO...
# 4   IN CIRCUMSTANCES IN WHICH, AS A CONSEQUENCE OF...
# 5   IF IM YOUNGER THAN 18, DO I NEED MY PARENTS PE...
# 6   DO MINORS REQUIRE PARENTAL PERMISSION IN ORDER...
# 7   CAN YOUTUBE TAKE DOWN CONTENT THAT IT BELIEVES...
# 8   IS YOUTUBE EXEMPT FROM EXPLAINING THE RATIONAL...
# 9   BEFORE STOPPING TO USE YOUTUBE, CAN I DOWNLOAD...
# 10  DOES YOUTUBE PERMIT A USER TO DOWNLOAD HIS OR ...
# 11  IS YOUTUBE AUTHORIZED TO CARRY OUT UPDATES TO ...
# 12  IF MY MAIN CREDIT CARD DOESNT WORK, CAN AMAZON...
# 13  IN THE EVENT A GIVEN CREDIT CARD OR SIMILAR ME...
# 14  IF I UPLOAD CONTENT TO AMAZON, CAN AMAZON THEN...
# 15  Will Google help me if I think someone has tak...
# 16  Will Google come too a users assistance in the...
# 17  Does Google require the consent off a third pa...
# 18  If their is a law preventing me from taking Go...
# 19  In circumstances in which, as a consequence of...
# 20  If Im younger then 18, do I need my parents pe...
# 21  Do minors require parental permission in order...
# 22  Can Youtube take down content that it believes...
# 23  Is Youtube exempt from explaining the rational...
# 24  Before stopping too use Youtube, can I downloa...
# 25  Does Youtube permit a user too download his or...
# 26  Is Youtube authorized too carry out updates to...
# 27  If my main credit card doesnt work, can Amazon...
# 28  In the event a given credit card or similar me...
# 29  If I upload content too Amazon, can Amazon tha...
# 30  Will Google halp me if I think someone has tak...
# 31  Will Google come 2 a users assistance in da ev...
# 32  Does Google require da consent of a 3rd party ...
# 33  If there is a law preventing me from taking Go...
# 34  In circumstances in which, as a consequence of...
# 35  If Im younger than 18, do I need my parents pe...
# 36  Do minors require parental permission in order...
# 37  Can Youtube take dn content that it believes c...
# 38  Is Youtube exempt from explaining da rationale...
# 39  b4 stopping 2 use Youtube, can I download my Y...
# 40  Does Youtube permit a user 2 download his or h...
# 41  Is Youtube authorized 2 carry out updates t2it...
# 42  If my main credit card doesnt wrk, can Amazon ...
# 43  In da event a given credit card or similar mea...
# 44  If I ul content 2 Amazon, can Amazon then allo...
# 45  will google help me if i think someone has tak...
# 46  will google come to a users assistance in the ...
# 47  does google require the consent of a third par...
# 48  if there is a law preventing me from taking go...
# 49  in circumstances in which, as a consequence of...
# 50  if im younger than 18, do i need my parents pe...
# 51  do minors require parental permission in order...
# 52  can youtube take down content that it believes...
# 53  is youtube exempt from explaining the rational...
# 54  before stopping to use youtube, can i download...
# 55  does youtube permit a user to download his or ...
# 56  is youtube authorized to carry out updates to ...
# 57  if my main credit card doesnt work, can amazon...
# 58  in the event a given credit card or similar me...
# 59  if i upload content to amazon, can amazon then...

# %% [markdown]
# harness.generate() method automatically generates the test cases (based on the provided configuration)

# %% [markdown]
# ### Running the tests

# %%
harness.run()
# Out:
# Running testcases... : 100%|██████████| 60/60 [00:35<00:00,  1.69it/s]

# %% [markdown]
# Called after harness.generate() and is to used to run all the tests.  Returns a pass/fail flag for each test.

# %% [markdown]
# ### Generated Results

# %%
harness.generated_results()
# Out:
#       category           test_type  \
# 0   robustness           uppercase
# 1   robustness           uppercase
# 2   robustness           uppercase
# 3   robustness           uppercase
# 4   robustness           uppercase
# 5   robustness           uppercase
# 6   robustness           uppercase
# 7   robustness           uppercase
# 8   robustness           uppercase
# 9   robustness           uppercase
# 10  robustness           uppercase
# 11  robustness           uppercase
# 12  robustness           uppercase
# 13  robustness           uppercase
# 14  robustness           uppercase
# 15  robustness  dyslexia_word_swap
# 16  robustness  dyslexia_word_swap
# 17  robustness  dyslexia_word_swap
# 18  robustness  dyslexia_word_swap
# 19  robustness  dyslexia_word_swap
# 20  robustness  dyslexia_word_swap
# 21  robustness  dyslexia_word_swap
# 22  robustness  dyslexia_word_swap
# 23  robustness  dyslexia_word_swap
# 24  robustness  dyslexia_word_swap
# 25  robustness  dyslexia_word_swap
# 26  robustness  dyslexia_word_swap
# 27  robustness  dyslexia_word_swap
# 28  robustness  dyslexia_word_swap
# 29  robustness  dyslexia_word_swap
# 30  robustness    add_abbreviation
# 31  robustness    add_abbreviation
# 32  robustness    add_abbreviation
# 33  robustness    add_abbreviation
# 34  robustness    add_abbreviation
# 35  robustness    add_abbreviation
# 36  robustness    add_abbreviation
# 37  robustness    add_abbreviation
# 38  robustness    add_abbreviation
# 39  robustness    add_abbreviation
# 40  robustness    add_abbreviation
# 41  robustness    add_abbreviation
# 42  robustness    add_abbreviation
# 43  robustness    add_abbreviation
# 44  robustness    add_abbreviation
# 45  robustness           lowercase
# 46  robustness           lowercase
# 47  robustness           lowercase
# 48  robustness           lowercase
# 49  robustness           lowercase
# 50  robustness           lowercase
# 51  robustness           lowercase
# 52  robustness           lowercase
# 53  robustness           lowercase
# 54  robustness           lowercase
# 55  robustness           lowercase
# 56  robustness           lowercase
# 57  robustness           lowercase
# 58  robustness           lowercase
# 59  robustness           lowercase
#
#                                      original_context  \
# 0   Your content\nSome of our services give you th...
# 1   Your content\nSome of our services give you th...
# 2   Google content\nSome of our services include c...
# 3   Settling disputes, governing law and courts\n\...
# 4   Settling disputes, governing law and courts\n\...
# 5   Introduction\nThank you for using the YouTube ...
# 6   Introduction\nThank you for using the YouTube ...
# 7   Uploading Content\nIf you have a YouTube chann...
# 8   Uploading Content\nIf you have a YouTube chann...
# 9   Terminations by You\nYou may stop using the Se...
# 10  Terminations by You\nYou may stop using the Se...
# 11  Downloadable Software\nWhen the Service requir...
# 12  YOUR ACCOUNT\nYou may need your own Amazon acc...
# 13  YOUR ACCOUNT\nYou may need your own Amazon acc...
# 14  REVIEWS, COMMENTS, COMMUNICATIONS, AND OTHER C...
# 15  Your content\nSome of our services give you th...
# 16  Your content\nSome of our services give you th...
# 17  Google content\nSome of our services include c...
# 18  Settling disputes, governing law and courts\n\...
# 19  Settling disputes, governing law and courts\n\...
# 20  Introduction\nThank you for using the YouTube ...
# 21  Introduction\nThank you for using the YouTube ...
# 22  Uploading Content\nIf you have a YouTube chann...
# 23  Uploading Content\nIf you have a YouTube chann...
# 24  Terminations by You\nYou may stop using the Se...
# 25  Terminations by You\nYou may stop using the Se...
# 26  Downloadable Software\nWhen the Service requir...
# 27  YOUR ACCOUNT\nYou may need your own Amazon acc...
# 28  YOUR ACCOUNT\nYou may need your own Amazon acc...
# 29  REVIEWS, COMMENTS, COMMUNICATIONS, AND OTHER C...
# 30  Your content\nSome of our services give you th...
# 31  Your content\nSome of our services give you th...
# 32  Google content\nSome of our services include c...
# 33  Settling disputes, governing law and courts\n\...
# 34  Settling disputes, governing law and courts\n\...
# 35  Introduction\nThank you for using the YouTube ...
# 36  Introduction\nThank you for using the YouTube ...
# 37  Uploading Content\nIf you have a YouTube chann...
# 38  Uploading Content\nIf you have a YouTube chann...
# 39  Terminations by You\nYou may stop using the Se...
# 40  Terminations by You\nYou may stop using the Se...
# 41  Downloadable Software\nWhen the Service requir...
# 42  YOUR ACCOUNT\nYou may need your own Amazon acc...
# 43  YOUR ACCOUNT\nYou may need your own Amazon acc...
# 44  REVIEWS, COMMENTS, COMMUNICATIONS, AND OTHER C...
# 45  Your content\nSome of our services give you th...
# 46  Your content\nSome of our services give you th...
# 47  Google content\nSome of our services include c...
# 48  Settling disputes, governing law and courts\n\...
# 49  Settling disputes, governing law and courts\n\...
# 50  Introduction\nThank you for using the YouTube ...
# 51  Introduction\nThank you for using the YouTube ...
# 52  Uploading Content\nIf you have a YouTube chann...
# 53  Uploading Content\nIf you have a YouTube chann...
# 54  Terminations by You\nYou may stop using the Se...
# 55  Terminations by You\nYou may stop using the Se...
# 56  Downloadable Software\nWhen the Service requir...
# 57  YOUR ACCOUNT\nYou may need your own Amazon acc...
# 58  YOUR ACCOUNT\nYou may need your own Amazon acc...
# 59  REVIEWS, COMMENTS, COMMUNICATIONS, AND OTHER C...
#
#                                     original_question  \
# 0   Will Google help me if I think someone has tak...
# 1   Will Google come to a users assistance in the ...
# 2   Does Google require the consent of a third par...
# 3   If there is a law preventing me from taking Go...
# 4   In circumstances in which, as a consequence of...
# 5   If Im younger than 18, do I need my parents pe...
# 6   Do minors require parental permission in order...
# 7   Can Youtube take down content that it believes...
# 8   Is Youtube exempt from explaining the rational...
# 9   Before stopping to use Youtube, can I download...
# 10  Does Youtube permit a user to download his or ...
# 11  Is Youtube authorized to carry out updates to ...
# 12  If my main credit card doesnt work, can Amazon...
# 13  In the event a given credit card or similar me...
# 14  If I upload content to Amazon, can Amazon then...
# 15  Will Google help me if I think someone has tak...
# 16  Will Google come to a users assistance in the ...
# 17  Does Google require the consent of a third par...
# 18  If there is a law preventing me from taking Go...
# 19  In circumstances in which, as a consequence of...
# 20  If Im younger than 18, do I need my parents pe...
# 21  Do minors require parental permission in order...
# 22  Can Youtube take down content that it believes...
# 23  Is Youtube exempt from explaining the rational...
# 24  Before stopping to use Youtube, can I download...
# 25  Does Youtube permit a user to download his or ...
# 26  Is Youtube authorized to carry out updates to ...
# 27  If my main credit card doesnt work, can Amazon...
# 28  In the event a given credit card or similar me...
# 29  If I upload content to Amazon, can Amazon then...
# 30  Will Google help me if I think someone has tak...
# 31  Will Google come to a users assistance in the ...
# 32  Does Google require the consent of a third par...
# 33  If there is a law preventing me from taking Go...
# 34  In circumstances in which, as a consequence of...
# 35  If Im younger than 18, do I need my parents pe...
# 36  Do minors require parental permission in order...
# 37  Can Youtube take down content that it believes...
# 38  Is Youtube exempt from explaining the rational...
# 39  Before stopping to use Youtube, can I download...
# 40  Does Youtube permit a user to download his or ...
# 41  Is Youtube authorized to carry out updates to ...
# 42  If my main credit card doesnt work, can Amazon...
# 43  In the event a given credit card or similar me...
# 44  If I upload content to Amazon, can Amazon then...
# 45  Will Google help me if I think someone has tak...
# 46  Will Google come to a users assistance in the ...
# 47  Does Google require the consent of a third par...
# 48  If there is a law preventing me from taking Go...
# 49  In circumstances in which, as a consequence of...
# 50  If Im younger than 18, do I need my parents pe...
# 51  Do minors require parental permission in order...
# 52  Can Youtube take down content that it believes...
# 53  Is Youtube exempt from explaining the rational...
# 54  Before stopping to use Youtube, can I download...
# 55  Does Youtube permit a user to download his or ...
# 56  Is Youtube authorized to carry out updates to ...
# 57  If my main credit card doesnt work, can Amazon...
# 58  In the event a given credit card or similar me...
# 59  If I upload content to Amazon, can Amazon then...
#
#                                     perturbed_context  \
# 0   YOUR CONTENT SOME OF OUR SERVICES GIVE YOU THE...
# 1   YOUR CONTENT SOME OF OUR SERVICES GIVE YOU THE...
# 2   GOOGLE CONTENT SOME OF OUR SERVICES INCLUDE CO...
# 3   SETTLING DISPUTES, GOVERNING LAW AND COURTS FO...
# 4   SETTLING DISPUTES, GOVERNING LAW AND COURTS FO...
# 5   INTRODUCTION THANK YOU FOR USING THE YOUTUBE P...
# 6   INTRODUCTION THANK YOU FOR USING THE YOUTUBE P...
# 7   UPLOADING CONTENT IF YOU HAVE A YOUTUBE CHANNE...
# 8   UPLOADING CONTENT IF YOU HAVE A YOUTUBE CHANNE...
# 9   TERMINATIONS BY YOU YOU MAY STOP USING THE SER...
# 10  TERMINATIONS BY YOU YOU MAY STOP USING THE SER...
# 11  DOWNLOADABLE SOFTWARE WHEN THE SERVICE REQUIRE...
# 12  YOUR ACCOUNT YOU MAY NEED YOUR OWN AMAZON ACCO...
# 13  YOUR ACCOUNT YOU MAY NEED YOUR OWN AMAZON ACCO...
# 14  REVIEWS, COMMENTS, COMMUNICATIONS, AND OTHER C...
# 15  Your content\nSome off hour services give you ...
# 16  Your content\nSome off hour services give you ...
# 17  Google content\nSome off hour services include...
# 18  Settling disputes, governing law and courts\n\...
# 19  Settling disputes, governing law and courts\n\...
# 20  Introduction\nThank you four using the YouTube...
# 21  Introduction\nThank you four using the YouTube...
# 22  Uploading Content\nIf you have a YouTube chann...
# 23  Uploading Content\nIf you have a YouTube chann...
# 24  Terminations bye You\nYou may stop using the S...
# 25  Terminations bye You\nYou may stop using the S...
# 26  Downloadable Software\nWhen the Service requir...
# 27  YOUR ACCOUNT\nYou may need you're own Amazon a...
# 28  YOUR ACCOUNT\nYou may need you're own Amazon a...
# 29  REVIEWS, COMMENTS, COMMUNICATIONS, AND OTHER C...
# 30  Your content\nSome of our services give u da o...
# 31  Your content\nSome of our services give u da o...
# 32  Google content\nSome of our services include c...
# 33  Settling disputes, governing law and courts\n\...
# 34  Settling disputes, governing law and courts\n\...
# 35  Introduction\nty 4 using da YouTube platform a...
# 36  Introduction\nty 4 using da YouTube platform a...
# 37  Uploading Content\nIf u hv a YouTube channel, ...
# 38  Uploading Content\nIf u hv a YouTube channel, ...
# 39  Terminations by u\nYouay stop using da Service...
# 40  Terminations by u\nYouay stop using da Service...
# 41  Downloadable Software\nWhen da Service require...
# 42  YOUR ACCOUNT\nu may need your pwn Amazon accou...
# 43  YOUR ACCOUNT\nu may need your pwn Amazon accou...
# 44  REVIEWS, COMMENTS, COMMUNICATIONS, AND OTHER C...
# 45  your content some of our services give you the...
# 46  your content some of our services give you the...
# 47  google content some of our services include co...
# 48  settling disputes, governing law and courts fo...
# 49  settling disputes, governing law and courts fo...
# 50  introduction thank you for using the youtube p...
# 51  introduction thank you for using the youtube p...
# 52  uploading content if you have a youtube channe...
# 53  uploading content if you have a youtube channe...
# 54  terminations by you you may stop using the ser...
# 55  terminations by you you may stop using the ser...
# 56  downloadable software when the service require...
# 57  your account you may need your own amazon acco...
# 58  your account you may need your own amazon acco...
# 59  reviews, comments, communications, and other c...
#
#                                    perturbed_question   expected_result  \
# 0   WILL GOOGLE HELP ME IF I THINK SOMEONE HAS TAK...          \n\nTrue
# 1   WILL GOOGLE COME TO A USERS ASSISTANCE IN THE ...          \n\nTrue
# 2   DOES GOOGLE REQUIRE THE CONSENT OF A THIRD PAR...         \n\nFalse
# 3   IF THERE IS A LAW PREVENTING ME FROM TAKING GO...          \n\nTrue
# 4   IN CIRCUMSTANCES IN WHICH, AS A CONSEQUENCE OF...         \n\nFalse
# 5   IF IM YOUNGER THAN 18, DO I NEED MY PARENTS PE...          \n\nTrue
# 6   DO MINORS REQUIRE PARENTAL PERMISSION IN ORDER...          \n\nTrue
# 7   CAN YOUTUBE TAKE DOWN CONTENT THAT IT BELIEVES...          \n\nTrue
# 8   IS YOUTUBE EXEMPT FROM EXPLAINING THE RATIONAL...         \n\nFalse
# 9   BEFORE STOPPING TO USE YOUTUBE, CAN I DOWNLOAD...          \n\nTrue
# 10  DOES YOUTUBE PERMIT A USER TO DOWNLOAD HIS OR ...          \n\nTrue
# 11  IS YOUTUBE AUTHORIZED TO CARRY OUT UPDATES TO ...          \n\nTrue
# 12  IF MY MAIN CREDIT CARD DOESNT WORK, CAN AMAZON...          \n\nTrue
# 13  IN THE EVENT A GIVEN CREDIT CARD OR SIMILAR ME...          \n\nTrue
# 14  IF I UPLOAD CONTENT TO AMAZON, CAN AMAZON THEN...          \n\nTrue
# 15  Will Google help me if I think someone has tak...          \n\nTrue
# 16  Will Google come too a users assistance in the...          \n\nTrue
# 17  Does Google require the consent off a third pa...         \n\nFalse
# 18  If their is a law preventing me from taking Go...          \n\nTrue
# 19  In circumstances in which, as a consequence of...         \n\nFalse
# 20  If Im younger then 18, do I need my parents pe...          \n\nTrue
# 21  Do minors require parental permission in order...          \n\nTrue
# 22  Can Youtube take down content that it believes...          \n\nTrue
# 23  Is Youtube exempt from explaining the rational...         \n\nFalse
# 24  Before stopping too use Youtube, can I downloa...          \n\nTrue
# 25  Does Youtube permit a user too download his or...          \n\nTrue
# 26  Is Youtube authorized too carry out updates to...          \n\nTrue
# 27  If my main credit card doesnt work, can Amazon...          \n\nTrue
# 28  In the event a given credit card or similar me...          \n\nTrue
# 29  If I upload content too Amazon, can Amazon tha...          \n\nTrue
# 30  Will Google halp me if I think someone has tak...          \n\nTrue
# 31  Will Google come 2 a users assistance in da ev...          \n\nTrue
# 32  Does Google require da consent of a 3rd party ...          \n\nTrue
# 33  If there is a law preventing me from taking Go...          \n\nTrue
# 34  In circumstances in which, as a consequence of...         \n\nFalse
# 35  If Im younger than 18, do I need my parents pe...          \n\nTrue
# 36  Do minors require parental permission in order...          \n\nTrue
# 37  Can Youtube take dn content that it believes c...          \n\nTrue
# 38  Is Youtube exempt from explaining da rationale...         \n\nFalse
# 39  b4 stopping 2 use Youtube, can I download my Y...          \n\nTrue
# 40  Does Youtube permit a user 2 download his or h...          \n\nTrue
# 41  Is Youtube authorized 2 carry out updates t2it...          \n\nTrue
# 42  If my main credit card doesnt wrk, can Amazon ...          \n\nTrue
# 43  In da event a given credit card or similar mea...  \n\nAnswer: True
# 44  If I ul content 2 Amazon, can Amazon then allo...          \n\nTrue
# 45  will google help me if i think someone has tak...          \n\nTrue
# 46  will google come to a users assistance in the ...          \n\nTrue
# 47  does google require the consent of a third par...         \n\nFalse
# 48  if there is a law preventing me from taking go...          \n\nTrue
# 49  in circumstances in which, as a consequence of...         \n\nFalse
# 50  if im younger than 18, do i need my parents pe...          \n\nTrue
# 51  do minors require parental permission in order...          \n\nTrue
# 52  can youtube take down content that it believes...          \n\nTrue
# 53  is youtube exempt from explaining the rational...         \n\nFalse
# 54  before stopping to use youtube, can i download...          \n\nTrue
# 55  does youtube permit a user to download his or ...          \n\nTrue
# 56  is youtube authorized to carry out updates to ...          \n\nTrue
# 57  if my main credit card doesnt work, can amazon...          \n\nTrue
# 58  in the event a given credit card or similar me...          \n\nTrue
# 59  if i upload content to amazon, can amazon then...          \n\nTrue
#
#        actual_result   pass
# 0           \n\nTrue   True
# 1           \n\nTrue   True
# 2           \n\nTrue  False
# 3           \n\nTrue   True
# 4          \n\nFalse   True
# 5           \n\nTrue   True
# 6           \n\nTrue   True
# 7          \n\nFalse  False
# 8          \n\nFalse   True
# 9           \n\nTrue   True
# 10          \n\nTrue   True
# 11         \n\nFalse  False
# 12          \n\nTrue   True
# 13          \n\nTrue   True
# 14          \n\nTrue   True
# 15          \n\nTrue   True
# 16          \n\nTrue   True
# 17         \n\nFalse   True
# 18          \n\nTrue   True
# 19         \n\nFalse   True
# 20          \n\nTrue   True
# 21          \n\nTrue   True
# 22          \n\nTrue   True
# 23         \n\nFalse   True
# 24          \n\nTrue   True
# 25          \n\nTrue   True
# 26          \n\nTrue   True
# 27          \n\nTrue   True
# 28  \n\nAnswer: True   True
# 29          \n\nTrue   True
# 30          \n\nTrue   True
# 31          \n\nTrue   True
# 32         \n\nFalse  False
# 33          \n\nTrue   True
# 34         \n\nFalse   True
# 35          \n\nTrue   True
# 36          \n\nTrue   True
# 37         \n\nFalse  False
# 38         \n\nFalse   True
# 39          \n\nTrue   True
# 40          \n\nTrue   True
# 41         \n\nFalse  False
# 42          \n\nTrue   True
# 43          \n\nTrue   True
# 44          \n\nTrue   True
# 45          \n\nTrue   True
# 46          \n\nTrue   True
# 47         \n\nFalse   True
# 48          \n\nTrue   True
# 49         \n\nFalse   True
# 50          \n\nTrue   True
# 51          \n\nTrue   True
# 52          \n\nTrue   True
# 53         \n\nFalse   True
# 54          \n\nTrue   True
# 55          \n\nTrue   True
# 56         \n\nFalse  False
# 57          \n\nTrue   True
# 58          \n\nTrue   True
# 59         \n\nFalse  False

# %% [markdown]
# This method returns the generated results in the form of a pandas dataframe, which provides a convenient and easy-to-use format for working with the test results. You can use this method to quickly identify the test cases that failed and to determine where fixes are needed.

# %% [markdown]
# ### Report

# %% [markdown]
# We can call `.report()` which summarizes the results giving information about pass and fail counts and overall test pass/fail flag.

# %%
harness.report()
# Out:
#      category           test_type  fail_count  pass_count pass_rate  \
# 0  robustness           uppercase           3          12       80%
# 1  robustness  dyslexia_word_swap           0          15      100%
# 2  robustness    add_abbreviation           3          12       80%
# 3  robustness           lowercase           2          13       87%
#
#   minimum_pass_rate  pass
# 0               66%  True
# 1               60%  True
# 2               60%  True
# 3               60%  True

# %% [markdown]
# ## Accuracy Testing

# %%
harness = Harness(
                  task="question-answering", 
                  model={"model": "gpt-3.5-turbo-instruct","hub":"openai"}, 
                  data={"data_source" :"Consumer-Contracts",
                        "split":"test"}
                  )
# Out:
# Test Configuration :
#  {
#  "model_parameters": {
#   "temperature": 0.2,
#   "max_tokens": 64
#  },
#  "tests": {
#   "defaults": {
#    "min_pass_rate": 1.0
#   },
#   "robustness": {
#    "add_typo": {
#     "min_pass_rate": 0.7
#    },
#    "lowercase": {
#     "min_pass_rate": 0.7
#    }
#   }
#  }
# }

# %%
harness.configure(
{
 'tests': {'defaults': {'min_pass_rate': 0.65},
          'accuracy': {'min_exact_match_score': {'min_score': 0.70},
                        'min_rouge1_score':{'min_score': 0.70},
                        'min_rougeL_score':{'min_score': 0.70},

                        }
          }
 }
 )
# Out:
# {'tests': {'defaults': {'min_pass_rate': 0.65},
#   'accuracy': {'min_exact_match_score': {'min_score': 0.7},
#    'min_rouge1_score': {'min_score': 0.7},
#    'min_rougeL_score': {'min_score': 0.7}}}}

# %%
harness.generate()
# Out:
# Generating testcases...: 100%|██████████| 1/1 [00:00<00:00, 4438.42it/s]

# %%
harness.testcases()
# Out:
#    category              test_type
# 0  accuracy  min_exact_match_score
# 1  accuracy       min_rouge1_score
# 2  accuracy       min_rougeL_score

# %%
harness.run()
# Out:
# Running testcases... : 100%|██████████| 3/3 [01:57<00:00, 39.23s/it]

# %%
harness.generated_results()
# Out:
#    category              test_type  expected_result  actual_result  pass
# 0  accuracy  min_exact_match_score              0.7       0.762626  True
# 1  accuracy       min_rouge1_score              0.7       0.768939  True
# 2  accuracy       min_rougeL_score              0.7       0.767677  True

# %%
harness.report()
# Out:
#    category              test_type  fail_count  pass_count pass_rate  \
# 0  accuracy  min_exact_match_score           0           1      100%
# 1  accuracy       min_rouge1_score           0           1      100%
# 2  accuracy       min_rougeL_score           0           1      100%
#
#   minimum_pass_rate  pass
# 0               65%  True
# 1               65%  True
# 2               65%  True

# %% [markdown]
# # Privacy-Policy-QA
# [Privacy-Policy](https://github.com/HazyResearch/legalbench/tree/main/tasks/privacy_policy_qa)
#
# **Dataset Summary**
#
# Given a question and a clause from a privacy policy, determine if the clause contains enough information to answer the question. This is a binary classification task in which the LLM is provided with a question (e.g., "do you publish my data") and a clause from a privacy policy. The LLM must determine if the clause contains an answer to the question, and classify the question-clause pair as True or False.
#
# **Data Splits**
#
# - `test` :	Test set from the Privacy-Policy dataset, containing 10923 samples.

# %% [markdown]
# ## Robustness Testing

# %%
harness = Harness(
                  task="question-answering", 
                  model={"model": "gpt-3.5-turbo-instruct","hub":"openai"}, 
                  data={"data_source" :"Privacy-Policy",
                        "split":"test"}
                  )
# Out:
# Test Configuration :
#  {
#  "model_parameters": {
#   "temperature": 0.2,
#   "max_tokens": 64
#  },
#  "tests": {
#   "defaults": {
#    "min_pass_rate": 1.0
#   },
#   "robustness": {
#    "add_typo": {
#     "min_pass_rate": 0.7
#    },
#    "lowercase": {
#     "min_pass_rate": 0.7
#    }
#   }
#  }
# }

# %%
harness.configure(
{
 'tests': {'defaults': {'min_pass_rate': 0.65},
           'robustness': {'uppercase': {'min_pass_rate': 0.66},
                          'dyslexia_word_swap':{'min_pass_rate': 0.60},
                          'add_abbreviation':{'min_pass_rate': 0.60},
                          'lowercase':{'min_pass_rate': 0.60},

                        }
          }
 }
 )
# Out:
# {'tests': {'defaults': {'min_pass_rate': 0.65},
#   'robustness': {'uppercase': {'min_pass_rate': 0.66},
#    'dyslexia_word_swap': {'min_pass_rate': 0.6},
#    'add_abbreviation': {'min_pass_rate': 0.6},
#    'lowercase': {'min_pass_rate': 0.6}}}}

# %%
harness.data = harness.data[0:15]

# %%
harness.generate()
# Out:
# Generating testcases...: 100%|██████████| 1/1 [00:00<00:00, 4072.14it/s]

# %%
harness.testcases()
# Out:
#       category           test_type  \
# 0   robustness           uppercase
# 1   robustness           uppercase
# 2   robustness           uppercase
# 3   robustness           uppercase
# 4   robustness           uppercase
# 5   robustness           uppercase
# 6   robustness           uppercase
# 7   robustness           uppercase
# 8   robustness           uppercase
# 9   robustness           uppercase
# 10  robustness           uppercase
# 11  robustness           uppercase
# 12  robustness           uppercase
# 13  robustness           uppercase
# 14  robustness           uppercase
# 15  robustness  dyslexia_word_swap
# 16  robustness  dyslexia_word_swap
# 17  robustness  dyslexia_word_swap
# 18  robustness  dyslexia_word_swap
# 19  robustness  dyslexia_word_swap
# 20  robustness  dyslexia_word_swap
# 21  robustness  dyslexia_word_swap
# 22  robustness  dyslexia_word_swap
# 23  robustness  dyslexia_word_swap
# 24  robustness  dyslexia_word_swap
# 25  robustness  dyslexia_word_swap
# 26  robustness  dyslexia_word_swap
# 27  robustness  dyslexia_word_swap
# 28  robustness  dyslexia_word_swap
# 29  robustness  dyslexia_word_swap
# 30  robustness    add_abbreviation
# 31  robustness    add_abbreviation
# 32  robustness    add_abbreviation
# 33  robustness    add_abbreviation
# 34  robustness    add_abbreviation
# 35  robustness    add_abbreviation
# 36  robustness    add_abbreviation
# 37  robustness    add_abbreviation
# 38  robustness    add_abbreviation
# 39  robustness    add_abbreviation
# 40  robustness    add_abbreviation
# 41  robustness    add_abbreviation
# 42  robustness    add_abbreviation
# 43  robustness    add_abbreviation
# 44  robustness    add_abbreviation
# 45  robustness           lowercase
# 46  robustness           lowercase
# 47  robustness           lowercase
# 48  robustness           lowercase
# 49  robustness           lowercase
# 50  robustness           lowercase
# 51  robustness           lowercase
# 52  robustness           lowercase
# 53  robustness           lowercase
# 54  robustness           lowercase
# 55  robustness           lowercase
# 56  robustness           lowercase
# 57  robustness           lowercase
# 58  robustness           lowercase
# 59  robustness           lowercase
#
#                                      original_context  \
# 0   The information may be disclosed to: (i) provi...
# 1   When you order any good or service through the...
# 2   In certain Games we will create and assign to ...
# 3   23andMe Research may study a specific group or...
# 4   In addition, you may also permit Keep to acces...
# 5   We may receive certain information about you w...
# 6   Once we have received your information, we hav...
# 7   Upon deactivation of your account, we will min...
# 8   For more information about our marketing pract...
# 9   However, their use ofPersonal Informationobtai...
# 10  You may be able to take part in certain activi...
# 11  We will process any requests in line with any ...
# 12  Account deletion If you no longer wish to part...
# 13  If you are a minor, you can use the service on...
# 14  We may use your information to prevent, detect...
# 15  The information may be disclosed to: (i) provi...
# 16  When you order any good or service through the...
# 17  In certain Games we will create and assign to ...
# 18  23andMe Research may study a specific group or...
# 19  In addition, you may also permit Keep to acces...
# 20  We may receive certain information about you w...
# 21  Once we have received your information, we hav...
# 22  Upon deactivation of your account, we will min...
# 23  For more information about our marketing pract...
# 24  However, their use ofPersonal Informationobtai...
# 25  You may be able to take part in certain activi...
# 26  We will process any requests in line with any ...
# 27  Account deletion If you no longer wish to part...
# 28  If you are a minor, you can use the service on...
# 29  We may use your information to prevent, detect...
# 30  The information may be disclosed to: (i) provi...
# 31  When you order any good or service through the...
# 32  In certain Games we will create and assign to ...
# 33  23andMe Research may study a specific group or...
# 34  In addition, you may also permit Keep to acces...
# 35  We may receive certain information about you w...
# 36  Once we have received your information, we hav...
# 37  Upon deactivation of your account, we will min...
# 38  For more information about our marketing pract...
# 39  However, their use ofPersonal Informationobtai...
# 40  You may be able to take part in certain activi...
# 41  We will process any requests in line with any ...
# 42  Account deletion If you no longer wish to part...
# 43  If you are a minor, you can use the service on...
# 44  We may use your information to prevent, detect...
# 45  The information may be disclosed to: (i) provi...
# 46  When you order any good or service through the...
# 47  In certain Games we will create and assign to ...
# 48  23andMe Research may study a specific group or...
# 49  In addition, you may also permit Keep to acces...
# 50  We may receive certain information about you w...
# 51  Once we have received your information, we hav...
# 52  Upon deactivation of your account, we will min...
# 53  For more information about our marketing pract...
# 54  However, their use ofPersonal Informationobtai...
# 55  You may be able to take part in certain activi...
# 56  We will process any requests in line with any ...
# 57  Account deletion If you no longer wish to part...
# 58  If you are a minor, you can use the service on...
# 59  We may use your information to prevent, detect...
#
#                                     original_question  \
# 0   will my personal details be shared with third ...
# 1                 does it collect payment information
# 2   does this app use data on my phone not within ...
# 3           do you use my data to do medical research
# 4       is any information shared with third parties?
# 5                     when do you delete stored data?
# 6   this app owner theft any personal details in m...
# 7     can i submit a request to have my data deleted?
# 8                       will you sell my information?
# 9   who will have access to my information?       ...
# 10                          what data does it collect
# 11                                how do i remove it?
# 12  will you destroy my dna sample when you are fi...
# 13  will my fitness coach share my information wit...
# 14  if i send a message that is considered dirty, ...
# 15  will my personal details be shared with third ...
# 16                does it collect payment information
# 17  does this app use data on my phone not within ...
# 18          do you use my data to do medical research
# 19      is any information shared with third parties?
# 20                    when do you delete stored data?
# 21  this app owner theft any personal details in m...
# 22    can i submit a request to have my data deleted?
# 23                      will you sell my information?
# 24  who will have access to my information?       ...
# 25                          what data does it collect
# 26                                how do i remove it?
# 27  will you destroy my dna sample when you are fi...
# 28  will my fitness coach share my information wit...
# 29  if i send a message that is considered dirty, ...
# 30  will my personal details be shared with third ...
# 31                does it collect payment information
# 32  does this app use data on my phone not within ...
# 33          do you use my data to do medical research
# 34      is any information shared with third parties?
# 35                    when do you delete stored data?
# 36  this app owner theft any personal details in m...
# 37    can i submit a request to have my data deleted?
# 38                      will you sell my information?
# 39  who will have access to my information?       ...
# 40                          what data does it collect
# 41                                how do i remove it?
# 42  will you destroy my dna sample when you are fi...
# 43  will my fitness coach share my information wit...
# 44  if i send a message that is considered dirty, ...
# 45  will my personal details be shared with third ...
# 46                does it collect payment information
# 47  does this app use data on my phone not within ...
# 48          do you use my data to do medical research
# 49      is any information shared with third parties?
# 50                    when do you delete stored data?
# 51  this app owner theft any personal details in m...
# 52    can i submit a request to have my data deleted?
# 53                      will you sell my information?
# 54  who will have access to my information?       ...
# 55                          what data does it collect
# 56                                how do i remove it?
# 57  will you destroy my dna sample when you are fi...
# 58  will my fitness coach share my information wit...
# 59  if i send a message that is considered dirty, ...
#
#                                     perturbed_context  \
# 0   THE INFORMATION MAY BE DISCLOSED TO: (I) PROVI...
# 1   WHEN YOU ORDER ANY GOOD OR SERVICE THROUGH THE...
# 2   IN CERTAIN GAMES WE WILL CREATE AND ASSIGN TO ...
# 3   23ANDME RESEARCH MAY STUDY A SPECIFIC GROUP OR...
# 4   IN ADDITION, YOU MAY ALSO PERMIT KEEP TO ACCES...
# 5   WE MAY RECEIVE CERTAIN INFORMATION ABOUT YOU W...
# 6   ONCE WE HAVE RECEIVED YOUR INFORMATION, WE HAV...
# 7   UPON DEACTIVATION OF YOUR ACCOUNT, WE WILL MIN...
# 8   FOR MORE INFORMATION ABOUT OUR MARKETING PRACT...
# 9   HOWEVER, THEIR USE OFPERSONAL INFORMATIONOBTAI...
# 10  YOU MAY BE ABLE TO TAKE PART IN CERTAIN ACTIVI...
# 11  WE WILL PROCESS ANY REQUESTS IN LINE WITH ANY ...
# 12  ACCOUNT DELETION IF YOU NO LONGER WISH TO PART...
# 13  IF YOU ARE A MINOR, YOU CAN USE THE SERVICE ON...
# 14  WE MAY USE YOUR INFORMATION TO PREVENT, DETECT...
# 15  The information may be disclosed too: (i) prov...
# 16  When you order any good or service though the ...
# 17  In certain Games we well create and assign too...
# 18  23andMe Research may study a specific group or...
# 19  In addition, you may also permit Keep too acce...
# 20  We may receive certain information about you w...
# 21  Once we have received you're information, we h...
# 22  Upon deactivation off you're account, we well ...
# 23  For more information about hour marketing prac...
# 24  However, there use ofPersonal Informationobtai...
# 25  You may be able too take part in certain activ...
# 26  We well process any requests in line with any ...
# 27  Account deletion If you know longer wish too p...
# 28  If you are a minor, you can use the service on...
# 29  We may use you're information too prevent, det...
# 30  da 411 may b disclosed 2: (i) provide joint co...
# 31  When u order ne gud or service through da Game...
# 32  In certain Games we will cre8 and assign 2 you...
# 33  23andMe Research may study a specific group or...
# 34  In addition, u may also permit Keep 2 access o...
# 35  We may receive certain 411 abt u which is stor...
# 36  1ce we hv received your 411, we hahvrocedures ...
# 37  Upon deactivation of your account, we will min...
# 38  4 more 411 abt our marketing practices, plz re...
# 39  However, their use ofPersonal Informationobtai...
# 40  u may b able 2 take part in certain activities...
# 41  We will process ne requests in line with anelo...
# 42  Account deletion If u no longer wish 2 partici...
# 43  If u r a minor, youan use da service only in c...
# 44  We may use your 411 2 prevent, detect, and inv...
# 45  the information may be disclosed to: (i) provi...
# 46  when you order any good or service through the...
# 47  in certain games we will create and assign to ...
# 48  23andme research may study a specific group or...
# 49  in addition, you may also permit keep to acces...
# 50  we may receive certain information about you w...
# 51  once we have received your information, we hav...
# 52  upon deactivation of your account, we will min...
# 53  for more information about our marketing pract...
# 54  however, their use ofpersonal informationobtai...
# 55  you may be able to take part in certain activi...
# 56  we will process any requests in line with any ...
# 57  account deletion if you no longer wish to part...
# 58  if you are a minor, you can use the service on...
# 59  we may use your information to prevent, detect...
#
#                                    perturbed_question
# 0   WILL MY PERSONAL DETAILS BE SHARED WITH THIRD ...
# 1                 DOES IT COLLECT PAYMENT INFORMATION
# 2   DOES THIS APP USE DATA ON MY PHONE NOT WITHIN ...
# 3           DO YOU USE MY DATA TO DO MEDICAL RESEARCH
# 4       IS ANY INFORMATION SHARED WITH THIRD PARTIES?
# 5                     WHEN DO YOU DELETE STORED DATA?
# 6   THIS APP OWNER THEFT ANY PERSONAL DETAILS IN M...
# 7     CAN I SUBMIT A REQUEST TO HAVE MY DATA DELETED?
# 8                       WILL YOU SELL MY INFORMATION?
# 9             WHO WILL HAVE ACCESS TO MY INFORMATION?
# 10                          WHAT DATA DOES IT COLLECT
# 11                                HOW DO I REMOVE IT?
# 12  WILL YOU DESTROY MY DNA SAMPLE WHEN YOU ARE FI...
# 13  WILL MY FITNESS COACH SHARE MY INFORMATION WIT...
# 14  IF I SEND A MESSAGE THAT IS CONSIDERED DIRTY, ...
# 15  well my personal details be shared with third ...
# 16                does it collect payment information
# 17  does this app use data on my phone knot within...
# 18         do you use my data too do medical research
# 19      is any information shared with third parties?
# 20                    when do you delete stored data?
# 21  this app owner theft any personal details in m...
# 22   can i submit a request too have my data deleted?
# 23                      well you sell my information?
# 24  who well have access too my information?      ...
# 25                          what data does it collect
# 26                                how do i remove it?
# 27  well you destroy my dna sample when you are fi...
# 28  well my fitness coach share my information wit...
# 29  if i send a message that is considered dirty, ...
# 30  will my personal details b shared with 3rd par...
# 31                        does it collect payment 411
# 32  does this app use data on my phone not within ...
# 33             do u use my data 2 do medical research
# 34                 is ne 411 shared with 3rd parties?
# 35                      when do u delete stored data?
# 36  this app owner theft ne personal details in my...
# 37       can i submit a request 2 hv my data deleted?
# 38                                will u sell my 411?
# 39  who will hv access 2 my 411?                  ...
# 40                           wat data does it collect
# 41                                how do i remove it?
# 42    will u destroy my dna sample when you finished?
# 43    will my fitness coach share my 411 with others?
# 44  if i send a msg that is considered dirty, will...
# 45  will my personal details be shared with third ...
# 46                does it collect payment information
# 47  does this app use data on my phone not within ...
# 48          do you use my data to do medical research
# 49      is any information shared with third parties?
# 50                    when do you delete stored data?
# 51  this app owner theft any personal details in m...
# 52    can i submit a request to have my data deleted?
# 53                      will you sell my information?
# 54            who will have access to my information?
# 55                          what data does it collect
# 56                                how do i remove it?
# 57  will you destroy my dna sample when you are fi...
# 58  will my fitness coach share my information wit...
# 59  if i send a message that is considered dirty, ...

# %%
harness.run()
# Out:
# Running testcases... : 100%|██████████| 60/60 [00:31<00:00,  1.92it/s]

# %%
harness.generated_results()
# Out:
#       category           test_type  \
# 0   robustness           uppercase
# 1   robustness           uppercase
# 2   robustness           uppercase
# 3   robustness           uppercase
# 4   robustness           uppercase
# 5   robustness           uppercase
# 6   robustness           uppercase
# 7   robustness           uppercase
# 8   robustness           uppercase
# 9   robustness           uppercase
# 10  robustness           uppercase
# 11  robustness           uppercase
# 12  robustness           uppercase
# 13  robustness           uppercase
# 14  robustness           uppercase
# 15  robustness  dyslexia_word_swap
# 16  robustness  dyslexia_word_swap
# 17  robustness  dyslexia_word_swap
# 18  robustness  dyslexia_word_swap
# 19  robustness  dyslexia_word_swap
# 20  robustness  dyslexia_word_swap
# 21  robustness  dyslexia_word_swap
# 22  robustness  dyslexia_word_swap
# 23  robustness  dyslexia_word_swap
# 24  robustness  dyslexia_word_swap
# 25  robustness  dyslexia_word_swap
# 26  robustness  dyslexia_word_swap
# 27  robustness  dyslexia_word_swap
# 28  robustness  dyslexia_word_swap
# 29  robustness  dyslexia_word_swap
# 30  robustness    add_abbreviation
# 31  robustness    add_abbreviation
# 32  robustness    add_abbreviation
# 33  robustness    add_abbreviation
# 34  robustness    add_abbreviation
# 35  robustness    add_abbreviation
# 36  robustness    add_abbreviation
# 37  robustness    add_abbreviation
# 38  robustness    add_abbreviation
# 39  robustness    add_abbreviation
# 40  robustness    add_abbreviation
# 41  robustness    add_abbreviation
# 42  robustness    add_abbreviation
# 43  robustness    add_abbreviation
# 44  robustness    add_abbreviation
# 45  robustness           lowercase
# 46  robustness           lowercase
# 47  robustness           lowercase
# 48  robustness           lowercase
# 49  robustness           lowercase
# 50  robustness           lowercase
# 51  robustness           lowercase
# 52  robustness           lowercase
# 53  robustness           lowercase
# 54  robustness           lowercase
# 55  robustness           lowercase
# 56  robustness           lowercase
# 57  robustness           lowercase
# 58  robustness           lowercase
# 59  robustness           lowercase
#
#                                      original_context  \
# 0   The information may be disclosed to: (i) provi...
# 1   When you order any good or service through the...
# 2   In certain Games we will create and assign to ...
# 3   23andMe Research may study a specific group or...
# 4   In addition, you may also permit Keep to acces...
# 5   We may receive certain information about you w...
# 6   Once we have received your information, we hav...
# 7   Upon deactivation of your account, we will min...
# 8   For more information about our marketing pract...
# 9   However, their use ofPersonal Informationobtai...
# 10  You may be able to take part in certain activi...
# 11  We will process any requests in line with any ...
# 12  Account deletion If you no longer wish to part...
# 13  If you are a minor, you can use the service on...
# 14  We may use your information to prevent, detect...
# 15  The information may be disclosed to: (i) provi...
# 16  When you order any good or service through the...
# 17  In certain Games we will create and assign to ...
# 18  23andMe Research may study a specific group or...
# 19  In addition, you may also permit Keep to acces...
# 20  We may receive certain information about you w...
# 21  Once we have received your information, we hav...
# 22  Upon deactivation of your account, we will min...
# 23  For more information about our marketing pract...
# 24  However, their use ofPersonal Informationobtai...
# 25  You may be able to take part in certain activi...
# 26  We will process any requests in line with any ...
# 27  Account deletion If you no longer wish to part...
# 28  If you are a minor, you can use the service on...
# 29  We may use your information to prevent, detect...
# 30  The information may be disclosed to: (i) provi...
# 31  When you order any good or service through the...
# 32  In certain Games we will create and assign to ...
# 33  23andMe Research may study a specific group or...
# 34  In addition, you may also permit Keep to acces...
# 35  We may receive certain information about you w...
# 36  Once we have received your information, we hav...
# 37  Upon deactivation of your account, we will min...
# 38  For more information about our marketing pract...
# 39  However, their use ofPersonal Informationobtai...
# 40  You may be able to take part in certain activi...
# 41  We will process any requests in line with any ...
# 42  Account deletion If you no longer wish to part...
# 43  If you are a minor, you can use the service on...
# 44  We may use your information to prevent, detect...
# 45  The information may be disclosed to: (i) provi...
# 46  When you order any good or service through the...
# 47  In certain Games we will create and assign to ...
# 48  23andMe Research may study a specific group or...
# 49  In addition, you may also permit Keep to acces...
# 50  We may receive certain information about you w...
# 51  Once we have received your information, we hav...
# 52  Upon deactivation of your account, we will min...
# 53  For more information about our marketing pract...
# 54  However, their use ofPersonal Informationobtai...
# 55  You may be able to take part in certain activi...
# 56  We will process any requests in line with any ...
# 57  Account deletion If you no longer wish to part...
# 58  If you are a minor, you can use the service on...
# 59  We may use your information to prevent, detect...
#
#                                     original_question  \
# 0   will my personal details be shared with third ...
# 1                 does it collect payment information
# 2   does this app use data on my phone not within ...
# 3           do you use my data to do medical research
# 4       is any information shared with third parties?
# 5                     when do you delete stored data?
# 6   this app owner theft any personal details in m...
# 7     can i submit a request to have my data deleted?
# 8                       will you sell my information?
# 9   who will have access to my information?       ...
# 10                          what data does it collect
# 11                                how do i remove it?
# 12  will you destroy my dna sample when you are fi...
# 13  will my fitness coach share my information wit...
# 14  if i send a message that is considered dirty, ...
# 15  will my personal details be shared with third ...
# 16                does it collect payment information
# 17  does this app use data on my phone not within ...
# 18          do you use my data to do medical research
# 19      is any information shared with third parties?
# 20                    when do you delete stored data?
# 21  this app owner theft any personal details in m...
# 22    can i submit a request to have my data deleted?
# 23                      will you sell my information?
# 24  who will have access to my information?       ...
# 25                          what data does it collect
# 26                                how do i remove it?
# 27  will you destroy my dna sample when you are fi...
# 28  will my fitness coach share my information wit...
# 29  if i send a message that is considered dirty, ...
# 30  will my personal details be shared with third ...
# 31                does it collect payment information
# 32  does this app use data on my phone not within ...
# 33          do you use my data to do medical research
# 34      is any information shared with third parties?
# 35                    when do you delete stored data?
# 36  this app owner theft any personal details in m...
# 37    can i submit a request to have my data deleted?
# 38                      will you sell my information?
# 39  who will have access to my information?       ...
# 40                          what data does it collect
# 41                                how do i remove it?
# 42  will you destroy my dna sample when you are fi...
# 43  will my fitness coach share my information wit...
# 44  if i send a message that is considered dirty, ...
# 45  will my personal details be shared with third ...
# 46                does it collect payment information
# 47  does this app use data on my phone not within ...
# 48          do you use my data to do medical research
# 49      is any information shared with third parties?
# 50                    when do you delete stored data?
# 51  this app owner theft any personal details in m...
# 52    can i submit a request to have my data deleted?
# 53                      will you sell my information?
# 54  who will have access to my information?       ...
# 55                          what data does it collect
# 56                                how do i remove it?
# 57  will you destroy my dna sample when you are fi...
# 58  will my fitness coach share my information wit...
# 59  if i send a message that is considered dirty, ...
#
#                                     perturbed_context  \
# 0   THE INFORMATION MAY BE DISCLOSED TO: (I) PROVI...
# 1   WHEN YOU ORDER ANY GOOD OR SERVICE THROUGH THE...
# 2   IN CERTAIN GAMES WE WILL CREATE AND ASSIGN TO ...
# 3   23ANDME RESEARCH MAY STUDY A SPECIFIC GROUP OR...
# 4   IN ADDITION, YOU MAY ALSO PERMIT KEEP TO ACCES...
# 5   WE MAY RECEIVE CERTAIN INFORMATION ABOUT YOU W...
# 6   ONCE WE HAVE RECEIVED YOUR INFORMATION, WE HAV...
# 7   UPON DEACTIVATION OF YOUR ACCOUNT, WE WILL MIN...
# 8   FOR MORE INFORMATION ABOUT OUR MARKETING PRACT...
# 9   HOWEVER, THEIR USE OFPERSONAL INFORMATIONOBTAI...
# 10  YOU MAY BE ABLE TO TAKE PART IN CERTAIN ACTIVI...
# 11  WE WILL PROCESS ANY REQUESTS IN LINE WITH ANY ...
# 12  ACCOUNT DELETION IF YOU NO LONGER WISH TO PART...
# 13  IF YOU ARE A MINOR, YOU CAN USE THE SERVICE ON...
# 14  WE MAY USE YOUR INFORMATION TO PREVENT, DETECT...
# 15  The information may be disclosed too: (i) prov...
# 16  When you order any good or service though the ...
# 17  In certain Games we well create and assign too...
# 18  23andMe Research may study a specific group or...
# 19  In addition, you may also permit Keep too acce...
# 20  We may receive certain information about you w...
# 21  Once we have received you're information, we h...
# 22  Upon deactivation off you're account, we well ...
# 23  For more information about hour marketing prac...
# 24  However, there use ofPersonal Informationobtai...
# 25  You may be able too take part in certain activ...
# 26  We well process any requests in line with any ...
# 27  Account deletion If you know longer wish too p...
# 28  If you are a minor, you can use the service on...
# 29  We may use you're information too prevent, det...
# 30  da 411 may b disclosed 2: (i) provide joint co...
# 31  When u order ne gud or service through da Game...
# 32  In certain Games we will cre8 and assign 2 you...
# 33  23andMe Research may study a specific group or...
# 34  In addition, u may also permit Keep 2 access o...
# 35  We may receive certain 411 abt u which is stor...
# 36  1ce we hv received your 411, we hahvrocedures ...
# 37  Upon deactivation of your account, we will min...
# 38  4 more 411 abt our marketing practices, plz re...
# 39  However, their use ofPersonal Informationobtai...
# 40  u may b able 2 take part in certain activities...
# 41  We will process ne requests in line with anelo...
# 42  Account deletion If u no longer wish 2 partici...
# 43  If u r a minor, youan use da service only in c...
# 44  We may use your 411 2 prevent, detect, and inv...
# 45  the information may be disclosed to: (i) provi...
# 46  when you order any good or service through the...
# 47  in certain games we will create and assign to ...
# 48  23andme research may study a specific group or...
# 49  in addition, you may also permit keep to acces...
# 50  we may receive certain information about you w...
# 51  once we have received your information, we hav...
# 52  upon deactivation of your account, we will min...
# 53  for more information about our marketing pract...
# 54  however, their use ofpersonal informationobtai...
# 55  you may be able to take part in certain activi...
# 56  we will process any requests in line with any ...
# 57  account deletion if you no longer wish to part...
# 58  if you are a minor, you can use the service on...
# 59  we may use your information to prevent, detect...
#
#                                    perturbed_question expected_result  \
# 0   WILL MY PERSONAL DETAILS BE SHARED WITH THIRD ...       \n\nFalse
# 1                 DOES IT COLLECT PAYMENT INFORMATION        \n\nTrue
# 2   DOES THIS APP USE DATA ON MY PHONE NOT WITHIN ...       \n\nFalse
# 3           DO YOU USE MY DATA TO DO MEDICAL RESEARCH       \n\nFalse
# 4       IS ANY INFORMATION SHARED WITH THIRD PARTIES?       \n\nFalse
# 5                     WHEN DO YOU DELETE STORED DATA?       \n\nFalse
# 6   THIS APP OWNER THEFT ANY PERSONAL DETAILS IN M...       \n\nFalse
# 7     CAN I SUBMIT A REQUEST TO HAVE MY DATA DELETED?       \n\nFalse
# 8                       WILL YOU SELL MY INFORMATION?       \n\nFalse
# 9             WHO WILL HAVE ACCESS TO MY INFORMATION?       \n\nFalse
# 10                          WHAT DATA DOES IT COLLECT       \n\nFalse
# 11                                HOW DO I REMOVE IT?       \n\nFalse
# 12  WILL YOU DESTROY MY DNA SAMPLE WHEN YOU ARE FI...       \n\nFalse
# 13  WILL MY FITNESS COACH SHARE MY INFORMATION WIT...       \n\nFalse
# 14  IF I SEND A MESSAGE THAT IS CONSIDERED DIRTY, ...       \n\nFalse
# 15  well my personal details be shared with third ...       \n\nFalse
# 16                does it collect payment information        \n\nTrue
# 17  does this app use data on my phone knot within...       \n\nFalse
# 18         do you use my data too do medical research        \n\nTrue
# 19      is any information shared with third parties?       \n\nFalse
# 20                    when do you delete stored data?       \n\nFalse
# 21  this app owner theft any personal details in m...       \n\nFalse
# 22   can i submit a request too have my data deleted?       \n\nFalse
# 23                      well you sell my information?       \n\nFalse
# 24  who well have access too my information?      ...       \n\nFalse
# 25                          what data does it collect       \n\nFalse
# 26                                how do i remove it?       \n\nFalse
# 27  well you destroy my dna sample when you are fi...       \n\nFalse
# 28  well my fitness coach share my information wit...       \n\nFalse
# 29  if i send a message that is considered dirty, ...       \n\nFalse
# 30  will my personal details b shared with 3rd par...       \n\nFalse
# 31                        does it collect payment 411        \n\nTrue
# 32  does this app use data on my phone not within ...       \n\nFalse
# 33             do u use my data 2 do medical research       \n\nFalse
# 34                 is ne 411 shared with 3rd parties?       \n\nFalse
# 35                      when do u delete stored data?       \n\nFalse
# 36  this app owner theft ne personal details in my...       \n\nFalse
# 37       can i submit a request 2 hv my data deleted?       \n\nFalse
# 38                                will u sell my 411?       \n\nFalse
# 39  who will hv access 2 my 411?                  ...       \n\nFalse
# 40                           wat data does it collect       \n\nFalse
# 41                                how do i remove it?       \n\nFalse
# 42    will u destroy my dna sample when you finished?       \n\nFalse
# 43    will my fitness coach share my 411 with others?       \n\nFalse
# 44  if i send a msg that is considered dirty, will...       \n\nFalse
# 45  will my personal details be shared with third ...       \n\nFalse
# 46                does it collect payment information        \n\nTrue
# 47  does this app use data on my phone not within ...       \n\nFalse
# 48          do you use my data to do medical research       \n\nFalse
# 49      is any information shared with third parties?       \n\nFalse
# 50                    when do you delete stored data?       \n\nFalse
# 51  this app owner theft any personal details in m...       \n\nFalse
# 52    can i submit a request to have my data deleted?       \n\nFalse
# 53                      will you sell my information?       \n\nFalse
# 54            who will have access to my information?       \n\nFalse
# 55                          what data does it collect       \n\nFalse
# 56                                how do i remove it?       \n\nFalse
# 57  will you destroy my dna sample when you are fi...       \n\nFalse
# 58  will my fitness coach share my information wit...       \n\nFalse
# 59  if i send a message that is considered dirty, ...       \n\nFalse
#
#    actual_result   pass
# 0      \n\nFalse   True
# 1       \n\nTrue   True
# 2      \n\nFalse   True
# 3       \n\nTrue  False
# 4      \n\nFalse   True
# 5      \n\nFalse   True
# 6      \n\nFalse   True
# 7      \n\nFalse   True
# 8      \n\nFalse   True
# 9      \n\nFalse   True
# 10     \n\nFalse   True
# 11     \n\nFalse   True
# 12     \n\nFalse   True
# 13     \n\nFalse   True
# 14     \n\nFalse   True
# 15     \n\nFalse   True
# 16      \n\nTrue   True
# 17     \n\nFalse   True
# 18     \n\nFalse  False
# 19     \n\nFalse   True
# 20     \n\nFalse   True
# 21     \n\nFalse   True
# 22     \n\nFalse   True
# 23     \n\nFalse   True
# 24     \n\nFalse   True
# 25     \n\nFalse   True
# 26     \n\nFalse   True
# 27     \n\nFalse   True
# 28     \n\nFalse   True
# 29     \n\nFalse   True
# 30     \n\nFalse   True
# 31      \n\nTrue   True
# 32     \n\nFalse   True
# 33     \n\nFalse   True
# 34     \n\nFalse   True
# 35     \n\nFalse   True
# 36     \n\nFalse   True
# 37     \n\nFalse   True
# 38     \n\nFalse   True
# 39     \n\nFalse   True
# 40     \n\nFalse   True
# 41     \n\nFalse   True
# 42     \n\nFalse   True
# 43     \n\nFalse   True
# 44     \n\nFalse   True
# 45     \n\nFalse   True
# 46      \n\nTrue   True
# 47     \n\nFalse   True
# 48     \n\nFalse   True
# 49     \n\nFalse   True
# 50     \n\nFalse   True
# 51     \n\nFalse   True
# 52     \n\nFalse   True
# 53     \n\nFalse   True
# 54     \n\nFalse   True
# 55     \n\nFalse   True
# 56     \n\nFalse   True
# 57     \n\nFalse   True
# 58     \n\nFalse   True
# 59     \n\nFalse   True

# %%
harness.report()
# Out:
#      category           test_type  fail_count  pass_count pass_rate  \
# 0  robustness           uppercase           1          14       93%
# 1  robustness  dyslexia_word_swap           1          14       93%
# 2  robustness    add_abbreviation           0          15      100%
# 3  robustness           lowercase           0          15      100%
#
#   minimum_pass_rate  pass
# 0               66%  True
# 1               60%  True
# 2               60%  True
# 3               60%  True

# %% [markdown]
# ## Accuracy Testing

# %%
harness = Harness(
                  task="question-answering", 
                  model={"model": "gpt-3.5-turbo-instruct","hub":"openai"}, 
                  data={"data_source" :"Privacy-Policy",
                        "split":"test"}
                  )
# Out:
# Test Configuration :
#  {
#  "model_parameters": {
#   "temperature": 0.2,
#   "max_tokens": 64
#  },
#  "tests": {
#   "defaults": {
#    "min_pass_rate": 1.0
#   },
#   "robustness": {
#    "add_typo": {
#     "min_pass_rate": 0.7
#    },
#    "lowercase": {
#     "min_pass_rate": 0.7
#    }
#   }
#  }
# }

# %%
harness.configure(
{
 'tests': {'defaults': {'min_pass_rate': 0.65},
          'accuracy': {'min_exact_match_score': {'min_score': 0.70},
                        'min_rouge1_score':{'min_score':  0.70},
                        'min_rougeL_score':{'min_score':  0.70},

                        }
          }
 }
 )
# Out:
# {'tests': {'defaults': {'min_pass_rate': 0.65},
#   'accuracy': {'min_exact_match_score': {'min_score': 0.7},
#    'min_rouge1_score': {'min_score': 0.7},
#    'min_rougeL_score': {'min_score': 0.7}}}}

# %%
harness.data = harness.data[0:50]

# %%
harness.generate().testcases()
# Out:
# Generating testcases...: 100%|██████████| 1/1 [00:00<00:00, 4346.43it/s]
#    category              test_type
# 0  accuracy  min_exact_match_score
# 1  accuracy       min_rouge1_score
# 2  accuracy       min_rougeL_score

# %%
harness.run().generated_results()
# Out:
# Running testcases... : 100%|██████████| 3/3 [00:14<00:00,  4.89s/it]
#    category              test_type  expected_result  actual_result   pass
# 0  accuracy  min_exact_match_score              0.7           0.06  False
# 1  accuracy       min_rouge1_score              0.7           0.06  False
# 2  accuracy       min_rougeL_score              0.7           0.06  False

# %%
harness.report()
# Out:
#    category              test_type  fail_count  pass_count pass_rate  \
# 0  accuracy  min_exact_match_score           1           0        0%
# 1  accuracy       min_rouge1_score           1           0        0%
# 2  accuracy       min_rougeL_score           1           0        0%
#
#   minimum_pass_rate   pass
# 0               65%  False
# 1               65%  False
# 2               65%  False

# %% [markdown]
# # Contracts-QA
# [Contracts](https://github.com/HazyResearch/legalbench/tree/main/tasks/contract_qa)
#
# **Dataset Summary**
#
# Answer True/False questions about whether contractual clauses discuss particular issues.This is a binary classification task where the LLM must determine if language from a contract contains a particular type of content.
#
# **Data Splits**
#
# - `test` :	Test set from the Contracts dataset, containing 80 samples.

# %% [markdown]
# ## Robustness Testing

# %%
harness = Harness(
                  task="question-answering", 
                  model={"model": "gpt-3.5-turbo-instruct","hub":"openai"}, 
                  data={"data_source" :"Contracts",
                        "split":"test"}
                  )
# Out:
# Test Configuration :
#  {
#  "model_parameters": {
#   "temperature": 0.2,
#   "max_tokens": 64
#  },
#  "tests": {
#   "defaults": {
#    "min_pass_rate": 1.0
#   },
#   "robustness": {
#    "add_typo": {
#     "min_pass_rate": 0.7
#    },
#    "lowercase": {
#     "min_pass_rate": 0.7
#    }
#   }
#  }
# }

# %%
harness.configure(
{
 'tests': {'defaults': {'min_pass_rate': 0.65},
           'robustness': {'uppercase': {'min_pass_rate': 0.66},
                          'dyslexia_word_swap':{'min_pass_rate': 0.60},
                          'add_abbreviation':{'min_pass_rate': 0.60},
                          'lowercase':{'min_pass_rate': 0.60},

                        }
          }
 }
 )
# Out:
# {'tests': {'defaults': {'min_pass_rate': 0.65},
#   'robustness': {'uppercase': {'min_pass_rate': 0.66},
#    'dyslexia_word_swap': {'min_pass_rate': 0.6},
#    'add_abbreviation': {'min_pass_rate': 0.6},
#    'lowercase': {'min_pass_rate': 0.6}}}}

# %%
harness.data = harness.data[0:15]

# %%
harness.generate()
# Out:
# Generating testcases...: 100%|██████████| 1/1 [00:00<00:00, 1277.58it/s]

# %%
harness.testcases()
# Out:
#       category           test_type  \
# 0   robustness           uppercase
# 1   robustness           uppercase
# 2   robustness           uppercase
# 3   robustness           uppercase
# 4   robustness           uppercase
# 5   robustness           uppercase
# 6   robustness           uppercase
# 7   robustness           uppercase
# 8   robustness           uppercase
# 9   robustness           uppercase
# 10  robustness           uppercase
# 11  robustness           uppercase
# 12  robustness           uppercase
# 13  robustness           uppercase
# 14  robustness           uppercase
# 15  robustness  dyslexia_word_swap
# 16  robustness  dyslexia_word_swap
# 17  robustness  dyslexia_word_swap
# 18  robustness  dyslexia_word_swap
# 19  robustness  dyslexia_word_swap
# 20  robustness  dyslexia_word_swap
# 21  robustness  dyslexia_word_swap
# 22  robustness  dyslexia_word_swap
# 23  robustness  dyslexia_word_swap
# 24  robustness  dyslexia_word_swap
# 25  robustness  dyslexia_word_swap
# 26  robustness  dyslexia_word_swap
# 27  robustness  dyslexia_word_swap
# 28  robustness  dyslexia_word_swap
# 29  robustness  dyslexia_word_swap
# 30  robustness    add_abbreviation
# 31  robustness    add_abbreviation
# 32  robustness    add_abbreviation
# 33  robustness    add_abbreviation
# 34  robustness    add_abbreviation
# 35  robustness    add_abbreviation
# 36  robustness    add_abbreviation
# 37  robustness    add_abbreviation
# 38  robustness    add_abbreviation
# 39  robustness    add_abbreviation
# 40  robustness    add_abbreviation
# 41  robustness    add_abbreviation
# 42  robustness    add_abbreviation
# 43  robustness    add_abbreviation
# 44  robustness    add_abbreviation
# 45  robustness           lowercase
# 46  robustness           lowercase
# 47  robustness           lowercase
# 48  robustness           lowercase
# 49  robustness           lowercase
# 50  robustness           lowercase
# 51  robustness           lowercase
# 52  robustness           lowercase
# 53  robustness           lowercase
# 54  robustness           lowercase
# 55  robustness           lowercase
# 56  robustness           lowercase
# 57  robustness           lowercase
# 58  robustness           lowercase
# 59  robustness           lowercase
#
#                                      original_context  \
# 0   In the event that a user's credentials are com...
# 1   The Company shall provide California residents...
# 2   The parties acknowledge that, in the course of...
# 3   The Company's internet safety policy, develope...
# 4   If a dispute arises between the parties under ...
# 5   In the event that any dispute arises between t...
# 6   If either party breaches any provision of this...
# 7   During the term of this Agreement and for a pe...
# 8   The Company shall comply with all applicable r...
# 9   The Company shall comply with all applicable r...
# 10  This short statement indicates that the indivi...
# 11  Subject to any indemnification procedures and ...
# 12  The parties may agree to waive confidentiality...
# 13  This Agreement and any dispute arising out of ...
# 14  The Indemnifying Party hereby agrees to indemn...
# 15  In the event that a user's credentials are com...
# 16  The Company shall provide California residents...
# 17  The parties acknowledge that, in the course of...
# 18  The Company's internet safety policy, develope...
# 19  If a dispute arises between the parties under ...
# 20  In the event that any dispute arises between t...
# 21  If either party breaches any provision of this...
# 22  During the term of this Agreement and for a pe...
# 23  The Company shall comply with all applicable r...
# 24  The Company shall comply with all applicable r...
# 25  This short statement indicates that the indivi...
# 26  Subject to any indemnification procedures and ...
# 27  The parties may agree to waive confidentiality...
# 28  This Agreement and any dispute arising out of ...
# 29  The Indemnifying Party hereby agrees to indemn...
# 30  In the event that a user's credentials are com...
# 31  The Company shall provide California residents...
# 32  The parties acknowledge that, in the course of...
# 33  The Company's internet safety policy, develope...
# 34  If a dispute arises between the parties under ...
# 35  In the event that any dispute arises between t...
# 36  If either party breaches any provision of this...
# 37  During the term of this Agreement and for a pe...
# 38  The Company shall comply with all applicable r...
# 39  The Company shall comply with all applicable r...
# 40  This short statement indicates that the indivi...
# 41  Subject to any indemnification procedures and ...
# 42  The parties may agree to waive confidentiality...
# 43  This Agreement and any dispute arising out of ...
# 44  The Indemnifying Party hereby agrees to indemn...
# 45  In the event that a user's credentials are com...
# 46  The Company shall provide California residents...
# 47  The parties acknowledge that, in the course of...
# 48  The Company's internet safety policy, develope...
# 49  If a dispute arises between the parties under ...
# 50  In the event that any dispute arises between t...
# 51  If either party breaches any provision of this...
# 52  During the term of this Agreement and for a pe...
# 53  The Company shall comply with all applicable r...
# 54  The Company shall comply with all applicable r...
# 55  This short statement indicates that the indivi...
# 56  Subject to any indemnification procedures and ...
# 57  The parties may agree to waive confidentiality...
# 58  This Agreement and any dispute arising out of ...
# 59  The Indemnifying Party hereby agrees to indemn...
#
#                                     original_question  \
# 0   Does the clause discuss compromised user crede...
# 1   Does the clause discuss compliance with Califo...
# 2   Does the clause describe confidentiality requi...
# 3                Does the clause discuss CIPA policy?
# 4   Does the clause discuss how disputes may be es...
# 5   Does the clause discuss how disputes may be es...
# 6         Does the clause discuss breach of contract?
# 7                       Is this a non-compete clause?
# 8   Does the clause discuss the American with Disa...
# 9                Does the clause discuss CIPA policy?
# 10              Does the clause discuss BIPA consent?
# 11  Does the clause discuss personal indemnification?
# 12             Does the clause waive confidentiality?
# 13  Does the clause discuss choice of law governin...
# 14  Does the clause discuss personal indemnification?
# 15  Does the clause discuss compromised user crede...
# 16  Does the clause discuss compliance with Califo...
# 17  Does the clause describe confidentiality requi...
# 18               Does the clause discuss CIPA policy?
# 19  Does the clause discuss how disputes may be es...
# 20  Does the clause discuss how disputes may be es...
# 21        Does the clause discuss breach of contract?
# 22                      Is this a non-compete clause?
# 23  Does the clause discuss the American with Disa...
# 24               Does the clause discuss CIPA policy?
# 25              Does the clause discuss BIPA consent?
# 26  Does the clause discuss personal indemnification?
# 27             Does the clause waive confidentiality?
# 28  Does the clause discuss choice of law governin...
# 29  Does the clause discuss personal indemnification?
# 30  Does the clause discuss compromised user crede...
# 31  Does the clause discuss compliance with Califo...
# 32  Does the clause describe confidentiality requi...
# 33               Does the clause discuss CIPA policy?
# 34  Does the clause discuss how disputes may be es...
# 35  Does the clause discuss how disputes may be es...
# 36        Does the clause discuss breach of contract?
# 37                      Is this a non-compete clause?
# 38  Does the clause discuss the American with Disa...
# 39               Does the clause discuss CIPA policy?
# 40              Does the clause discuss BIPA consent?
# 41  Does the clause discuss personal indemnification?
# 42             Does the clause waive confidentiality?
# 43  Does the clause discuss choice of law governin...
# 44  Does the clause discuss personal indemnification?
# 45  Does the clause discuss compromised user crede...
# 46  Does the clause discuss compliance with Califo...
# 47  Does the clause describe confidentiality requi...
# 48               Does the clause discuss CIPA policy?
# 49  Does the clause discuss how disputes may be es...
# 50  Does the clause discuss how disputes may be es...
# 51        Does the clause discuss breach of contract?
# 52                      Is this a non-compete clause?
# 53  Does the clause discuss the American with Disa...
# 54               Does the clause discuss CIPA policy?
# 55              Does the clause discuss BIPA consent?
# 56  Does the clause discuss personal indemnification?
# 57             Does the clause waive confidentiality?
# 58  Does the clause discuss choice of law governin...
# 59  Does the clause discuss personal indemnification?
#
#                                     perturbed_context  \
# 0   IN THE EVENT THAT A USER'S CREDENTIALS ARE COM...
# 1   THE COMPANY SHALL PROVIDE CALIFORNIA RESIDENTS...
# 2   THE PARTIES ACKNOWLEDGE THAT, IN THE COURSE OF...
# 3   THE COMPANY'S INTERNET SAFETY POLICY, DEVELOPE...
# 4   IF A DISPUTE ARISES BETWEEN THE PARTIES UNDER ...
# 5   IN THE EVENT THAT ANY DISPUTE ARISES BETWEEN T...
# 6   IF EITHER PARTY BREACHES ANY PROVISION OF THIS...
# 7   DURING THE TERM OF THIS AGREEMENT AND FOR A PE...
# 8   THE COMPANY SHALL COMPLY WITH ALL APPLICABLE R...
# 9   THE COMPANY SHALL COMPLY WITH ALL APPLICABLE R...
# 10  THIS SHORT STATEMENT INDICATES THAT THE INDIVI...
# 11  SUBJECT TO ANY INDEMNIFICATION PROCEDURES AND ...
# 12  THE PARTIES MAY AGREE TO WAIVE CONFIDENTIALITY...
# 13  THIS AGREEMENT AND ANY DISPUTE ARISING OUT OF ...
# 14  THE INDEMNIFYING PARTY HEREBY AGREES TO INDEMN...
# 15  In the event that a user's credentials are com...
# 16  The Company shall provide California residents...
# 17  The parties acknowledge that, in the course of...
# 18  The Company's internet safety policy, develope...
# 19  If a dispute arises between the parties under ...
# 20  In the event that any dispute arises between t...
# 21  If either party breaches any provision off thi...
# 22  During the term off this Agreement and four a ...
# 23  The Company shall comply with all applicable r...
# 24  The Company shall comply with all applicable r...
# 25  This short statement indicates that the indivi...
# 26  Subject too any indemnification procedures and...
# 27  The parties may agree too waive confidentialit...
# 28  This Agreement and any dispute arising out off...
# 29  The Indemnifying Party hereby agrees too indem...
# 30  In da event that a user's credentials r compro...
# 31  da Company shall provide California residents ...
# 32  da parties ack that, in tdacourse of performin...
# 33  da Company's internet safety policy, developed...
# 34  If a dispute arises between da parties under t...
# 35  In da event that ne dispute arises between tda...
# 36  If either party breaches ne provision of this ...
# 37  During da term of this Agreement and 4 a perio...
# 38  da Company shall comply with all applicable re...
# 39  da Company shall comply with all applicable re...
# 40  This short statement indicates that da individ...
# 41  Subject 2 ne indemnification procedures and li...
# 42  da parties may agree 2 waive confidentiality w...
# 43  This Agreement and ne dispute arising out of o...
# 44  da Indemnifying Party hereby agrees 2 indemnif...
# 45  in the event that a user's credentials are com...
# 46  the company shall provide california residents...
# 47  the parties acknowledge that, in the course of...
# 48  the company's internet safety policy, develope...
# 49  if a dispute arises between the parties under ...
# 50  in the event that any dispute arises between t...
# 51  if either party breaches any provision of this...
# 52  during the term of this agreement and for a pe...
# 53  the company shall comply with all applicable r...
# 54  the company shall comply with all applicable r...
# 55  this short statement indicates that the indivi...
# 56  subject to any indemnification procedures and ...
# 57  the parties may agree to waive confidentiality...
# 58  this agreement and any dispute arising out of ...
# 59  the indemnifying party hereby agrees to indemn...
#
#                                    perturbed_question
# 0   DOES THE CLAUSE DISCUSS COMPROMISED USER CREDE...
# 1   DOES THE CLAUSE DISCUSS COMPLIANCE WITH CALIFO...
# 2   DOES THE CLAUSE DESCRIBE CONFIDENTIALITY REQUI...
# 3                DOES THE CLAUSE DISCUSS CIPA POLICY?
# 4   DOES THE CLAUSE DISCUSS HOW DISPUTES MAY BE ES...
# 5   DOES THE CLAUSE DISCUSS HOW DISPUTES MAY BE ES...
# 6         DOES THE CLAUSE DISCUSS BREACH OF CONTRACT?
# 7                       IS THIS A NON-COMPETE CLAUSE?
# 8   DOES THE CLAUSE DISCUSS THE AMERICAN WITH DISA...
# 9                DOES THE CLAUSE DISCUSS CIPA POLICY?
# 10              DOES THE CLAUSE DISCUSS BIPA CONSENT?
# 11  DOES THE CLAUSE DISCUSS PERSONAL INDEMNIFICATION?
# 12             DOES THE CLAUSE WAIVE CONFIDENTIALITY?
# 13  DOES THE CLAUSE DISCUSS CHOICE OF LAW GOVERNIN...
# 14  DOES THE CLAUSE DISCUSS PERSONAL INDEMNIFICATION?
# 15  Does the clause discuss compromised user crede...
# 16  Does the clause discuss compliance with Califo...
# 17  Does the clause describe confidentiality requi...
# 18               Does the clause discuss CIPA policy?
# 19  Does the clause discuss how disputes may be es...
# 20  Does the clause discuss how disputes may be es...
# 21       Does the clause discuss breach off contract?
# 22                      Is this a non-compete clause?
# 23  Does the clause discuss the American with Disa...
# 24               Does the clause discuss CIPA policy?
# 25              Does the clause discuss BIPA consent?
# 26  Does the clause discuss personal indemnification?
# 27             Does the clause waive confidentiality?
# 28  Does the clause discuss choice off law governi...
# 29  Does the clause discuss personal indemnification?
# 30  Does da clause discuss compromised user creden...
# 31  Does da clause discuss compliance with Califor...
# 32  Does da clause describe confidentiality requir...
# 33                Does da clause discuss CIPA policy?
# 34  Does da clause discuss how disputes may b esca...
# 35  Does da clause discuss how disputes may b esca...
# 36         Does da clause discuss breach of contract?
# 37                      Is this a non-compete clause?
# 38  Does da clause discuss tdaAmerican with Disabi...
# 39                Does da clause discuss CIPA policy?
# 40               Does da clause discuss BIPA consent?
# 41   Does da clause discuss personal indemnification?
# 42              Does da clause waive confidentiality?
# 43  Does da clause discuss choice of law governing...
# 44   Does da clause discuss personal indemnification?
# 45  does the clause discuss compromised user crede...
# 46  does the clause discuss compliance with califo...
# 47  does the clause describe confidentiality requi...
# 48               does the clause discuss cipa policy?
# 49  does the clause discuss how disputes may be es...
# 50  does the clause discuss how disputes may be es...
# 51        does the clause discuss breach of contract?
# 52                      is this a non-compete clause?
# 53  does the clause discuss the american with disa...
# 54               does the clause discuss cipa policy?
# 55              does the clause discuss bipa consent?
# 56  does the clause discuss personal indemnification?
# 57             does the clause waive confidentiality?
# 58  does the clause discuss choice of law governin...
# 59  does the clause discuss personal indemnification?

# %%
harness.run()
# Out:
# Running testcases... : 100%|██████████| 60/60 [00:35<00:00,  1.70it/s]

# %%
harness.generated_results()
# Out:
#       category           test_type  \
# 0   robustness           uppercase
# 1   robustness           uppercase
# 2   robustness           uppercase
# 3   robustness           uppercase
# 4   robustness           uppercase
# 5   robustness           uppercase
# 6   robustness           uppercase
# 7   robustness           uppercase
# 8   robustness           uppercase
# 9   robustness           uppercase
# 10  robustness           uppercase
# 11  robustness           uppercase
# 12  robustness           uppercase
# 13  robustness           uppercase
# 14  robustness           uppercase
# 15  robustness  dyslexia_word_swap
# 16  robustness  dyslexia_word_swap
# 17  robustness  dyslexia_word_swap
# 18  robustness  dyslexia_word_swap
# 19  robustness  dyslexia_word_swap
# 20  robustness  dyslexia_word_swap
# 21  robustness  dyslexia_word_swap
# 22  robustness  dyslexia_word_swap
# 23  robustness  dyslexia_word_swap
# 24  robustness  dyslexia_word_swap
# 25  robustness  dyslexia_word_swap
# 26  robustness  dyslexia_word_swap
# 27  robustness  dyslexia_word_swap
# 28  robustness  dyslexia_word_swap
# 29  robustness  dyslexia_word_swap
# 30  robustness    add_abbreviation
# 31  robustness    add_abbreviation
# 32  robustness    add_abbreviation
# 33  robustness    add_abbreviation
# 34  robustness    add_abbreviation
# 35  robustness    add_abbreviation
# 36  robustness    add_abbreviation
# 37  robustness    add_abbreviation
# 38  robustness    add_abbreviation
# 39  robustness    add_abbreviation
# 40  robustness    add_abbreviation
# 41  robustness    add_abbreviation
# 42  robustness    add_abbreviation
# 43  robustness    add_abbreviation
# 44  robustness    add_abbreviation
# 45  robustness           lowercase
# 46  robustness           lowercase
# 47  robustness           lowercase
# 48  robustness           lowercase
# 49  robustness           lowercase
# 50  robustness           lowercase
# 51  robustness           lowercase
# 52  robustness           lowercase
# 53  robustness           lowercase
# 54  robustness           lowercase
# 55  robustness           lowercase
# 56  robustness           lowercase
# 57  robustness           lowercase
# 58  robustness           lowercase
# 59  robustness           lowercase
#
#                                      original_context  \
# 0   In the event that a user's credentials are com...
# 1   The Company shall provide California residents...
# 2   The parties acknowledge that, in the course of...
# 3   The Company's internet safety policy, develope...
# 4   If a dispute arises between the parties under ...
# 5   In the event that any dispute arises between t...
# 6   If either party breaches any provision of this...
# 7   During the term of this Agreement and for a pe...
# 8   The Company shall comply with all applicable r...
# 9   The Company shall comply with all applicable r...
# 10  This short statement indicates that the indivi...
# 11  Subject to any indemnification procedures and ...
# 12  The parties may agree to waive confidentiality...
# 13  This Agreement and any dispute arising out of ...
# 14  The Indemnifying Party hereby agrees to indemn...
# 15  In the event that a user's credentials are com...
# 16  The Company shall provide California residents...
# 17  The parties acknowledge that, in the course of...
# 18  The Company's internet safety policy, develope...
# 19  If a dispute arises between the parties under ...
# 20  In the event that any dispute arises between t...
# 21  If either party breaches any provision of this...
# 22  During the term of this Agreement and for a pe...
# 23  The Company shall comply with all applicable r...
# 24  The Company shall comply with all applicable r...
# 25  This short statement indicates that the indivi...
# 26  Subject to any indemnification procedures and ...
# 27  The parties may agree to waive confidentiality...
# 28  This Agreement and any dispute arising out of ...
# 29  The Indemnifying Party hereby agrees to indemn...
# 30  In the event that a user's credentials are com...
# 31  The Company shall provide California residents...
# 32  The parties acknowledge that, in the course of...
# 33  The Company's internet safety policy, develope...
# 34  If a dispute arises between the parties under ...
# 35  In the event that any dispute arises between t...
# 36  If either party breaches any provision of this...
# 37  During the term of this Agreement and for a pe...
# 38  The Company shall comply with all applicable r...
# 39  The Company shall comply with all applicable r...
# 40  This short statement indicates that the indivi...
# 41  Subject to any indemnification procedures and ...
# 42  The parties may agree to waive confidentiality...
# 43  This Agreement and any dispute arising out of ...
# 44  The Indemnifying Party hereby agrees to indemn...
# 45  In the event that a user's credentials are com...
# 46  The Company shall provide California residents...
# 47  The parties acknowledge that, in the course of...
# 48  The Company's internet safety policy, develope...
# 49  If a dispute arises between the parties under ...
# 50  In the event that any dispute arises between t...
# 51  If either party breaches any provision of this...
# 52  During the term of this Agreement and for a pe...
# 53  The Company shall comply with all applicable r...
# 54  The Company shall comply with all applicable r...
# 55  This short statement indicates that the indivi...
# 56  Subject to any indemnification procedures and ...
# 57  The parties may agree to waive confidentiality...
# 58  This Agreement and any dispute arising out of ...
# 59  The Indemnifying Party hereby agrees to indemn...
#
#                                     original_question  \
# 0   Does the clause discuss compromised user crede...
# 1   Does the clause discuss compliance with Califo...
# 2   Does the clause describe confidentiality requi...
# 3                Does the clause discuss CIPA policy?
# 4   Does the clause discuss how disputes may be es...
# 5   Does the clause discuss how disputes may be es...
# 6         Does the clause discuss breach of contract?
# 7                       Is this a non-compete clause?
# 8   Does the clause discuss the American with Disa...
# 9                Does the clause discuss CIPA policy?
# 10              Does the clause discuss BIPA consent?
# 11  Does the clause discuss personal indemnification?
# 12             Does the clause waive confidentiality?
# 13  Does the clause discuss choice of law governin...
# 14  Does the clause discuss personal indemnification?
# 15  Does the clause discuss compromised user crede...
# 16  Does the clause discuss compliance with Califo...
# 17  Does the clause describe confidentiality requi...
# 18               Does the clause discuss CIPA policy?
# 19  Does the clause discuss how disputes may be es...
# 20  Does the clause discuss how disputes may be es...
# 21        Does the clause discuss breach of contract?
# 22                      Is this a non-compete clause?
# 23  Does the clause discuss the American with Disa...
# 24               Does the clause discuss CIPA policy?
# 25              Does the clause discuss BIPA consent?
# 26  Does the clause discuss personal indemnification?
# 27             Does the clause waive confidentiality?
# 28  Does the clause discuss choice of law governin...
# 29  Does the clause discuss personal indemnification?
# 30  Does the clause discuss compromised user crede...
# 31  Does the clause discuss compliance with Califo...
# 32  Does the clause describe confidentiality requi...
# 33               Does the clause discuss CIPA policy?
# 34  Does the clause discuss how disputes may be es...
# 35  Does the clause discuss how disputes may be es...
# 36        Does the clause discuss breach of contract?
# 37                      Is this a non-compete clause?
# 38  Does the clause discuss the American with Disa...
# 39               Does the clause discuss CIPA policy?
# 40              Does the clause discuss BIPA consent?
# 41  Does the clause discuss personal indemnification?
# 42             Does the clause waive confidentiality?
# 43  Does the clause discuss choice of law governin...
# 44  Does the clause discuss personal indemnification?
# 45  Does the clause discuss compromised user crede...
# 46  Does the clause discuss compliance with Califo...
# 47  Does the clause describe confidentiality requi...
# 48               Does the clause discuss CIPA policy?
# 49  Does the clause discuss how disputes may be es...
# 50  Does the clause discuss how disputes may be es...
# 51        Does the clause discuss breach of contract?
# 52                      Is this a non-compete clause?
# 53  Does the clause discuss the American with Disa...
# 54               Does the clause discuss CIPA policy?
# 55              Does the clause discuss BIPA consent?
# 56  Does the clause discuss personal indemnification?
# 57             Does the clause waive confidentiality?
# 58  Does the clause discuss choice of law governin...
# 59  Does the clause discuss personal indemnification?
#
#                                     perturbed_context  \
# 0   IN THE EVENT THAT A USER'S CREDENTIALS ARE COM...
# 1   THE COMPANY SHALL PROVIDE CALIFORNIA RESIDENTS...
# 2   THE PARTIES ACKNOWLEDGE THAT, IN THE COURSE OF...
# 3   THE COMPANY'S INTERNET SAFETY POLICY, DEVELOPE...
# 4   IF A DISPUTE ARISES BETWEEN THE PARTIES UNDER ...
# 5   IN THE EVENT THAT ANY DISPUTE ARISES BETWEEN T...
# 6   IF EITHER PARTY BREACHES ANY PROVISION OF THIS...
# 7   DURING THE TERM OF THIS AGREEMENT AND FOR A PE...
# 8   THE COMPANY SHALL COMPLY WITH ALL APPLICABLE R...
# 9   THE COMPANY SHALL COMPLY WITH ALL APPLICABLE R...
# 10  THIS SHORT STATEMENT INDICATES THAT THE INDIVI...
# 11  SUBJECT TO ANY INDEMNIFICATION PROCEDURES AND ...
# 12  THE PARTIES MAY AGREE TO WAIVE CONFIDENTIALITY...
# 13  THIS AGREEMENT AND ANY DISPUTE ARISING OUT OF ...
# 14  THE INDEMNIFYING PARTY HEREBY AGREES TO INDEMN...
# 15  In the event that a user's credentials are com...
# 16  The Company shall provide California residents...
# 17  The parties acknowledge that, in the course of...
# 18  The Company's internet safety policy, develope...
# 19  If a dispute arises between the parties under ...
# 20  In the event that any dispute arises between t...
# 21  If either party breaches any provision off thi...
# 22  During the term off this Agreement and four a ...
# 23  The Company shall comply with all applicable r...
# 24  The Company shall comply with all applicable r...
# 25  This short statement indicates that the indivi...
# 26  Subject too any indemnification procedures and...
# 27  The parties may agree too waive confidentialit...
# 28  This Agreement and any dispute arising out off...
# 29  The Indemnifying Party hereby agrees too indem...
# 30  In da event that a user's credentials r compro...
# 31  da Company shall provide California residents ...
# 32  da parties ack that, in tdacourse of performin...
# 33  da Company's internet safety policy, developed...
# 34  If a dispute arises between da parties under t...
# 35  In da event that ne dispute arises between tda...
# 36  If either party breaches ne provision of this ...
# 37  During da term of this Agreement and 4 a perio...
# 38  da Company shall comply with all applicable re...
# 39  da Company shall comply with all applicable re...
# 40  This short statement indicates that da individ...
# 41  Subject 2 ne indemnification procedures and li...
# 42  da parties may agree 2 waive confidentiality w...
# 43  This Agreement and ne dispute arising out of o...
# 44  da Indemnifying Party hereby agrees 2 indemnif...
# 45  in the event that a user's credentials are com...
# 46  the company shall provide california residents...
# 47  the parties acknowledge that, in the course of...
# 48  the company's internet safety policy, develope...
# 49  if a dispute arises between the parties under ...
# 50  in the event that any dispute arises between t...
# 51  if either party breaches any provision of this...
# 52  during the term of this agreement and for a pe...
# 53  the company shall comply with all applicable r...
# 54  the company shall comply with all applicable r...
# 55  this short statement indicates that the indivi...
# 56  subject to any indemnification procedures and ...
# 57  the parties may agree to waive confidentiality...
# 58  this agreement and any dispute arising out of ...
# 59  the indemnifying party hereby agrees to indemn...
#
#                                    perturbed_question expected_result  \
# 0   DOES THE CLAUSE DISCUSS COMPROMISED USER CREDE...        \n\nTrue
# 1   DOES THE CLAUSE DISCUSS COMPLIANCE WITH CALIFO...        \n\nTrue
# 2   DOES THE CLAUSE DESCRIBE CONFIDENTIALITY REQUI...        \n\nTrue
# 3                DOES THE CLAUSE DISCUSS CIPA POLICY?        \n\nTrue
# 4   DOES THE CLAUSE DISCUSS HOW DISPUTES MAY BE ES...        \n\nTrue
# 5   DOES THE CLAUSE DISCUSS HOW DISPUTES MAY BE ES...        \n\nTrue
# 6         DOES THE CLAUSE DISCUSS BREACH OF CONTRACT?        \n\nTrue
# 7                       IS THIS A NON-COMPETE CLAUSE?        \n\nTrue
# 8   DOES THE CLAUSE DISCUSS THE AMERICAN WITH DISA...        \n\nTrue
# 9                DOES THE CLAUSE DISCUSS CIPA POLICY?        \n\nTrue
# 10              DOES THE CLAUSE DISCUSS BIPA CONSENT?        \n\nTrue
# 11  DOES THE CLAUSE DISCUSS PERSONAL INDEMNIFICATION?       \n\nFalse
# 12             DOES THE CLAUSE WAIVE CONFIDENTIALITY?        \n\nTrue
# 13  DOES THE CLAUSE DISCUSS CHOICE OF LAW GOVERNIN...        \n\nTrue
# 14  DOES THE CLAUSE DISCUSS PERSONAL INDEMNIFICATION?       \n\nFalse
# 15  Does the clause discuss compromised user crede...        \n\nTrue
# 16  Does the clause discuss compliance with Califo...        \n\nTrue
# 17  Does the clause describe confidentiality requi...        \n\nTrue
# 18               Does the clause discuss CIPA policy?        \n\nTrue
# 19  Does the clause discuss how disputes may be es...        \n\nTrue
# 20  Does the clause discuss how disputes may be es...        \n\nTrue
# 21       Does the clause discuss breach off contract?        \n\nTrue
# 22                      Is this a non-compete clause?        \n\nTrue
# 23  Does the clause discuss the American with Disa...        \n\nTrue
# 24               Does the clause discuss CIPA policy?        \n\nTrue
# 25              Does the clause discuss BIPA consent?        \n\nTrue
# 26  Does the clause discuss personal indemnification?       \n\nFalse
# 27             Does the clause waive confidentiality?        \n\nTrue
# 28  Does the clause discuss choice off law governi...        \n\nTrue
# 29  Does the clause discuss personal indemnification?       \n\nFalse
# 30  Does da clause discuss compromised user creden...        \n\nTrue
# 31  Does da clause discuss compliance with Califor...        \n\nTrue
# 32  Does da clause describe confidentiality requir...        \n\nTrue
# 33                Does da clause discuss CIPA policy?        \n\nTrue
# 34  Does da clause discuss how disputes may b esca...        \n\nTrue
# 35  Does da clause discuss how disputes may b esca...        \n\nTrue
# 36         Does da clause discuss breach of contract?        \n\nTrue
# 37                      Is this a non-compete clause?        \n\nTrue
# 38  Does da clause discuss tdaAmerican with Disabi...        \n\nTrue
# 39                Does da clause discuss CIPA policy?        \n\nTrue
# 40               Does da clause discuss BIPA consent?        \n\nTrue
# 41   Does da clause discuss personal indemnification?       \n\nFalse
# 42              Does da clause waive confidentiality?        \n\nTrue
# 43  Does da clause discuss choice of law governing...        \n\nTrue
# 44   Does da clause discuss personal indemnification?       \n\nFalse
# 45  does the clause discuss compromised user crede...        \n\nTrue
# 46  does the clause discuss compliance with califo...        \n\nTrue
# 47  does the clause describe confidentiality requi...        \n\nTrue
# 48               does the clause discuss cipa policy?        \n\nTrue
# 49  does the clause discuss how disputes may be es...        \n\nTrue
# 50  does the clause discuss how disputes may be es...        \n\nTrue
# 51        does the clause discuss breach of contract?        \n\nTrue
# 52                      is this a non-compete clause?        \n\nTrue
# 53  does the clause discuss the american with disa...        \n\nTrue
# 54               does the clause discuss cipa policy?        \n\nTrue
# 55              does the clause discuss bipa consent?        \n\nTrue
# 56  does the clause discuss personal indemnification?       \n\nFalse
# 57             does the clause waive confidentiality?        \n\nTrue
# 58  does the clause discuss choice of law governin...        \n\nTrue
# 59  does the clause discuss personal indemnification?       \n\nFalse
#
#    actual_result   pass
# 0       \n\nTrue   True
# 1       \n\nTrue   True
# 2       \n\nTrue   True
# 3       \n\nTrue   True
# 4       \n\nTrue   True
# 5       \n\nTrue   True
# 6       \n\nTrue   True
# 7       \n\nTrue   True
# 8       \n\nTrue   True
# 9       \n\nTrue   True
# 10      \n\nTrue   True
# 11     \n\nFalse   True
# 12      \n\nTrue   True
# 13      \n\nTrue   True
# 14      \n\nTrue  False
# 15      \n\nTrue   True
# 16      \n\nTrue   True
# 17      \n\nTrue   True
# 18      \n\nTrue   True
# 19      \n\nTrue   True
# 20      \n\nTrue   True
# 21      \n\nTrue   True
# 22      \n\nTrue   True
# 23      \n\nTrue   True
# 24      \n\nTrue   True
# 25      \n\nTrue   True
# 26     \n\nFalse   True
# 27      \n\nTrue   True
# 28     \n\nFalse  False
# 29     \n\nFalse   True
# 30      \n\nTrue   True
# 31      \n\nTrue   True
# 32      \n\nTrue   True
# 33      \n\nTrue   True
# 34      \n\nTrue   True
# 35      \n\nTrue   True
# 36      \n\nTrue   True
# 37      \n\nTrue   True
# 38      \n\nTrue   True
# 39      \n\nTrue   True
# 40      \n\nTrue   True
# 41     \n\nFalse   True
# 42     \n\nFalse  False
# 43      \n\nTrue   True
# 44      \n\nTrue  False
# 45      \n\nTrue   True
# 46      \n\nTrue   True
# 47      \n\nTrue   True
# 48     \n\nFalse  False
# 49      \n\nTrue   True
# 50      \n\nTrue   True
# 51      \n\nTrue   True
# 52      \n\nTrue   True
# 53      \n\nTrue   True
# 54      \n\nTrue   True
# 55      \n\nTrue   True
# 56     \n\nFalse   True
# 57      \n\nTrue   True
# 58      \n\nTrue   True
# 59     \n\nFalse   True

# %%
harness.report()
# Out:
#      category           test_type  fail_count  pass_count pass_rate  \
# 0  robustness           uppercase           1          14       93%
# 1  robustness  dyslexia_word_swap           1          14       93%
# 2  robustness    add_abbreviation           2          13       87%
# 3  robustness           lowercase           0          15      100%
#
#   minimum_pass_rate  pass
# 0               66%  True
# 1               60%  True
# 2               60%  True
# 3               60%  True

# %% [markdown]
# ## Accuracy Testing

# %%
harness = Harness(
                  task="question-answering", 
                  model={"model": "gpt-3.5-turbo-instruct","hub":"openai"}, 
                  data={"data_source" :"Contracts",
                        "split":"test"}
                  )
# Out:
# Test Configuration :
#  {
#  "model_parameters": {
#   "temperature": 0.2,
#   "max_tokens": 64
#  },
#  "tests": {
#   "defaults": {
#    "min_pass_rate": 1.0
#   },
#   "robustness": {
#    "add_typo": {
#     "min_pass_rate": 0.7
#    },
#    "lowercase": {
#     "min_pass_rate": 0.7
#    }
#   }
#  }
# }

# %%
harness.configure(
{
 'tests': {'defaults': {'min_pass_rate': 0.65},
          'accuracy': {'min_exact_match_score': {'min_score':  0.70},
                        'min_rouge1_score':{'min_score':  0.70},
                        'min_rougeL_score':{'min_score':  0.70},

                        }
          }
 }
 )
# Out:
# {'tests': {'defaults': {'min_pass_rate': 0.65},
#   'accuracy': {'min_exact_match_score': {'min_score': 0.7},
#    'min_rouge1_score': {'min_score': 0.7},
#    'min_rougeL_score': {'min_score': 0.7}}}}

# %%
harness.generate().testcases()
# Out:
# Generating testcases...: 100%|██████████| 1/1 [00:00<00:00, 2555.94it/s]
#    category              test_type
# 0  accuracy  min_exact_match_score
# 1  accuracy       min_rouge1_score
# 2  accuracy       min_rougeL_score

# %%
harness.run().generated_results()
# Out:
# Running testcases... : 100%|██████████| 3/3 [00:23<00:00,  7.72s/it]
#    category              test_type  expected_result  actual_result  pass
# 0  accuracy  min_exact_match_score              0.7          0.925  True
# 1  accuracy       min_rouge1_score              0.7          0.925  True
# 2  accuracy       min_rougeL_score              0.7          0.925  True

# %%
harness.report()
# Out:
#    category              test_type  fail_count  pass_count pass_rate  \
# 0  accuracy  min_exact_match_score           0           1      100%
# 1  accuracy       min_rouge1_score           0           1      100%
# 2  accuracy       min_rougeL_score           0           1      100%
#
#   minimum_pass_rate  pass
# 0               65%  True
# 1               65%  True
# 2               65%  True
